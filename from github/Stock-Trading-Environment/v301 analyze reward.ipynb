# %%
import pickle
import numpy as np
import pandas as pd
from os import path
import matplotlib.pyplot as plt

# %%
DIR = "./output/301"
record = pickle.load(open(path.join(DIR,"BRZ_TW_NASDAQ-7d_detailed-ModelNo-50000-1.out"), "rb"))
df = pd.DataFrame(record)

# %%
df
# Out:
#           date                                       actual_price  \
# 0   2015-01-22  [48933.9561063885, 9218.096577760798, 4655.651...
# 1   2015-02-02  [48546.46944875992, 9442.000616151603, 4759.83...
# 2   2015-02-11  [47695.34797627248, 9444.650579567882, 4706.52...
# 3   2015-03-03  [49672.389769735004, 9476.793471819245, 4846.1...
# 4   2015-03-12  [50615.77319038512, 9619.481324760427, 4958.35...
# ..         ...                                                ...
# 154 2019-10-18  [100817.4748417999, 11005.15668422185, 7875.30...
# 155 2019-10-29  [105141.92597466499, 11151.83202948117, 8152.0...
# 156 2019-11-07  [107429.04273907316, 11311.745022934916, 8306....
# 157 2019-11-19  [108965.64296713361, 11620.96084093751, 8465.9...
# 158 2019-12-02  [106954.35010418, 11495.019125417168, 8514.796...
#
#                    action                                          inventory  \
# 0    [0.0, 0.0, 0.0, 0.0]  [240918.16198455665, 30158.30859815706, 30158....
# 1    [0.0, 0.0, 0.0, 0.0]  [240583.6237860406, 30073.445517726723, 30073....
# 2    [0.0, 0.0, 0.0, 0.0]  [236945.93830033558, 29618.423956301718, 29618...
# 3    [0.0, 0.0, 0.0, 0.0]  [245587.0630724496, 30695.936516945465, 30697....
# 4    [0.0, 0.0, 0.0, 0.0]  [250254.51729863844, 31281.50660907885, 31281....
# ..                    ...                                                ...
# 154  [0.0, 0.0, 0.0, 0.0]  [468054.75673679914, 58507.78128257054, 58507....
# 155  [0.0, 0.0, 0.0, 0.0]  [486386.1764914512, 60794.49765585348, 60797.6...
# 156  [0.0, 0.0, 0.0, 0.0]  [496462.97787802684, 62056.89383462757, 62057....
# 157  [0.0, 0.0, 0.0, 0.0]  [504453.4417712436, 63056.95866741891, 63056.9...
# 158  [0.0, 0.0, 0.0, 0.0]  [496745.4662259599, 62093.685234637764, 62093....
#
#                                            shares_held      net_worth  \
# 0    [4.923333021772665, 3.271641639220374, 6.47778...  301234.779181
# 1    [4.955738831635801, 3.185071336077093, 6.31817...  300730.514821
# 2    [4.967904593509028, 3.135999972341681, 6.29304...  296182.786213
# 3    [4.944136253780241, 3.239063572317443, 6.33451...  306980.879110
# 4    [4.944200227018883, 3.251891193817346, 6.30891...  312817.839584
# ..                                                 ...            ...
# 154  [4.642595517009905, 5.316396936579144, 7.42927...  585070.319302
# 155  [4.6259964517736805, 5.4515255874672555, 7.457...  607978.360197
# 156  [4.621310636490086, 5.486058402908241, 7.47140...  620577.464652
# 157  [4.629472446864721, 5.42613984596577, 7.448334...  630567.359106
# 158  [4.644462480881795, 5.401790510930038, 7.29244...  620932.836695
#
#      net_worth_delta  buyNhold_balance  buyNhold_delta  actual_profit  \
# 0        1234.779181     300000.000000        0.000000    1234.779181
# 1        -504.264359     306183.720514     6183.720514   -5453.205692
# 2       -4547.728609     305689.989463     -493.731051   -9507.203250
# 3       10798.092897     310175.748981     4485.759518   -3194.869871
# 4        5836.960474     315830.210615     5654.461634   -3012.371031
# ..               ...               ...             ...            ...
# 154    -17394.626816     495291.202167   -13975.052598   89779.117135
# 155     22908.040895     516949.715220    21658.513053   91028.644977
# 156     12599.104455     527065.281890    10115.566670   93512.182763
# 157      9989.894454     531277.605593     4212.323703   99289.753513
# 158     -9634.522411     531435.325519      157.719926   89497.511176
#
#         progress  testNo   rewards
# 0    1235.779181       0  0.010895
# 1      -0.081372       1  0.030090
# 2       9.227607       2  0.029710
# 3       2.406880       3  0.030768
# 4       1.032269       4  0.031280
# ..           ...     ...       ...
# 154     1.244709     154  0.058577
# 155     1.057690     155  0.060799
# 156     1.245492     156  0.062069
# 157     2.371262     157  0.063041
# 158   -60.695104     158  0.062120
#
# [159 rows x 13 columns]

# %%
DIR = "./output/301"
record = pickle.load(open(path.join(DIR,"BRZ_TW_NASDAQ-MultiRewardWithLeakage-7d_detailed-ModelNo-100-9.out"), "rb"))
df = pd.DataFrame(record)
plt.plot(df['rewards'], label="Rewards")
# plt.plot(df['progress']/100, label="Progress")
# plt.plot(df['actual_profit']/df['actual_profit'][0], label="Actual Profit")
# plt.scatter(range(len(df['action'])), [np.argmax(tmp)-3 for tmp in df['action']])
plt.legend()
plt.show()

# %%
DIR = "./output/301"
axx = plt.figure(figsize=(20,10))
plt.suptitle("Rewards of the Models")
plt.rcParams['figure.facecolor'] = 'white'
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
# legend_list = ['S&P 500', 'Germany Dax', 'Hang Seng', 'CASH']
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Rewards")
            ax = ax0
        else:
            ax = plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        
        record = pickle.load(open(path.join(DIR,"BRZ_TW_NASDAQ-MultiRewardWithLeakage-7d_detailed-ModelNo-100-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
#         plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=0, color = "grey", linestyle='--')
        plt.xlim((pd.Timestamp('2015-01-01'),pd.Timestamp('2019-12-31')))
        plt.ylim(-0.05,0.1)
        ax.set_xticks([pd.Timestamp('2015-01-01'), pd.Timestamp('2016-01-01'), 
                       pd.Timestamp('2017-01-01'), pd.Timestamp('2018-01-01'),
                       pd.Timestamp('2019-01-01'), pd.Timestamp('2020-01-01')])
        plt.plot(df['date'], df['rewards'], label="RL Model")
#         plt.plot(df['date'], df['buyNhold_balance'], label="Buy N Hold")
        
#         for j in range(3):
#             plt.plot(df['date'], [tmp[j] for tmp in df['inventory']/1000000], label = labels[j])
# #             first_price = df['actual_price'][0][j]
# #             plt.plot(df['date'], [tmp[j]/first_price*300000 for tmp in df['actual_price']])
        plt.title("Model "+str(i+1))
    except Exception as e:
        print(e)
plt.legend()

# %%
DIR = "./output/301"
axx = plt.figure(figsize=(20,10))
plt.suptitle("Inventory Value of the Models")
plt.rcParams['figure.facecolor'] = 'white'
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
# legend_list = ['S&P 500', 'Germany Dax', 'Hang Seng', 'CASH']
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Value ($)")
            ax = ax0
        else:
            ax = plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        
        record = pickle.load(open(path.join(DIR,"BRZ_TW_NASDAQ-MultiRewardWithLeakage-7d_detailed-ModelNo-100-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
#         plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=300000, color = "grey", linestyle='--')
        plt.xlim((pd.Timestamp('2015-01-01'),pd.Timestamp('2019-12-31')))
        ax.set_xticks([pd.Timestamp('2015-01-01'), pd.Timestamp('2016-01-01'), 
                       pd.Timestamp('2017-01-01'), pd.Timestamp('2018-01-01'),
                       pd.Timestamp('2019-01-01'), pd.Timestamp('2020-01-01')])
        plt.plot(df['date'], df['net_worth'], label="RL Model")
        plt.plot(df['date'], df['buyNhold_balance'], label="Buy N Hold")
        
        for j in range(3):
            plt.plot(df['date'], [tmp[j] for tmp in df['inventory']], label = labels[j])
#             first_price = df['actual_price'][0][j]
#             plt.plot(df['date'], [tmp[j]/first_price*300000 for tmp in df['actual_price']])
        plt.title("Model "+str(i+1))
    except Exception as e:
        print(e)
plt.legend()

# %%
DIR = "./output/302"
axx = plt.figure(figsize=(20,10))
plt.suptitle("Rewards of the Models")
plt.rcParams['figure.facecolor'] = 'white'
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
# legend_list = ['S&P 500', 'Germany Dax', 'Hang Seng', 'CASH']
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Rewards")
            ax = ax0
        else:
            ax = plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        
        record = pickle.load(open(path.join(DIR,"BRZ_TW_NASDAQ-7d_detailed-ModelNo-10000-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
#         plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=0, color = "grey", linestyle='--')
        plt.xlim((pd.Timestamp('2015-01-01'),pd.Timestamp('2019-12-31')))
        plt.ylim(-0.05,0.1)
        ax.set_xticks([pd.Timestamp('2015-01-01'), pd.Timestamp('2016-01-01'), 
                       pd.Timestamp('2017-01-01'), pd.Timestamp('2018-01-01'),
                       pd.Timestamp('2019-01-01'), pd.Timestamp('2020-01-01')])
        plt.plot(df['date'], df['rewards'], label="RL Model")
#         plt.plot(df['date'], df['buyNhold_balance'], label="Buy N Hold")
        
#         for j in range(3):
#             plt.plot(df['date'], [tmp[j] for tmp in df['inventory']/1000000], label = labels[j])
# #             first_price = df['actual_price'][0][j]
# #             plt.plot(df['date'], [tmp[j]/first_price*300000 for tmp in df['actual_price']])
        plt.title("Model "+str(i+1))
    except Exception as e:
        print(e)
plt.legend()

# %%
DIR = "./output/302"
axx = plt.figure(figsize=(20,10))
plt.suptitle("Inventory Value of the Models")
plt.rcParams['figure.facecolor'] = 'white'
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
# legend_list = ['S&P 500', 'Germany Dax', 'Hang Seng', 'CASH']
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Value ($)")
            ax = ax0
        else:
            ax = plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        
        record = pickle.load(open(path.join(DIR,"BRZ_TW_NASDAQ-7d_detailed-ModelNo-10000-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
#         plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=300000, color = "grey", linestyle='--')
        plt.xlim((pd.Timestamp('2015-01-01'),pd.Timestamp('2019-12-31')))
        ax.set_xticks([pd.Timestamp('2015-01-01'), pd.Timestamp('2016-01-01'), 
                       pd.Timestamp('2017-01-01'), pd.Timestamp('2018-01-01'),
                       pd.Timestamp('2019-01-01'), pd.Timestamp('2020-01-01')])
        plt.plot(df['date'], df['net_worth'], label="RL Model")
        plt.plot(df['date'], df['buyNhold_balance'], label="Buy N Hold")
        
        for j in range(3):
            plt.plot(df['date'], [tmp[j] for tmp in df['inventory']], label = labels[j])
#             first_price = df['actual_price'][0][j]
#             plt.plot(df['date'], [tmp[j]/first_price*300000 for tmp in df['actual_price']])
        plt.title("Model "+str(i+1))
    except Exception as e:
        print(e)
plt.legend()

# %%
DIR = "./output/303"
axx = plt.figure(figsize=(20,10))
plt.suptitle("Rewards of the Models")
plt.rcParams['figure.facecolor'] = 'white'
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
# legend_list = ['S&P 500', 'Germany Dax', 'Hang Seng', 'CASH']
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Rewards")
            ax = ax0
        else:
            ax = plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        
        record = pickle.load(open(path.join(DIR,"BRZ_TW_NASDAQ-Selected_Trans-7d_detailed-ModelNo-10000-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
#         plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=0, color = "grey", linestyle='--')
        plt.xlim((pd.Timestamp('2015-01-01'),pd.Timestamp('2019-12-31')))
#         plt.ylim(-0.05,0.1)
        ax.set_xticks([pd.Timestamp('2015-01-01'), pd.Timestamp('2016-01-01'), 
                       pd.Timestamp('2017-01-01'), pd.Timestamp('2018-01-01'),
                       pd.Timestamp('2019-01-01'), pd.Timestamp('2020-01-01')])
        plt.plot(df['date'], df['rewards'], label="RL Model")
#         plt.plot(df['date'], df['buyNhold_balance'], label="Buy N Hold")
        
#         for j in range(3):
#             plt.plot(df['date'], [tmp[j] for tmp in df['inventory']/1000000], label = labels[j])
# #             first_price = df['actual_price'][0][j]
# #             plt.plot(df['date'], [tmp[j]/first_price*300000 for tmp in df['actual_price']])
        plt.title("Model "+str(i+1))
    except Exception as e:
        print(e)
plt.legend()

# %%
DIR = "./output/303"
axx = plt.figure(figsize=(20,10))
plt.suptitle("Inventory Value of the Models")
plt.rcParams['figure.facecolor'] = 'white'
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
# legend_list = ['S&P 500', 'Germany Dax', 'Hang Seng', 'CASH']
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Value ($)")
            ax = ax0
        else:
            ax = plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        
        record = pickle.load(open(path.join(DIR,"BRZ_TW_NASDAQ-Selected_Trans-7d_detailed-ModelNo-10000-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
#         plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=300000, color = "grey", linestyle='--')
        plt.xlim((pd.Timestamp('2015-01-01'),pd.Timestamp('2019-12-31')))
        ax.set_xticks([pd.Timestamp('2015-01-01'), pd.Timestamp('2016-01-01'), 
                       pd.Timestamp('2017-01-01'), pd.Timestamp('2018-01-01'),
                       pd.Timestamp('2019-01-01'), pd.Timestamp('2020-01-01')])
        plt.plot(df['date'], df['net_worth'], label="RL Model")
        plt.plot(df['date'], df['buyNhold_balance'], label="Buy N Hold")
        
        for j in range(3):
            plt.plot(df['date'], [tmp[j] for tmp in df['inventory']], label = labels[j])
#             first_price = df['actual_price'][0][j]
#             plt.plot(df['date'], [tmp[j]/first_price*300000 for tmp in df['actual_price']])
        plt.title("Model "+str(i+1))
    except Exception as e:
        print(e)
plt.legend()

# %%
DIR = "./output/303"
axx = plt.figure(figsize=(20,10))
plt.suptitle("Rewards of the Models")
plt.rcParams['figure.facecolor'] = 'white'
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
# legend_list = ['S&P 500', 'Germany Dax', 'Hang Seng', 'CASH']
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Rewards")
            ax = ax0
        else:
            ax = plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        
        record = pickle.load(open(path.join(DIR,"BRZ_TW_NASDAQ-Selected_Trans-7d_detailed-ModelNo-50000-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
#         plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=0, color = "grey", linestyle='--')
        plt.xlim((pd.Timestamp('2015-01-01'),pd.Timestamp('2019-12-31')))
#         plt.ylim(-0.05,0.1)
        ax.set_xticks([pd.Timestamp('2015-01-01'), pd.Timestamp('2016-01-01'), 
                       pd.Timestamp('2017-01-01'), pd.Timestamp('2018-01-01'),
                       pd.Timestamp('2019-01-01'), pd.Timestamp('2020-01-01')])
        plt.plot(df['date'], df['rewards'], label="RL Model")
#         plt.plot(df['date'], df['buyNhold_balance'], label="Buy N Hold")
        
#         for j in range(3):
#             plt.plot(df['date'], [tmp[j] for tmp in df['inventory']/1000000], label = labels[j])
# #             first_price = df['actual_price'][0][j]
# #             plt.plot(df['date'], [tmp[j]/first_price*300000 for tmp in df['actual_price']])
        plt.title("Model "+str(i+1))
    except Exception as e:
        print(e)
plt.legend()

# %%
DIR = "./output/303"
axx = plt.figure(figsize=(20,10))
plt.suptitle("Inventory Value of the Models")
plt.rcParams['figure.facecolor'] = 'white'
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
# legend_list = ['S&P 500', 'Germany Dax', 'Hang Seng', 'CASH']
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Value ($)")
            ax = ax0
        else:
            ax = plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        
        record = pickle.load(open(path.join(DIR,"BRZ_TW_NASDAQ-Selected_Trans-7d_detailed-ModelNo-50000-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
#         plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=300000, color = "grey", linestyle='--')
        plt.xlim((pd.Timestamp('2015-01-01'),pd.Timestamp('2019-12-31')))
        ax.set_xticks([pd.Timestamp('2015-01-01'), pd.Timestamp('2016-01-01'), 
                       pd.Timestamp('2017-01-01'), pd.Timestamp('2018-01-01'),
                       pd.Timestamp('2019-01-01'), pd.Timestamp('2020-01-01')])
        plt.plot(df['date'], df['net_worth'], label="RL Model")
        plt.plot(df['date'], df['buyNhold_balance'], label="Buy N Hold")
        
        for j in range(3):
            plt.plot(df['date'], [tmp[j] for tmp in df['inventory']], label = labels[j])
#             first_price = df['actual_price'][0][j]
#             plt.plot(df['date'], [tmp[j]/first_price*300000 for tmp in df['actual_price']])
        plt.title("Model "+str(i+1))
    except Exception as e:
        print(e)
plt.legend()

# %%
DIR = "./output/303"
axx = plt.figure(figsize=(20,10))
plt.suptitle("Rewards of the Models")
plt.rcParams['figure.facecolor'] = 'white'
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
# legend_list = ['S&P 500', 'Germany Dax', 'Hang Seng', 'CASH']
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Rewards")
            ax = ax0
        else:
            ax = plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        
        record = pickle.load(open(path.join(DIR,"BRZ_TW_NASDAQ-Selected_Trans-7d_detailed-ModelNo-100000-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
#         plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=0, color = "grey", linestyle='--')
        plt.xlim((pd.Timestamp('2015-01-01'),pd.Timestamp('2019-12-31')))
#         plt.ylim(-0.05,0.1)
        ax.set_xticks([pd.Timestamp('2015-01-01'), pd.Timestamp('2016-01-01'), 
                       pd.Timestamp('2017-01-01'), pd.Timestamp('2018-01-01'),
                       pd.Timestamp('2019-01-01'), pd.Timestamp('2020-01-01')])
        plt.plot(df['date'], df['rewards'], label="RL Model")
#         plt.plot(df['date'], df['buyNhold_balance'], label="Buy N Hold")
        
#         for j in range(3):
#             plt.plot(df['date'], [tmp[j] for tmp in df['inventory']/1000000], label = labels[j])
# #             first_price = df['actual_price'][0][j]
# #             plt.plot(df['date'], [tmp[j]/first_price*300000 for tmp in df['actual_price']])
        plt.title("Model "+str(i+1))
    except Exception as e:
        print(e)
plt.legend()
# Out:
# /Users/lzcai/anaconda3/lib/python3.6/site-packages/pandas/plotting/_matplotlib/converter.py:102: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
DIR = "./output/303"
axx = plt.figure(figsize=(20,10))
plt.suptitle("Inventory Value of the Models")
plt.rcParams['figure.facecolor'] = 'white'
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
# legend_list = ['S&P 500', 'Germany Dax', 'Hang Seng', 'CASH']
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Value ($)")
            ax = ax0
        else:
            ax = plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        
        record = pickle.load(open(path.join(DIR,"BRZ_TW_NASDAQ-Selected_Trans-7d_detailed-ModelNo-100000-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
#         plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=300000, color = "grey", linestyle='--')
        plt.xlim((pd.Timestamp('2015-01-01'),pd.Timestamp('2019-12-31')))
        ax.set_xticks([pd.Timestamp('2015-01-01'), pd.Timestamp('2016-01-01'), 
                       pd.Timestamp('2017-01-01'), pd.Timestamp('2018-01-01'),
                       pd.Timestamp('2019-01-01'), pd.Timestamp('2020-01-01')])
        plt.plot(df['date'], df['net_worth'], label="RL Model")
        plt.plot(df['date'], df['buyNhold_balance'], label="Buy N Hold")
        
        for j in range(3):
            plt.plot(df['date'], [tmp[j] for tmp in df['inventory']], label = labels[j])
#             first_price = df['actual_price'][0][j]
#             plt.plot(df['date'], [tmp[j]/first_price*300000 for tmp in df['actual_price']])
        plt.title("Model "+str(i+1))
    except Exception as e:
        print(e)
plt.legend()

# %%
DIR = "./output/304"
axx = plt.figure(figsize=(20,10))
plt.suptitle("Rewards of the Models")
plt.rcParams['figure.facecolor'] = 'white'
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
# legend_list = ['S&P 500', 'Germany Dax', 'Hang Seng', 'CASH']
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Rewards")
            ax = ax0
        else:
            ax = plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        
        record = pickle.load(open(path.join(DIR,"BRZ_TW_NASDAQ-Selected_Trans-7d_detailed-ModelNo-10000-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
#         plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=0, color = "grey", linestyle='--')
        plt.xlim((pd.Timestamp('2015-01-01'),pd.Timestamp('2019-12-31')))
#         plt.ylim(-0.05,0.1)
        ax.set_xticks([pd.Timestamp('2015-01-01'), pd.Timestamp('2016-01-01'), 
                       pd.Timestamp('2017-01-01'), pd.Timestamp('2018-01-01'),
                       pd.Timestamp('2019-01-01'), pd.Timestamp('2020-01-01')])
        plt.plot(df['date'], df['rewards'], label="RL Model")
#         plt.plot(df['date'], df['buyNhold_balance'], label="Buy N Hold")
        
#         for j in range(3):
#             plt.plot(df['date'], [tmp[j] for tmp in df['inventory']/1000000], label = labels[j])
# #             first_price = df['actual_price'][0][j]
# #             plt.plot(df['date'], [tmp[j]/first_price*300000 for tmp in df['actual_price']])
        plt.title("Model "+str(i+1))
    except Exception as e:
        print(e)
plt.legend()

# %%
DIR = "./output/304"
axx = plt.figure(figsize=(20,10))
plt.suptitle("Inventory Value of the Models")
plt.rcParams['figure.facecolor'] = 'white'
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
# legend_list = ['S&P 500', 'Germany Dax', 'Hang Seng', 'CASH']
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Value ($)")
            ax = ax0
        else:
            ax = plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        
        record = pickle.load(open(path.join(DIR,"BRZ_TW_NASDAQ-Selected_Trans-7d_detailed-ModelNo-10000-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
#         plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=300000, color = "grey", linestyle='--')
        plt.xlim((pd.Timestamp('2015-01-01'),pd.Timestamp('2019-12-31')))
        ax.set_xticks([pd.Timestamp('2015-01-01'), pd.Timestamp('2016-01-01'), 
                       pd.Timestamp('2017-01-01'), pd.Timestamp('2018-01-01'),
                       pd.Timestamp('2019-01-01'), pd.Timestamp('2020-01-01')])
        plt.plot(df['date'], df['net_worth'], label="RL Model")
        plt.plot(df['date'], df['buyNhold_balance'], label="Buy N Hold")
        
        for j in range(3):
            plt.plot(df['date'], [tmp[j] for tmp in df['inventory']], label = labels[j])
#             first_price = df['actual_price'][0][j]
#             plt.plot(df['date'], [tmp[j]/first_price*300000 for tmp in df['actual_price']])
        plt.title("Model "+str(i+1))
    except Exception as e:
        print(e)
plt.legend()

# %%
DIR = "./output/304"
axx = plt.figure(figsize=(20,10))
plt.suptitle("Rewards of the Models")
plt.rcParams['figure.facecolor'] = 'white'
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
# legend_list = ['S&P 500', 'Germany Dax', 'Hang Seng', 'CASH']
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Rewards")
            ax = ax0
        else:
            ax = plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        
        record = pickle.load(open(path.join(DIR,"BRZ_TW_NASDAQ-Selected_Trans-withleakage_detailed-ModelNo-50000-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
#         plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=0, color = "grey", linestyle='--')
        plt.xlim((pd.Timestamp('2015-01-01'),pd.Timestamp('2019-12-31')))
#         plt.ylim(-0.05,0.1)
        ax.set_xticks([pd.Timestamp('2015-01-01'), pd.Timestamp('2016-01-01'), 
                       pd.Timestamp('2017-01-01'), pd.Timestamp('2018-01-01'),
                       pd.Timestamp('2019-01-01'), pd.Timestamp('2020-01-01')])
        plt.plot(df['date'], df['rewards'], label="RL Model")
#         plt.plot(df['date'], df['buyNhold_balance'], label="Buy N Hold")
        
#         for j in range(3):
#             plt.plot(df['date'], [tmp[j] for tmp in df['inventory']/1000000], label = labels[j])
# #             first_price = df['actual_price'][0][j]
# #             plt.plot(df['date'], [tmp[j]/first_price*300000 for tmp in df['actual_price']])
        plt.title("Model "+str(i+1))
    except Exception as e:
        print(e)
plt.legend()

# %%
DIR = "./output/304"
axx = plt.figure(figsize=(20,10))
plt.suptitle("Inventory Value of the Models")
plt.rcParams['figure.facecolor'] = 'white'
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
# legend_list = ['S&P 500', 'Germany Dax', 'Hang Seng', 'CASH']
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Value ($)")
            ax = ax0
        else:
            ax = plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        
        record = pickle.load(open(path.join(DIR,"BRZ_TW_NASDAQ-Selected_Trans-withleakage_detailed-ModelNo-50000-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
#         plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=300000, color = "grey", linestyle='--')
        plt.xlim((pd.Timestamp('2015-01-01'),pd.Timestamp('2019-12-31')))
        ax.set_xticks([pd.Timestamp('2015-01-01'), pd.Timestamp('2016-01-01'), 
                       pd.Timestamp('2017-01-01'), pd.Timestamp('2018-01-01'),
                       pd.Timestamp('2019-01-01'), pd.Timestamp('2020-01-01')])
        plt.plot(df['date'], df['net_worth'], label="RL Model")
        plt.plot(df['date'], df['buyNhold_balance'], label="Buy N Hold")
        
        for j in range(3):
            plt.plot(df['date'], [tmp[j] for tmp in df['inventory']], label = labels[j])
#             first_price = df['actual_price'][0][j]
#             plt.plot(df['date'], [tmp[j]/first_price*300000 for tmp in df['actual_price']])
        plt.title("Model "+str(i+1))
    except Exception as e:
        print(e)
plt.legend()

# %%
# plt.plot(df['rewards'], label="Rewards")
plt.plot(df['buyNhold_balance']/df['buyNhold_balance'][0], label="buyNhold_balance")
# plt.plot(df['actual_profit']/df['actual_profit'][0], label="Actual Profit")
# plt.scatter(range(len(df['action'])), [np.argmax(tmp)-3 for tmp in df['action']])
plt.legend()
plt.show()

# %%
import pickle

tmp = pickle.load(open("../../0306-currency adjusted rebalance record.out", "rb"))
nominal_price_result = tmp[0][3] # Six Months
actual_price_result = tmp[1][3]
price_df_list = pickle.load(open("../../0306-adjusted market prices.out", "rb"))

# %%
price_df_list[0]
# Out:
#            Date      Open      High       Low     Price        Vol    Change  \
# 0    2015-01-05   48512.0   48512.0   47264.0   47517.0  3866100.0 -0.020510
# 1    2015-01-06   47517.0   48061.0   47338.0   48001.0  4559300.0  0.010186
# 2    2015-01-07   48006.0   49882.0   48006.0   49463.0  4408800.0  0.030458
# 3    2015-01-08   49463.0   50261.0   49017.0   49943.0  3621900.0  0.009704
# 4    2015-01-09   49955.0   49955.0   48501.0   48840.0  2999200.0 -0.022085
# ...         ...       ...       ...       ...       ...        ...       ...
# 1132 2019-12-20  115133.0  115171.0  114526.0  115121.0  6887400.0 -0.000087
# 1133 2019-12-23  115119.0  115863.0  114964.0  115863.0  3995200.0  0.006445
# 1134 2019-12-26  115864.0  117220.0  115673.0  117203.0  3788900.0  0.011565
# 1135 2019-12-27  117205.0  117803.0  115995.0  116534.0  3905900.0 -0.005708
# 1136 2019-12-30  116530.0  117086.0  115790.0  115964.0  3667900.0 -0.004891
#
#       FX Change  Cum FX Change  Actual Price
# 0       -0.0046       0.995400  47298.421800
# 1        0.0024       0.997789  47894.867869
# 2        0.0062       1.003975  49659.627868
# 3        0.0075       1.011505  50517.597508
# 4        0.0125       1.024149  50019.431263
# ...         ...            ...           ...
# 1132    -0.0081       0.833756  95982.878403
# 1133     0.0049       0.837842  97074.873178
# 1134     0.0065       0.843288  98835.865569
# 1135     0.0028       0.845649  98546.866776
# 1136     0.0065       0.851146  98702.268320
#
# [1137 rows x 10 columns]

# %%
plt.plot(df['rewards']/df['rewards'][0], label="Rewards")
plt.plot(df['net_worth']/df['net_worth'][0], label="Net Worth")
# plt.plot(df['actual_profit']/df['actual_profit'][0], label="Actual Profit")

plt.legend()
plt.show()
