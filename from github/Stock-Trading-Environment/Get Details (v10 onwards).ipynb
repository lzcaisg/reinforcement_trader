# %%
import pickle
from os import path

# %%
DIR = "./output/10"
pickle.load(open(path.join(DIR,"sp500_actual_10k-Training_detailed-ModelNo-0.out"), "rb"))
# Out:
# [{'step': 6,
#   'date': Timestamp('2015-01-09 00:00:00'),
#   'actual_price': 2048.829450269485,
#   'action': 0.45955572,
#   'shares_held': 1,
#   'net_worth': 9983.609364397844,
#   'net_worth_delta': -16.39063560215618,
#   'buyNhold_balance': 9915.961889594268,
#   'actual_profit': 67.64747480357619,
#   'testNo': 1},
#  {'step': 7,
#   'date': Timestamp('2015-01-12 00:00:00'),
#   'actual_price': 2036.0541166649984,
#   'action': 1.0,
#   'shares_held': 4,
#   'net_worth': 9921.968731993398,
#   'net_worth_delta': -61.64063240444557,
#   'buyNhold_balance': 9835.70521517475,
#   'actual_profit': 86.26351681864799,
#   'testNo': 2},
#  {'step': 8,
#   'date': Timestamp('2015-01-13 00:00:00'),
#   'actual_price': 2038.718755709726,
#   'action': 0.1374012,
#   'shares_held': 4,
#   'net_worth': 9932.627288172309,
#   'net_worth_delta': 10.658556178910658,
#   'buyNhold_balance': 9810.343303416224,
#   'actual_profit': 122.28398475608446,
#   'testNo': 3},
#  {'step': 16,
# ...
