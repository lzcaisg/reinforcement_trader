# %%
import pickle
from os import path

# %%
DIR = "./output/10"
pickle.load(open(path.join(DIR,"sp500_actual_10k-Training_detailed-ModelNo-0.out"), "rb"))
# Out:
# [{'step': 5,
#   'date': Timestamp('2015-01-08 00:00:00'),
#   'actual_price': 2048.322904241778,
#   'action': 4.882042757658697,
#   'shares_held': 4.882042757658697,
#   'net_worth': 9920.0,
#   'net_worth_delta': -80.0,
#   'buyNhold_balance': 10000.0,
#   'actual_profit': -80.0,
#   'testNo': 0},
#  {'step': 6,
#   'date': Timestamp('2015-01-09 00:00:00'),
#   'actual_price': 2051.7722081508073,
#   'action': -4.882042757658697,
#   'shares_held': 0.0,
#   'net_worth': 9856.704931974697,
#   'net_worth_delta': -63.29506802530341,
#   'buyNhold_balance': 9915.961889594268,
#   'actual_profit': -59.25695761957104,
#   'testNo': 1},
#  {'step': 7,
#   'date': Timestamp('2015-01-12 00:00:00'),
#   'actual_price': 2043.3935385938203,
#   'action': 2.287234254053515,
#   'shares_held': 2.287234254053515,
#   'net_worth': 9819.31517440683,
#   'net_worth_delta': -37.38975756786749,
#   'buyNhold_balance': 9835.70521517475,
#   'actual_profit': -16.390040767921164,
#   'testNo': 2},
# ...
