# %%
import pickle
from os import path
import pandas as pd
import matplotlib.pyplot as plt
from pprint import pprint

# %%
DIR = "./output/201"
record = pickle.load(open(path.join(DIR,"BRZ+TW+NASDAQ-Training_detailed-ModelNo-50000-9.out"), "rb"))
df = pd.DataFrame(record)
# df
# for i in range(3):
#     plt.plot([tmp[i] for tmp in df['inventory']])
plt.plot(df['net_worth'])
plt.plot(df['buyNhold_balance'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-35-c5f26c9bc85f> in <module>
#       1 DIR = "./output/201"
# ----> 2 record = pickle.load(open(path.join(DIR,"BRZ+TW+NASDAQ-Training_detailed-ModelNo-50000-9.out"), "rb"))
#       3 df = pd.DataFrame(record)
#       4 # df
#       5 # for i in range(3):
#
# FileNotFoundError: [Errno 2] No such file or directory: './output/201\\BRZ+TW+NASDAQ-Training_detailed-ModelNo-50000-9.out'

# %%
df
# Out:
#            date                                       actual_price  \
# 0    2015-01-13  [48140.93904018113, 9183.629163132122, 4635.57...
# 1    2015-01-14  [47447.72674859392, 9176.348569359105, 4648.40...
# 2    2015-01-15  [48197.6257325863, 9211.69660038877, 4614.4528...
# 3    2015-01-16  [48875.34810036001, 9189.985683087321, 4593.72...
# 4    2015-01-20  [48668.68448574729, 9197.652118703361, 4639.94...
# ...         ...                                                ...
# 1114 2019-12-04  [110150.26813416084, 11496.789483866154, 8564....
# 1115 2019-12-05  [110055.71560655048, 11561.682931198138, 8542....
# 1116 2019-12-06  [110959.86722806598, 11638.863211016756, 8650....
# 1117 2019-12-09  [111064.16923691705, 11651.955147404495, 8626....
# 1118 2019-12-10  [110564.21115482115, 11608.395326846456, 8601....
#
#                            action  \
# 0            [1.0, 0.0, 1.0, 0.0]
# 1     [1.0, 0.0, 0.27097893, 0.0]
# 2      [1.0, 0.0, 0.0, 0.4823597]
# 3            [1.0, 0.0, 1.0, 0.0]
# 4            [1.0, 0.0, 1.0, 0.0]
# ...                           ...
# 1114  [0.0, 0.93405867, 0.0, 1.0]
# 1115  [0.0, 0.0, 0.71763134, 0.0]
# 1116  [1.0, 0.0, 0.19057965, 0.0]
# 1117         [1.0, 0.0, 1.0, 0.0]
# 1118    [1.0, 0.0, 0.695409, 0.0]
#
#                                               inventory  \
# 0     [238955.1836970531, 29912.838534004502, 29912....
# 1     [236317.23181677205, 29539.90535997809, 29539....
# 2     [239224.01058983436, 29902.37844857491, 29901....
# 3     [241749.58544197015, 30217.73179405514, 30217....
# 4     [241192.37660371306, 30149.192661074354, 30149...
# ...                                                 ...
# 1114  [37117.02332318465, 37117.02332318465, 296287....
# 1115  [166138.66139679405, 166139.26443853482, 36991...
# 1116  [297442.9225636419, 37221.04763569665, 37221.0...
# 1117  [297683.5022158728, 37210.4377769841, 37210.20...
# 1118  [296415.5067431613, 37051.960895833836, 37051....
#
#                                             shares_held      net_worth  \
# 0     [4.96365855052407, 3.257191465666998, 6.452885...  298780.860765
# 1     [4.980580693969182, 3.219135055376522, 6.35484...  295397.042537
# 2     [4.963398237023439, 3.2461314940955512, 6.4799...  299027.944147
# 3     [4.946247849643233, 3.2881152197729726, 6.5780...  302184.887534
# 4     [4.955802260781194, 3.2779226993991415, 6.4977...  301490.761926
# ...                                                 ...            ...
# 1114  [0.33696716269430094, 3.2284685542230953, 34.5...  370521.360144
# 1115  [1.5095868531784415, 14.369816697725147, 4.330...  369269.459412
# 1116  [2.6806351701221867, 3.197996828458736, 4.3029...  371885.017835
# 1117  [2.6802838778802536, 3.193493049556823, 4.3135...  372104.149178
# 1118  [2.6809353917254093, 3.1918245246304338, 4.307...  370519.428535
#
#       net_worth_delta  buyNhold_balance  buyNhold_delta  actual_profit  \
# 0        -1219.139235     300000.000000        0.000000   -1219.139235
# 1        -3383.818228     298141.297453    -1858.702547   -2744.254916
# 2         3630.901610     297298.782211     -842.515242    1729.161937
# 3         3156.943387     300434.771593     3135.989383    1750.115941
# 4         -694.125608     299729.353192     -705.418402    1761.408734
# ...               ...               ...             ...            ...
# 1114       166.792281     538051.116441     3456.425049 -167529.756296
# 1115     -1251.900733     539717.599276     1666.482835 -170448.139864
# 1116      2615.558424     542770.301909     3052.702633 -170885.284074
# 1117       219.131343     542269.604138     -500.697772 -170165.454959
# 1118     -1584.720643     541156.829215    -1112.774923 -170637.400680
#
#          progress  testNo
# 0    -1218.139235       0
# 1        1.820969       1
# 2       -4.315907       2
# 3        1.006680       3
# 4        0.983969       4
# ...           ...     ...
# 1114     0.048531    1114
# 1115    -0.750173    1115
# 1116     0.856848    1116
# 1117    -0.440529    1117
# 1118     1.424498    1118
#
# [1119 rows x 12 columns]

# %%
DIR = "./output/200"
axx = plt.figure(figsize=(20,10))
plt.suptitle("Inventory Value of the Models")
plt.rcParams['figure.facecolor'] = 'white'
# legend_list = ['S&P 500', 'Germany Dax', 'Hang Seng', 'CASH']
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Value ($)")
            ax = ax0
        else:
            ax = plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        
        record = pickle.load(open(path.join(DIR,"BRZ+TW+NASDAQ-Training_detailed-ModelNo-10000-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
#         plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=300000, color = "grey", linestyle='--')
        plt.xlim((pd.Timestamp('2015-01-01'),pd.Timestamp('2019-12-31')))
        ax.set_xticks([pd.Timestamp('2015-01-01'), pd.Timestamp('2016-01-01'), 
                       pd.Timestamp('2017-01-01'), pd.Timestamp('2018-01-01'),
                       pd.Timestamp('2019-01-01'), pd.Timestamp('2020-01-01')])
        plt.plot(df['date'], df['net_worth'])
        plt.plot(df['date'], df['buyNhold_balance'])
#         for j in range(3):
#             first_price = df['actual_price'][0][j]
#             plt.plot(df['date'], [tmp[j]/first_price*300000 for tmp in df['actual_price']])
        plt.title("Model "+str(i+1))
    except Exception as e:
        print(e)
# axx.legend(['Initialized Value','S&P 500', 'Germany DAX', 'Hang Seng', 'CASH'])

# %%
DIR = "./output/201"
axx = plt.figure(figsize=(20,10))
plt.suptitle("Inventory Value of the Models")
plt.rcParams['figure.facecolor'] = 'white'
# legend_list = ['S&P 500', 'Germany Dax', 'Hang Seng', 'CASH']
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Value ($)")
            ax = ax0
        else:
            ax = plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        
        record = pickle.load(open(path.join(DIR,"BRZ+TW+NASDAQ-Training_detailed-ModelNo-50000-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
#         plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=300000, color = "grey", linestyle='--')
        plt.xlim((pd.Timestamp('2015-01-01'),pd.Timestamp('2019-12-31')))
        ax.set_xticks([pd.Timestamp('2015-01-01'), pd.Timestamp('2016-01-01'), 
                       pd.Timestamp('2017-01-01'), pd.Timestamp('2018-01-01'),
                       pd.Timestamp('2019-01-01'), pd.Timestamp('2020-01-01')])
        plt.plot(df['date'], df['net_worth'])
        plt.plot(df['date'], df['buyNhold_balance'])
#         for j in range(4):
#             plt.plot(df['date'], [tmp[j] for tmp in df['inventory']])
        plt.title("Model "+str(i+1))
    except Exception as e:
        print(e)
# axx.legend(['Initialized Value','S&P 500', 'Germany DAX', 'Hang Seng', 'CASH'])

# %%
DIR = "./output/201"
axx = plt.figure(figsize=(20,10))
plt.suptitle("Inventory Value of the Models")
plt.rcParams['figure.facecolor'] = 'white'
# legend_list = ['S&P 500', 'Germany Dax', 'Hang Seng', 'CASH']
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Value ($)")
            ax = ax0
        else:
            ax = plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        
        record = pickle.load(open(path.join(DIR,"BRZ+TW+NASDAQ-Training_detailed-ModelNo-100000-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
#         plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=300000, color = "grey", linestyle='--')
        plt.xlim((pd.Timestamp('2015-01-01'),pd.Timestamp('2019-12-31')))
        ax.set_xticks([pd.Timestamp('2015-01-01'), pd.Timestamp('2016-01-01'), 
                       pd.Timestamp('2017-01-01'), pd.Timestamp('2018-01-01'),
                       pd.Timestamp('2019-01-01'), pd.Timestamp('2020-01-01')])
        plt.plot(df['date'], df['net_worth'])
        plt.plot(df['date'], df['buyNhold_balance'])
#         for j in range(4):
#             plt.plot(df['date'], [tmp[j] for tmp in df['inventory']])
        plt.title("Model "+str(i+1))
    except Exception as e:
        print(e)
# axx.legend(['Initialized Value','S&P 500', 'Germany DAX', 'Hang Seng', 'CASH'])

# %%
plt.xlim(pd.Timestamp(2015, 1, 1), pd.Timestamp(2019, 12, 31))
plt.axhline(y=0, color = "grey", linestyle='--')
# plt.axhline(y=10000, color = "grey", linestyle='--')
plt.plot(df['date'], df['actual_profit']/df['buyNhold_balance']*100, color = "green")
# plt.plot(df['date'], df['net_worth'], color = 'orange')

# %%
plt.xlim(pd.Timestamp(2015, 1, 1), pd.Timestamp(2019, 12, 31))
plt.axhline(y=0, color = "grey", linestyle='--')
# plt.axhline(y=10000, color = "grey", linestyle='--')
plt.plot(df['date'], df['progress'], color = "green")
# plt.plot(df['date'], df['net_worth'], color = 'orange')

# %%
DIR = "./output/15/5"
plt.figure(figsize=(20,10))
plt.suptitle("Transactions of the Models")
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Value ($)")
        else:
            plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        record = pickle.load(open(path.join(DIR,"sp500_deltaReward_5k-Training_detailed-ModelNo-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
        plt.scatter(df['date'], df['action']*df['actual_price'])
        plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=10000, color = "grey", linestyle='--')
        plt.plot(df['date'], df['actual_profit'], color = "green")
        plt.plot(df['date'], df['net_worth'], color = 'orange')
    except Exception as e:
        print(e)

# %%
DIR = "./output/15/10"
plt.figure(figsize=(20,10))
plt.suptitle("Transactions of the Models")
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Value ($)")
        else:
            plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        record = pickle.load(open(path.join(DIR,"sp500_deltaReward_10k-Training_detailed-ModelNo-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
        plt.scatter(df['date'], df['action']*df['actual_price'])
        plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=10000, color = "grey", linestyle='--')
        plt.plot(df['date'], df['actual_profit'], color = "green")
        plt.plot(df['date'], df['net_worth'], color = 'orange')
    except Exception as e:
        print(e)
