# %%
import pickle
from os import path
import pandas as pd
import matplotlib.pyplot as plt
from pprint import pprint

# %%
DIR = "./output/201"
record = pickle.load(open(path.join(DIR,"BRZ+TW+NASDAQ-Training_detailed-ModelNo-50000-0.out"), "rb"))
df = pd.DataFrame(record)
# df
# for i in range(3):
#     plt.plot([tmp[i] for tmp in df['inventory']])
plt.plot(df['net_worth'])
plt.plot(df['buyNhold_balance'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-a9bc346d5f2d> in <module>
#       1 DIR = "./output/201"
# ----> 2 record = pickle.load(open(path.join(DIR,"sp500+dax+hk-Training_detailed-ModelNo-50000-0.out"), "rb"))
#       3 df = pd.DataFrame(record)
#       4 # df
#       5 # for i in range(3):
#
# FileNotFoundError: [Errno 2] No such file or directory: './output/201\\sp500+dax+hk-Training_detailed-ModelNo-50000-0.out'

# %%
df
# Out:
#            date                                       actual_price  \
# 0    2015-01-13  [48701.77787641746, 9178.866132871124, 4654.39...
# 1    2015-01-14  [48137.82568102878, 9186.845947724256, 4622.28...
# 2    2015-01-15  [47698.455782572855, 9179.458415598441, 4569.1...
# 3    2015-01-16  [48418.215487483576, 9186.013342792676, 4584.0...
# 4    2015-01-20  [47675.51853630446, 9241.791296316806, 4612.11...
# ...         ...                                                ...
# 1114 2019-12-04  [109412.02563468111, 11502.749915489216, 8572....
# 1115 2019-12-05  [110113.88435258839, 11585.49965242156, 8554.6...
# 1116 2019-12-06  [110749.8830588653, 11597.078843786121, 8637.0...
# 1117 2019-12-09  [111316.23500992365, 11672.549678543464, 8670....
# 1118 2019-12-10  [110731.49868169478, 11633.022048439856, 8601....
#
#                                         action  \
# 0                  [0.0, 1.0, 0.0, 0.26736876]
# 1                  [1.0, 0.30337185, 1.0, 1.0]
# 2                         [0.0, 0.0, 0.0, 0.0]
# 3            [0.0, 0.0, 0.6425587, 0.26030737]
# 4           [0.0, 0.0, 0.06371878, 0.83226043]
# ...                                        ...
# 1114                [1.0, 0.8085549, 0.0, 0.0]
# 1115   [0.25550467, 1.0, 0.289145, 0.05530247]
# 1116         [0.6586077, 0.0, 0.26000103, 0.0]
# 1117  [0.0, 0.7005906, 0.66708136, 0.14538018]
# 1118               [1.0, 1.0, 0.0, 0.32258752]
#
#                                               inventory  \
# 0     [30064.793741709167, 240165.84197415216, 30064...
# 1     [239433.64008871999, 29994.864655939044, 29994...
# 2     [237494.6155216353, 29686.904074071197, 29686....
# 3     [135256.28670278442, 134992.58116279193, 30056...
# 4     [29923.432617312006, 29923.43261731202, 238864...
# ...                                                 ...
# 1114  [146215.84855540254, 18316.96939050772, 18316....
# 1115  [18388.115258556318, 146783.48263857057, 18387...
# 1116  [146869.88261499957, 18398.928035240067, 18398...
# 1117  [18461.068482608593, 147365.82497809007, 18461...
# 1118  [146514.65553544986, 18354.45420603856, 18354....
#
#                                             shares_held      net_worth  \
# 0     [0.617324357603529, 26.165088203441197, 6.4594...  300295.429458
# 1     [4.97391888190499, 3.264979605254979, 6.489113...  299423.025853
# 2     [4.979083947795361, 3.234058343096247, 6.49715...  296868.331583
# 3     [2.7935000359058884, 14.695447973489696, 6.556...  300305.136171
# 4     [0.6276477642193989, 3.23783903551659, 51.7908...  298711.785564
# ...                                                 ...            ...
# 1114  [1.3363782244888396, 1.5923991675975415, 2.136...  182849.787336
# 1115  [0.16699179550942866, 12.669585865283798, 2.14...  183559.439577
# 1116  [1.3261402952176113, 1.5865140078010658, 2.130...  183667.738685
# 1117  [0.16584345024751168, 12.624990172368134, 2.12...  184287.961943
# 1118  [1.3231524659177258, 1.5777889983884403, 2.133...  183223.462024
#
#       net_worth_delta  buyNhold_balance  buyNhold_delta  actual_profit  \
# 0          295.429458     300000.000000        0.000000     295.429458
# 1         -872.403604     298141.297453    -1858.702547    1281.728401
# 2        -2554.694270     297298.782211     -842.515242    -430.450627
# 3         3436.804588     300434.771593     3135.989383    -129.635422
# 4        -1593.350608     299729.353192     -705.418402   -1017.567628
# ...               ...               ...             ...            ...
# 1114       -72.894277     538051.116441     3456.425049 -355201.329104
# 1115       709.652241     539717.599276     1666.482835 -356158.159699
# 1116       108.299109     542770.301909     3052.702633 -359102.563224
# 1117       620.223258     542269.604138     -500.697772 -357981.642194
# 1118     -1064.499919     541156.829215    -1112.774923 -357933.367191
#
#         progress  testNo
# 0     296.429458       0
# 1       0.469076       1
# 2       3.034638       2
# 3       1.095893       3
# 4       2.260518       4
# ...          ...     ...
# 1114   -0.020794    1114
# 1115    0.426183    1115
# 1116    0.035792    1116
# 1117   -1.243198    1117
# 1118    0.956578    1118
#
# [1119 rows x 12 columns]

# %%
DIR = "./output/200"
axx = plt.figure(figsize=(20,10))
plt.suptitle("Inventory Value of the Models")
plt.rcParams['figure.facecolor'] = 'white'
# legend_list = ['S&P 500', 'Germany Dax', 'Hang Seng', 'CASH']
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Value ($)")
            ax = ax0
        else:
            ax = plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        
        record = pickle.load(open(path.join(DIR,"sp500+dax+hk-Training_detailed-ModelNo-10000-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
#         plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=300000, color = "grey", linestyle='--')
        plt.xlim((pd.Timestamp('2015-01-01'),pd.Timestamp('2019-12-31')))
        ax.set_xticks([pd.Timestamp('2015-01-01'), pd.Timestamp('2016-01-01'), 
                       pd.Timestamp('2017-01-01'), pd.Timestamp('2018-01-01'),
                       pd.Timestamp('2019-01-01'), pd.Timestamp('2020-01-01')])
        plt.plot(df['date'], df['net_worth'])
        plt.plot(df['date'], df['buyNhold_balance'])
#         for j in range(4):
#             plt.plot(df['date'], [tmp[j] for tmp in df['inventory']])
        plt.title("Model "+str(i+1))
    except Exception as e:
        print(e)
# axx.legend(['Initialized Value','S&P 500', 'Germany DAX', 'Hang Seng', 'CASH'])

# %%
plt.xlim(pd.Timestamp(2015, 1, 1), pd.Timestamp(2019, 12, 31))
plt.axhline(y=0, color = "grey", linestyle='--')
# plt.axhline(y=10000, color = "grey", linestyle='--')
plt.plot(df['date'], df['actual_profit']/df['buyNhold_balance']*100, color = "green")
# plt.plot(df['date'], df['net_worth'], color = 'orange')

# %%
plt.xlim(pd.Timestamp(2015, 1, 1), pd.Timestamp(2019, 12, 31))
plt.axhline(y=0, color = "grey", linestyle='--')
# plt.axhline(y=10000, color = "grey", linestyle='--')
plt.plot(df['date'], df['progress'], color = "green")
# plt.plot(df['date'], df['net_worth'], color = 'orange')

# %%
DIR = "./output/15/5"
plt.figure(figsize=(20,10))
plt.suptitle("Transactions of the Models")
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Value ($)")
        else:
            plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        record = pickle.load(open(path.join(DIR,"sp500_deltaReward_5k-Training_detailed-ModelNo-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
        plt.scatter(df['date'], df['action']*df['actual_price'])
        plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=10000, color = "grey", linestyle='--')
        plt.plot(df['date'], df['actual_profit'], color = "green")
        plt.plot(df['date'], df['net_worth'], color = 'orange')
    except Exception as e:
        print(e)

# %%
DIR = "./output/15/10"
plt.figure(figsize=(20,10))
plt.suptitle("Transactions of the Models")
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Value ($)")
        else:
            plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        record = pickle.load(open(path.join(DIR,"sp500_deltaReward_10k-Training_detailed-ModelNo-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
        plt.scatter(df['date'], df['action']*df['actual_price'])
        plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=10000, color = "grey", linestyle='--')
        plt.plot(df['date'], df['actual_profit'], color = "green")
        plt.plot(df['date'], df['net_worth'], color = 'orange')
    except Exception as e:
        print(e)
