# %%
import pickle
from os import path
import pandas as pd
import matplotlib.pyplot as plt

# %%
DIR = "./output/12"
record = pickle.load(open(path.join(DIR,"sp500_FilteredSmall_10k-Training_detailed-ModelNo-0.out"), "rb"))
df = pd.DataFrame(record)
df
# Out:
#      step       date  actual_price    action  shares_held    net_worth  \
# 0       5 2015-01-08   2049.606543  4.840263     4.840263  9920.634921
# 1      11 2015-01-16   1988.237542 -4.840263     0.000000  9623.592811
# 2      12 2015-01-20   2020.189337  4.725901     4.725901  9547.215091
# 3      23 2015-02-04   2045.607739 -0.743655     3.982247  9667.339942
# 4      25 2015-02-06   2067.683843  0.729876     4.712122  9743.179216
# ..    ...        ...           ...       ...          ...          ...
# 324  1241 2019-12-05   3119.434496 -0.807720     0.303965  5756.492189
# 325  1242 2019-12-06   3150.246094  1.514209     1.818174  5727.696775
# 326  1252 2019-12-20   3225.621248 -1.818174     0.000000  5864.741950
# 327  1253 2019-12-23   3226.617835  1.803187     1.803187  5818.196379
# 328  1255 2019-12-26   3230.148340 -1.803187     0.000000  5824.562542
#
#      net_worth_delta  buyNhold_balance  actual_profit  testNo
# ...

# %%
plt.scatter(df['date'], df['action'])

# %%
plt.scatter(df['date'], df['action'])

# %%
plt.scatter(df['date'], df['action'])

# %%
plt.scatter(df['date'], df['action'])

# %%
plt.scatter(df['date'], df['action'])

# %%
DIR = "./output/12"
plt.figure(figsize=(20,10))
plt.suptitle("Transactions of the Models")
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Value ($)")
        else:
            plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        record = pickle.load(open(path.join(DIR,"sp500_FilteredSmall_10k-Training_detailed-ModelNo-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
        plt.scatter(df['date'], df['action']*df['actual_price'])
        plt.axhline(y=0, color = "red")
        plt.axhline(y=10000, color = "red")
        plt.plot(df['date'], df['actual_profit'], color = "green")
        plt.plot(df['date'], df['net_worth'], color = 'orange')
    except Exception as e:
        print(e)
