# %%
import pickle
from os import path

# %%
DIR = "./output/10"
pickle.load(open(path.join(DIR,"sp500_actual_10k-Training_detailed-ModelNo-0.out"), "rb"))
# Out:
# [{'step': 5,
#   'date': Timestamp('2015-01-08 00:00:00'),
#   'actual_price': 2035.464118942609,
#   'action': 4,
#   'shares_held': 4,
#   'net_worth': 9934.865148193836,
#   'net_worth_delta': -65.13485180616408,
#   'buyNhold_balance': 10000.0,
#   'actual_profit': -65.13485180616408,
#   'testNo': 0},
#  {'step': 32,
#   'date': Timestamp('2015-02-18 00:00:00'),
#   'actual_price': 2095.6812421824184,
#   'action': -4,
#   'shares_held': 0,
#   'net_worth': 10175.733641153074,
#   'net_worth_delta': 20.47935396587127,
#   'buyNhold_balance': 10182.044094716517,
#   'actual_profit': -6.310453563442934,
#   'testNo': 27},
#  {'step': 34,
#   'date': Timestamp('2015-02-20 00:00:00'),
#   'actual_price': 2094.485922592195,
#   'action': 4,
#   'shares_held': 4,
#   'net_worth': 10108.710091630124,
#   'net_worth_delta': -67.0235495229499,
#   'buyNhold_balance': 10233.544562924568,
#   'actual_profit': -124.83447129444357,
#   'testNo': 29},
#  {'step': 51,
# ...
