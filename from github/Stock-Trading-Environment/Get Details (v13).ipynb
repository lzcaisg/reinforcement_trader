# %%
import pickle
from os import path
import pandas as pd
import matplotlib.pyplot as plt

# %%
DIR = "./output/14"
record = pickle.load(open(path.join(DIR,"sp500_Cashout_10k-Training_detailed-ModelNo-5.out"), "rb"))
df = pd.DataFrame(record)
df
# Out:
#      step       date  actual_price    action  shares_held     net_worth  \
# 0       7 2015-01-12   2037.011166  4.870192     4.870192   9920.634921
# 1      18 2015-01-28   2021.075905 -1.919126     2.951066   9843.027146
# 2      22 2015-02-03   2025.435218  0.659836     3.610901   9845.200130
# 3      24 2015-02-05   2053.588802  0.600669     4.211571   9936.991718
# 4      25 2015-02-06   2065.719505  0.618639     4.830209   9977.857563
# ..    ...        ...           ...       ...          ...           ...
# 215  1243 2019-12-09   3139.489182  2.500889     3.196087  10034.079687
# 216  1251 2019-12-19   3204.693079 -0.370726     2.825361  10242.476996
# 217  1252 2019-12-20   3220.446504  0.230548     3.055909  10281.046359
# 218  1253 2019-12-23   3225.651175  0.099534     3.155444  10294.382857
# 219  1257 2019-12-30   3224.670904 -3.155444     0.000000  10291.289665
#
#      net_worth_delta  buyNhold_balance  actual_profit  testNo
# 0         -79.365079       9835.705215      84.929705       2
# 1         -13.259297       9709.137779     133.889367      13
# 2          35.673939       9941.275255     -96.075125      17
# 3          26.514430      10001.843362     -64.851643      19
# 4          40.865845       9967.655337      10.202226      20
# ..               ...               ...            ...     ...
# 215       -67.594505      15207.309512   -5173.229825    1238
# 216        42.121980      15543.902370   -5301.425374    1246
# 217        38.569363      15620.763567   -5339.717208    1247
# 218        13.336498      15634.293391   -5339.910534    1248
# 219       -67.864336      15621.103350   -5329.813684    1252
#
# [220 rows x 10 columns]

# %%
DIR = "./output/14"
plt.figure(figsize=(20,10))
plt.suptitle("Transactions of the Models")
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Value ($)")
        else:
            plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        record = pickle.load(open(path.join(DIR,"sp500_Cashout_10k-Training_detailed-ModelNo-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
        plt.scatter(df['date'], df['action']*df['actual_price'])
        plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=10000, color = "grey", linestyle='--')
        plt.plot(df['date'], df['actual_profit'], color = "green")
        plt.plot(df['date'], df['net_worth'], color = 'orange')
    except Exception as e:
        print(e)

# %%
DIR = "./output/14"
plt.figure(figsize=(20,10))
plt.suptitle("Transactions of the Models")
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Value ($)")
        else:
            plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        record = pickle.load(open(path.join(DIR,"sp500_Cashout_10k-Training_detailed-ModelNo-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
        plt.scatter(df['date'], df['action']*df['actual_price'])
        plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=10000, color = "grey", linestyle='--')
        plt.plot(df['date'], df['actual_profit'], color = "green")
        plt.plot(df['date'], df['net_worth'], color = 'orange')
    except Exception as e:
        print(e)
