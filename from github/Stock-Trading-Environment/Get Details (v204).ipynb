# %%
import pickle
from os import path
import pandas as pd
import matplotlib.pyplot as plt
from pprint import pprint
import numpy as np

# %%
DIR = "./output/204"
axx = plt.figure(figsize=(20,10))
plt.suptitle("Inventory Value of the Models")
plt.rcParams['figure.facecolor'] = 'white'
# legend_list = ['S&P 500', 'Germany Dax', 'Hang Seng', 'CASH']
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Value ($)")
            ax = ax0
        else:
            ax = plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        
        record = pickle.load(open(path.join(DIR,"BRZ+TW+NASDAQ-Training-punish_detailed-ModelNo-50000-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
#         plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=300000, color = "grey", linestyle='--')
        plt.xlim((pd.Timestamp('2015-01-01'),pd.Timestamp('2019-12-31')))
        ax.set_xticks([pd.Timestamp('2015-01-01'), pd.Timestamp('2016-01-01'), 
                       pd.Timestamp('2017-01-01'), pd.Timestamp('2018-01-01'),
                       pd.Timestamp('2019-01-01'), pd.Timestamp('2020-01-01')])
        plt.plot(df['date'], df['net_worth'], label="RL Model")
        plt.plot(df['date'], df['buyNhold_balance'], label="Buy N Hold")
        
        for j in range(3):
            plt.plot(df['date'], [tmp[j] for tmp in df['inventory']], label=labels[j])
#             first_price = df['actual_price'][0][j]
#             plt.plot(df['date'], [tmp[j]/first_price*300000 for tmp in df['actual_price']])
        plt.title("Model "+str(i+1))
    except Exception as e:
        print(e)
plt.legend()

# %%
DIR = "./output/204"
axx = plt.figure(figsize=(20,10))
plt.suptitle("Inventory Value of the Models")
plt.rcParams['figure.facecolor'] = 'white'
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
# legend_list = ['S&P 500', 'Germany Dax', 'Hang Seng', 'CASH']
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Value ($)")
            ax = ax0
        else:
            ax = plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        
        record = pickle.load(open(path.join(DIR,"BRZ+TW+NASDAQ-Training-punish_detailed-ModelNo-200000-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
#         plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=300000, color = "grey", linestyle='--')
        plt.xlim((pd.Timestamp('2015-01-01'),pd.Timestamp('2019-12-31')))
        ax.set_xticks([pd.Timestamp('2015-01-01'), pd.Timestamp('2016-01-01'), 
                       pd.Timestamp('2017-01-01'), pd.Timestamp('2018-01-01'),
                       pd.Timestamp('2019-01-01'), pd.Timestamp('2020-01-01')])
        plt.plot(df['date'], df['net_worth'], label="RL Model")
        plt.plot(df['date'], df['buyNhold_balance'], label="Buy N Hold")
        
        for j in range(3):
            plt.plot(df['date'], [tmp[j] for tmp in df['inventory']], label = labels[j])
#             first_price = df['actual_price'][0][j]
#             plt.plot(df['date'], [tmp[j]/first_price*300000 for tmp in df['actual_price']])
        plt.title("Model "+str(i+1))
    except Exception as e:
        print(e)
plt.legend()

# %%
DIR = "./output/204"
record = pickle.load(open(path.join(DIR,"BRZ+TW+NASDAQ-Training-punish_detailed-ModelNo-50000-1.out"), "rb"))
df = pd.DataFrame(record)
# df
# for i in range(3):
#     plt.plot([tmp[i] for tmp in df['inventory']])
plt.plot(df['net_worth'])
plt.plot(df['buyNhold_balance'])

# %%
dfDIR = "./output/203"
record = pickle.load(open(path.join(DIR,"BRZ+TW+NASDAQ-Training_detailed-ModelNo-500000-0.out"), "rb"))
df = pd.DataFrame(record)
plt.figure(figsize=(15,10))
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
for j in range(3):
    first_price = df['actual_price'][0][j]
    plt.plot(df['date'], [tmp[j]/first_price*300000 for tmp in df['actual_price']], label=labels[j])
plt.plot(df['date'], df['net_worth'], label="RL Portfolio")
plt.legend()
# plt.plot(df['buyNhold_balance'])

# %%
dfDIR = "./output/203"
record = pickle.load(open(path.join(DIR,"BRZ+TW+NASDAQ-Training_detailed-ModelNo-500000-2.out"), "rb"))
df = pd.DataFrame(record)
plt.figure(figsize=(15,10))
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
for j in range(3):
    first_price = df['actual_price'][0][j]
    plt.plot(df['date'], [tmp[j]/first_price*300000 for tmp in df['actual_price']], label=labels[j])
plt.plot(df['date'], df['net_worth'], label="RL Portfolio")
plt.legend()
# plt.plot(df['buyNhold_balance'])

# %%
np.sum(df['action'])
# Out:
# array([0., 0., 0., 0.])

# %%
DIR = "./output/203"
record = pickle.load(open(path.join(DIR,"BRZ+TW+NASDAQ-Training_detailed-ModelNo-500000-0.out"), "rb"))
df = pd.DataFrame(record)
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
# df
plt.figure(figsize=(15,10))
for i in range(3):
    plt.plot(df['date'], [tmp[i] for tmp in df['inventory']], label=labels[i])
plt.plot(df['date'], df['net_worth'], label="RL Portfolio")
plt.legend()
# plt.plot(df['buyNhold_balance'])

# %%
DIR = "./output/203"
record = pickle.load(open(path.join(DIR,"BRZ+TW+NASDAQ-Training_detailed-ModelNo-500000-0.out"), "rb"))
df = pd.DataFrame(record)
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
# df
plt.figure(figsize=(15,10))

first_price = df['actual_price'][0][0]
plt.plot(df['date'], [tmp[0]/first_price*300000 for tmp in df['actual_price']], label=labels[0])

plt.plot(df['date'], [tmp[0] for tmp in df['inventory']], label=labels[0])
plt.plot(df['date'], df['net_worth'], label="RL Portfolio")
plt.legend()
# plt.plot(df['buyNhold_balance'])

# %%
DIR = "./output/203"
record = pickle.load(open(path.join(DIR,"BRZ+TW+NASDAQ-Training_detailed-ModelNo-500000-0.out"), "rb"))
df = pd.DataFrame(record)
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
# df
plt.figure(figsize=(15,10))

first_price = df['actual_price'][0][1]
plt.plot(df['date'], [tmp[1]/first_price*300000 for tmp in df['actual_price']], label=labels[1])

plt.plot(df['date'], [tmp[1] for tmp in df['inventory']], label=labels[1])
plt.plot(df['date'], df['net_worth'], label="RL Portfolio")
plt.legend()
# plt.plot(df['buyNhold_balance'])

# %%
DIR = "./output/203"
record = pickle.load(open(path.join(DIR,"BRZ+TW+NASDAQ-Training_detailed-ModelNo-500000-0.out"), "rb"))
df = pd.DataFrame(record)
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
# df
plt.figure(figsize=(15,10))

first_price = df['actual_price'][0][2]
plt.plot(df['date'], [tmp[2]/first_price*300000 for tmp in df['actual_price']], label=labels[2]+"_hold")

plt.plot(df['date'], [tmp[2] for tmp in df['inventory']], label=labels[2]+"_inv")
plt.plot(df['date'], df['net_worth'], label="RL Portfolio")
plt.legend()
# plt.plot(df['buyNhold_balance'])

# %%
DIR = "./output/203"
record = pickle.load(open(path.join(DIR,"BRZ+TW+NASDAQ-Training_detailed-ModelNo-500000-3.out"), "rb"))
df = pd.DataFrame(record)
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
# df
plt.figure(figsize=(15,10))
for i in range(3):
    plt.plot(df['date'], [tmp[i] for tmp in df['inventory']], label=labels[i]+"_inv")
plt.plot(df['date'], df['net_worth'], label="RL Portfolio")
plt.legend()
# plt.plot(df['buyNhold_balance'])

# %%
DIR = "./output/203"
record = pickle.load(open(path.join(DIR,"BRZ+TW+NASDAQ-Training_detailed-ModelNo-500000-3.out"), "rb"))
df = pd.DataFrame(record)
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
# df
plt.figure(figsize=(15,10))

first_price = df['actual_price'][0][0]
plt.plot(df['date'], [tmp[0]/first_price*300000 for tmp in df['actual_price']], label=labels[0]+"_hold")

plt.plot(df['date'], [tmp[0] for tmp in df['inventory']], label=labels[0]+"_inv")

plt.plot(df['date'], df['net_worth'], label="RL Portfolio")
plt.legend()
# plt.plot(df['buyNhold_balance'])

# %%
DIR = "./output/203"
record = pickle.load(open(path.join(DIR,"BRZ+TW+NASDAQ-Training_detailed-ModelNo-500000-3.out"), "rb"))
df = pd.DataFrame(record)
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
# df
plt.figure(figsize=(15,10))

first_price = df['actual_price'][0][1]
plt.plot(df['date'], [tmp[1]/first_price*300000 for tmp in df['actual_price']], label=labels[1]+"_hold")

plt.plot(df['date'], [tmp[1] for tmp in df['inventory']], label=labels[1]+"_inv")
plt.plot(df['date'], df['net_worth'], label="RL Portfolio")
plt.legend()
# plt.plot(df['buyNhold_balance'])

# %%
DIR = "./output/203"
record = pickle.load(open(path.join(DIR,"BRZ+TW+NASDAQ-Training_detailed-ModelNo-500000-3.out"), "rb"))
df = pd.DataFrame(record)
labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
# df
plt.figure(figsize=(15,10))

first_price = df['actual_price'][0][2]
plt.plot(df['date'], [tmp[2]/first_price*300000 for tmp in df['actual_price']], label=labels[2]+"_hold")

plt.plot(df['date'], [tmp[2] for tmp in df['inventory']], label=labels[2]+"_inv")
plt.plot(df['date'], df['net_worth'], label="RL Portfolio")
plt.legend()
# plt.plot(df['buyNhold_balance'])

# %%
DIR = "./output/201"
axx = plt.figure(figsize=(20,10))
plt.suptitle("Inventory Value of the Models")
plt.rcParams['figure.facecolor'] = 'white'
# legend_list = ['S&P 500', 'Germany Dax', 'Hang Seng', 'CASH']
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Value ($)")
            ax = ax0
        else:
            ax = plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        
        record = pickle.load(open(path.join(DIR,"BRZ+TW+NASDAQ-Training_detailed-ModelNo-50000-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
#         plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=300000, color = "grey", linestyle='--')
        plt.xlim((pd.Timestamp('2015-01-01'),pd.Timestamp('2019-12-31')))
        ax.set_xticks([pd.Timestamp('2015-01-01'), pd.Timestamp('2016-01-01'), 
                       pd.Timestamp('2017-01-01'), pd.Timestamp('2018-01-01'),
                       pd.Timestamp('2019-01-01'), pd.Timestamp('2020-01-01')])
        plt.plot(df['date'], df['net_worth'])
        plt.plot(df['date'], df['buyNhold_balance'])
#         for j in range(4):
#             plt.plot(df['date'], [tmp[j] for tmp in df['inventory']])
        plt.title("Model "+str(i+1))
    except Exception as e:
        print(e)
# axx.legend(['Initialized Value','S&P 500', 'Germany DAX', 'Hang Seng', 'CASH'])

# %%
DIR = "./output/201"
axx = plt.figure(figsize=(20,10))
plt.suptitle("Inventory Value of the Models")
plt.rcParams['figure.facecolor'] = 'white'
# legend_list = ['S&P 500', 'Germany Dax', 'Hang Seng', 'CASH']
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Value ($)")
            ax = ax0
        else:
            ax = plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        
        record = pickle.load(open(path.join(DIR,"BRZ+TW+NASDAQ-Training_detailed-ModelNo-100000-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
#         plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=300000, color = "grey", linestyle='--')
        plt.xlim((pd.Timestamp('2015-01-01'),pd.Timestamp('2019-12-31')))
        ax.set_xticks([pd.Timestamp('2015-01-01'), pd.Timestamp('2016-01-01'), 
                       pd.Timestamp('2017-01-01'), pd.Timestamp('2018-01-01'),
                       pd.Timestamp('2019-01-01'), pd.Timestamp('2020-01-01')])
        plt.plot(df['date'], df['net_worth'])
        plt.plot(df['date'], df['buyNhold_balance'])
#         for j in range(4):
#             plt.plot(df['date'], [tmp[j] for tmp in df['inventory']])
        plt.title("Model "+str(i+1))
    except Exception as e:
        print(e)
# axx.legend(['Initialized Value','S&P 500', 'Germany DAX', 'Hang Seng', 'CASH'])

# %%
plt.xlim(pd.Timestamp(2015, 1, 1), pd.Timestamp(2019, 12, 31))
plt.axhline(y=0, color = "grey", linestyle='--')
# plt.axhline(y=10000, color = "grey", linestyle='--')
plt.plot(df['date'], df['actual_profit']/df['buyNhold_balance']*100, color = "green")
# plt.plot(df['date'], df['net_worth'], color = 'orange')

# %%
plt.xlim(pd.Timestamp(2015, 1, 1), pd.Timestamp(2019, 12, 31))
plt.axhline(y=0, color = "grey", linestyle='--')
# plt.axhline(y=10000, color = "grey", linestyle='--')
plt.plot(df['date'], df['progress'], color = "green")
# plt.plot(df['date'], df['net_worth'], color = 'orange')

# %%
DIR = "./output/15/5"
plt.figure(figsize=(20,10))
plt.suptitle("Transactions of the Models")
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Value ($)")
        else:
            plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        record = pickle.load(open(path.join(DIR,"sp500_deltaReward_5k-Training_detailed-ModelNo-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
        plt.scatter(df['date'], df['action']*df['actual_price'])
        plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=10000, color = "grey", linestyle='--')
        plt.plot(df['date'], df['actual_profit'], color = "green")
        plt.plot(df['date'], df['net_worth'], color = 'orange')
    except Exception as e:
        print(e)

# %%
DIR = "./output/15/10"
plt.figure(figsize=(20,10))
plt.suptitle("Transactions of the Models")
for i in range(10):
    try:
        if i == 0:
            ax0 = plt.subplot(2, 5, 1)
            plt.xlabel("Date")
            plt.ylabel("Value ($)")
        else:
            plt.subplot(2, 5, i+1, sharex=ax0, sharey = ax0)
        record = pickle.load(open(path.join(DIR,"sp500_deltaReward_10k-Training_detailed-ModelNo-"+str(i)+".out"), "rb"))
        df = pd.DataFrame(record)
        plt.scatter(df['date'], df['action']*df['actual_price'])
        plt.axhline(y=0, color = "grey", linestyle='--')
        plt.axhline(y=10000, color = "grey", linestyle='--')
        plt.plot(df['date'], df['actual_profit'], color = "green")
        plt.plot(df['date'], df['net_worth'], color = 'orange')
    except Exception as e:
        print(e)
