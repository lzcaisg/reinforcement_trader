# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
tmp = pickle.load(open("0306-currency adjusted rebalance record.out", "rb"))
nominal_price_result = tmp[0]
actual_price_result = tmp[1]

# %%
df_list = pickle.load(open("0306-adjusted market prices.out", "rb"))
df_list[0]
# Out:
#            Date      Open      High       Low     Price        Vol    Change  \
# 0    2015-01-05   48512.0   48512.0   47264.0   47517.0  3866100.0 -0.020510
# 1    2015-01-06   47517.0   48061.0   47338.0   48001.0  4559300.0  0.010186
# 2    2015-01-07   48006.0   49882.0   48006.0   49463.0  4408800.0  0.030458
# 3    2015-01-08   49463.0   50261.0   49017.0   49943.0  3621900.0  0.009704
# 4    2015-01-09   49955.0   49955.0   48501.0   48840.0  2999200.0 -0.022085
# ...         ...       ...       ...       ...       ...        ...       ...
# 1132 2019-12-20  115133.0  115171.0  114526.0  115121.0  6887400.0 -0.000087
# 1133 2019-12-23  115119.0  115863.0  114964.0  115863.0  3995200.0  0.006445
# 1134 2019-12-26  115864.0  117220.0  115673.0  117203.0  3788900.0  0.011565
# 1135 2019-12-27  117205.0  117803.0  115995.0  116534.0  3905900.0 -0.005708
# 1136 2019-12-30  116530.0  117086.0  115790.0  115964.0  3667900.0 -0.004891
#
#       FX Change  Cum FX Change  Actual Price
# 0       -0.0046       0.995400  47298.421800
# 1        0.0024       0.997789  47894.867869
# 2        0.0062       1.003975  49659.627868
# 3        0.0075       1.011505  50517.597508
# 4        0.0125       1.024149  50019.431263
# ...         ...            ...           ...
# 1132    -0.0081       0.833756  95982.878403
# 1133     0.0049       0.837842  97074.873178
# 1134     0.0065       0.843288  98835.865569
# 1135     0.0028       0.845649  98546.866776
# 1136     0.0065       0.851146  98702.268320
#
# [1137 rows x 10 columns]

# %%
nominal_price_result
# Out:
# [[{'Date': Timestamp('2015-01-05 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.1045099648546834,
#      'Price': 47517.0,
#      'Net Value': 100000.0,
#      'Delta Number': 2.1045099648546834},
#     {'Asset': '^TWII',
#      'Number': 10.782745164625332,
#      'Price': 9274.076172,
#      'Net Value': 100000.0,
#      'Delta Number': 10.782745164625332},
#     {'Asset': '^IXIC',
#      'Number': 21.49349795550752,
#      'Price': 4652.569824,
#      'Net Value': 100000.0,
#      'Delta Number': 21.49349795550752}]},
#   {'Date': Timestamp('2016-01-04 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.227160955871705,
#      'Price': 42141.0,
#      'Net Value': 93854.78984138952,
#      'Delta Number': 0.12265099101702148},
#     {'Asset': '^TWII',
#      'Number': 11.566692263075486,
#      'Price': 8114.229004000001,
#      'Net Value': 93854.78984138952,
#      'Delta Number': 0.7839470984501542},
#     {'Asset': '^IXIC',
#      'Number': 19.14196819302451,
#      'Price': 4903.089844,
#      'Net Value': 93854.78984138952,
#      'Delta Number': -2.351529762483011}]},
#   {'Date': Timestamp('2017-01-03 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8811783437728709,
#      'Price': 61814.0,
#      'Net Value': 116283.15814197624,
#      'Delta Number': -0.3459826120988341},
#     {'Asset': '^TWII',
#      'Number': 12.540143443417106,
#      'Price': 9272.873047,
#      'Net Value': 116283.15814197624,
#      'Delta Number': 0.9734511803416197},
#     {'Asset': '^IXIC',
#      'Number': 21.418574872966946,
#      'Price': 5429.080078,
#      'Net Value': 116283.15814197622,
#      'Delta Number': 2.276606679942436}]},
#   {'Date': Timestamp('2018-01-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8441102267622815,
#      'Price': 77891.0,
#      'Net Value': 143639.58967274087,
#      'Delta Number': -0.03706811701058932},
#     {'Asset': '^TWII',
#      'Number': 13.410811717135076,
#      'Price': 10710.730469,
#      'Net Value': 143639.58967274087,
#      'Delta Number': 0.8706682737179694},
#     {'Asset': '^IXIC',
#      'Number': 20.499734787383137,
#      'Price': 7006.899901999999,
#      'Net Value': 143639.58967274087,
#      'Delta Number': -0.9188400855838097}]},
#   {'Date': Timestamp('2019-01-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.5844611289198358,
#      'Price': 91012.0,
#      'Net Value': 144204.9762652521,
#      'Delta Number': -0.2596490978424457},
#     {'Asset': '^TWII',
#      'Number': 15.093454939758917,
#      'Price': 9554.139648,
#      'Net Value': 144204.97626525213,
#      'Delta Number': 1.6826432226238417},
#     {'Asset': '^IXIC',
#      'Number': 21.63310463964652,
#      'Price': 6665.939941,
#      'Net Value': 144204.97626525213,
#      'Delta Number': 1.1333698522633817}]}],
#  [{'Date': Timestamp('2015-01-05 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.1045099648546834,
#      'Price': 47517.0,
#      'Net Value': 100000.0,
#      'Delta Number': 2.1045099648546834},
#     {'Asset': '^TWII',
#      'Number': 10.782745164625332,
#      'Price': 9274.076172,
#      'Net Value': 100000.0,
#      'Delta Number': 10.782745164625332},
#     {'Asset': '^IXIC',
#      'Number': 21.49349795550752,
#      'Price': 4652.569824,
#      'Net Value': 100000.0,
#      'Delta Number': 21.49349795550752}]},
#   {'Date': Timestamp('2015-06-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.0058787597114054,
#      'Price': 53081.0,
#      'Net Value': 106474.0504442411,
#      'Delta Number': -0.09863120514327806},
#     {'Asset': '^TWII',
#      'Number': 11.420596131409765,
#      'Price': 9322.985352,
#      'Net Value': 106474.0504442411,
#      'Delta Number': 0.6378509667844323},
#     {'Asset': '^IXIC',
#      'Number': 21.350876992219266,
#      'Price': 4986.870117,
#      'Net Value': 106474.0504442411,
#      'Delta Number': -0.14262096328825535}]},
#   {'Date': Timestamp('2016-01-04 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.229691886179708,
#      'Price': 42141.0,
#      'Net Value': 93961.44577549909,
#      'Delta Number': 0.22381312646830276},
#     {'Asset': '^TWII',
#      'Number': 11.579836572172132,
#      'Price': 8114.229004000001,
#      'Net Value': 93961.44577549906,
#      'Delta Number': 0.15924044076236754},
#     {'Asset': '^IXIC',
#      'Number': 19.163720993300046,
#      'Price': 4903.089844,
#      'Net Value': 93961.44577549904,
#      'Delta Number': -2.18715599891922}]},
#   {'Date': Timestamp('2016-06-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.992808579346061,
#      'Price': 51527.0,
#      'Net Value': 102683.44766796449,
#      'Delta Number': -0.2368833068336471},
#     {'Asset': '^TWII',
#      'Number': 11.848225846531157,
#      'Price': 8666.567383,
#      'Net Value': 102683.44766796449,
#      'Delta Number': 0.26838927435902526},
#     {'Asset': '^IXIC',
#      'Number': 21.20389151477759,
#      'Price': 4842.669922,
#      'Net Value': 102683.44766796446,
#      'Delta Number': 2.0401705214775454}]},
#   {'Date': Timestamp('2017-01-03 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8775044953662992,
#      'Price': 61814.0,
#      'Net Value': 116056.06287657241,
#      'Delta Number': -0.11530408397976188},
#     {'Asset': '^TWII',
#      'Number': 12.515653162545922,
#      'Price': 9272.873047,
#      'Net Value': 116056.06287657238,
#      'Delta Number': 0.6674273160147646},
#     {'Asset': '^IXIC',
#      'Number': 21.376745453960204,
#      'Price': 5429.080078,
#      'Net Value': 116056.06287657241,
#      'Delta Number': 0.1728539391826125}]},
#   {'Date': Timestamp('2017-06-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.010907901692349,
#      'Price': 62900.0,
#      'Net Value': 126486.10701644873,
#      'Delta Number': 0.13340340632604963},
#     {'Asset': '^TWII',
#      'Number': 12.167893357899278,
#      'Price': 10395.070313,
#      'Net Value': 126486.10701644867,
#      'Delta Number': -0.34775980464664435},
#     {'Asset': '^IXIC',
#      'Number': 20.598934376339983,
#      'Price': 6140.419922,
#      'Net Value': 126486.10701644867,
#      'Delta Number': -0.7778110776202212}]},
#   {'Date': Timestamp('2018-01-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8457131323070888,
#      'Price': 77891.0,
#      'Net Value': 143764.44158853145,
#      'Delta Number': -0.16519476938526},
#     {'Asset': '^TWII',
#      'Number': 13.422468430573236,
#      'Price': 10710.730469,
#      'Net Value': 143764.44158853136,
#      'Delta Number': 1.2545750726739584},
#     {'Asset': '^IXIC',
#      'Number': 20.517553211727254,
#      'Price': 7006.899901999999,
#      'Net Value': 143764.44158853145,
#      'Delta Number': -0.08138116461272915}]},
#   {'Date': Timestamp('2018-07-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.98782166748967,
#      'Price': 72840.0,
#      'Net Value': 144792.93025994758,
#      'Delta Number': 0.14210853518258126},
#     {'Asset': '^TWII',
#      'Number': 13.434192849769502,
#      'Price': 10777.94043,
#      'Net Value': 144792.93025994764,
#      'Delta Number': 0.011724419196266211},
#     {'Asset': '^IXIC',
#      'Number': 19.133042102517035,
#      'Price': 7567.689941,
#      'Net Value': 144792.93025994764,
#      'Delta Number': -1.3845111092102194}]},
#   {'Date': Timestamp('2019-01-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.5998164699542685,
#      'Price': 91012.0,
#      'Net Value': 145602.49656347788,
#      'Delta Number': -0.3880051975354015},
#     {'Asset': '^TWII',
#      'Number': 15.239728738312648,
#      'Price': 9554.139648,
#      'Net Value': 145602.49656347788,
#      'Delta Number': 1.8055358885431456},
#     {'Asset': '^IXIC',
#      'Number': 21.842755538183734,
#      'Price': 6665.939941,
#      'Net Value': 145602.4965634779,
#      'Delta Number': 2.7097134356667}]},
#   {'Date': Timestamp('2019-07-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.6607541893880424,
#      'Price': 101340.0,
#      'Net Value': 168300.8295525842,
#      'Delta Number': 0.06093771943377391},
#     {'Asset': '^TWII',
#      'Number': 15.446876970317215,
#      'Price': 10895.459961,
#      'Net Value': 168300.8295525842,
#      'Delta Number': 0.20714823200456678},
#     {'Asset': '^IXIC',
#      'Number': 20.800580671707596,
#      'Price': 8091.160156,
#      'Net Value': 168300.8295525842,
#      'Delta Number': -1.042174866476138}]}],
#  [{'Date': Timestamp('2015-01-05 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.1045099648546834,
#      'Price': 47517.0,
#      'Net Value': 100000.0,
#      'Delta Number': 2.1045099648546834},
#     {'Asset': '^TWII',
#      'Number': 10.782745164625332,
#      'Price': 9274.076172,
#      'Net Value': 100000.0,
#      'Delta Number': 10.782745164625332},
#     {'Asset': '^IXIC',
#      'Number': 21.49349795550752,
#      'Price': 4652.569824,
#      'Net Value': 100000.0,
#      'Delta Number': 21.49349795550752}]},
#   {'Date': Timestamp('2015-03-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.0615867776304055,
#      'Price': 51150.0,
#      'Net Value': 105450.16367579524,
#      'Delta Number': -0.0429231872242779},
#     {'Asset': '^TWII',
#      'Number': 10.999970417354,
#      'Price': 9586.404297,
#      'Net Value': 105450.16367579525,
#      'Delta Number': 0.21722525272866733},
#     {'Asset': '^IXIC',
#      'Number': 21.516577878510567,
#      'Price': 4900.879883,
#      'Net Value': 105450.16367579525,
#      'Delta Number': 0.02307992300304562}]},
#   {'Date': Timestamp('2015-06-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.005011398047461,
#      'Price': 53081.0,
#      'Net Value': 106428.01001975728,
#      'Delta Number': -0.056575379582944674},
#     {'Asset': '^TWII',
#      'Number': 11.41565775354629,
#      'Price': 9322.985352,
#      'Net Value': 106428.01001975728,
#      'Delta Number': 0.41568733619229015},
#     {'Asset': '^IXIC',
#      'Number': 21.34164466344317,
#      'Price': 4986.870117,
#      'Net Value': 106428.01001975728,
#      'Delta Number': -0.1749332150673979}]},
#   {'Date': Timestamp('2015-09-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.0886653223256135,
#      'Price': 45059.0,
#      'Net Value': 94113.17075866982,
#      'Delta Number': 0.08365392427815266},
#     {'Asset': '^TWII',
#      'Number': 11.503576710664408,
#      'Price': 8181.209473000001,
#      'Net Value': 94113.17075866985,
#      'Delta Number': 0.08791895711811826},
#     {'Asset': '^IXIC',
#      'Number': 20.37011003535217,
#      'Price': 4620.160156,
#      'Net Value': 94113.17075866985,
#      'Delta Number': -0.9715346280909998}]},
#   {'Date': Timestamp('2016-01-04 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.2245760722260464,
#      'Price': 42141.0,
#      'Net Value': 93745.86025967782,
#      'Delta Number': 0.13591074990043284},
#     {'Asset': '^TWII',
#      'Number': 11.553267748970942,
#      'Price': 8114.229004000001,
#      'Net Value': 93745.86025967782,
#      'Delta Number': 0.0496910383065341},
#     {'Asset': '^IXIC',
#      'Number': 19.119751675445297,
#      'Price': 4903.089844,
#      'Net Value': 93745.86025967782,
#      'Delta Number': -1.2503583599068726}]},
#   {'Date': Timestamp('2016-03-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.0343796325987666,
#      'Price': 50055.0,
#      'Net Value': 101830.87250973127,
#      'Delta Number': -0.19019643962727972},
#     {'Asset': '^TWII',
#      'Number': 11.644720255793926,
#      'Price': 8744.810547,
#      'Net Value': 101830.87250973126,
#      'Delta Number': 0.09145250682298389},
#     {'Asset': '^IXIC',
#      'Number': 20.910473723113604,
#      'Price': 4869.850098,
#      'Net Value': 101830.87250973121,
#      'Delta Number': 1.7907220476683072}]},
#   {'Date': Timestamp('2016-06-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9860639679885193,
#      'Price': 51527.0,
#      'Net Value': 102335.91807854443,
#      'Delta Number': -0.04831566461024739},
#     {'Asset': '^TWII',
#      'Number': 11.80812581914295,
#      'Price': 8666.567383,
#      'Net Value': 102335.91807854443,
#      'Delta Number': 0.16340556334902345},
#     {'Asset': '^IXIC',
#      'Number': 21.1321274682872,
#      'Price': 4842.669922,
#      'Net Value': 102335.91807854445,
#      'Delta Number': 0.22165374517359737}]},
#   {'Date': Timestamp('2016-09-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.921277550529144,
#      'Price': 58367.0,
#      'Net Value': 112139.20679173454,
#      'Delta Number': -0.0647864174593753},
#     {'Asset': '^TWII',
#      'Number': 12.233140814414462,
#      'Price': 9166.836914,
#      'Net Value': 112139.20679173451,
#      'Delta Number': 0.4250149952715123},
#     {'Asset': '^IXIC',
#      'Number': 21.110543447239184,
#      'Price': 5312.0,
#      'Net Value': 112139.20679173454,
#      'Delta Number': -0.021584021048017377}]},
#   {'Date': Timestamp('2017-01-03 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8701752737336075,
#      'Price': 61814.0,
#      'Net Value': 115603.01437056922,
#      'Delta Number': -0.05110227679553647},
#     {'Asset': '^TWII',
#      'Number': 12.466795758405173,
#      'Price': 9272.873047,
#      'Net Value': 115603.01437056925,
#      'Delta Number': 0.23365494399071096},
#     {'Asset': '^IXIC',
#      'Number': 21.29329696922721,
#      'Price': 5429.080078,
#      'Net Value': 115603.01437056923,
#      'Delta Number': 0.18275352198802608}]},
#   {'Date': Timestamp('2017-03-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8965182980700892,
#      'Price': 64984.0,
#      'Net Value': 123243.34508178668,
#      'Delta Number': 0.026343024336481724},
#     {'Asset': '^TWII',
#      'Number': 12.561095206511038,
#      'Price': 9811.512695,
#      'Net Value': 123243.34508178668,
#      'Delta Number': 0.09429944810586477},
#     {'Asset': '^IXIC',
#      'Number': 20.84721929644019,
#      'Price': 5911.740234000001,
#      'Net Value': 123243.34508178667,
#      'Delta Number': -0.4460776727870197}]},
#   {'Date': Timestamp('2017-06-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.0025180154464355,
#      'Price': 62900.0,
#      'Net Value': 125958.38317158079,
#      'Delta Number': 0.10599971737634628},
#     {'Asset': '^TWII',
#      'Number': 12.117126616648095,
#      'Price': 10395.070313,
#      'Net Value': 125958.38317158075,
#      'Delta Number': -0.4439685898629424},
#     {'Asset': '^IXIC',
#      'Number': 20.512991745123966,
#      'Price': 6140.419922,
#      'Net Value': 125958.38317158075,
#      'Delta Number': -0.33422755131622495}]},
#   {'Date': Timestamp('2017-10-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8351817208083516,
#      'Price': 74360.0,
#      'Net Value': 136464.11275930904,
#      'Delta Number': -0.16733629463808386},
#     {'Asset': '^TWII',
#      'Number': 13.03984943613787,
#      'Price': 10465.160156,
#      'Net Value': 136464.1127593091,
#      'Delta Number': 0.9227228194897741},
#     {'Asset': '^IXIC',
#      'Number': 20.94061249479452,
#      'Price': 6516.720215,
#      'Net Value': 136464.11275930904,
#      'Delta Number': 0.42762074967055597}]},
#   {'Date': Timestamp('2018-01-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8373506041343814,
#      'Price': 77891.0,
#      'Net Value': 143113.0759066311,
#      'Delta Number': 0.0021688833260298246},
#     {'Asset': '^TWII',
#      'Number': 13.361654120682285,
#      'Price': 10710.730469,
#      'Net Value': 143113.07590663116,
#      'Delta Number': 0.321804684544416},
#     {'Asset': '^IXIC',
#      'Number': 20.424592602754597,
#      'Price': 7006.899901999999,
#      'Net Value': 143113.0759066311,
#      'Delta Number': -0.5160198920399246}]},
#   {'Date': Timestamp('2018-04-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.737674399866695,
#      'Price': 84666.0,
#      'Net Value': 147121.9407391136,
#      'Delta Number': -0.09967620426768642},
#     {'Asset': '^TWII',
#      'Number': 13.511967197380871,
#      'Price': 10888.269531,
#      'Net Value': 147121.9407391136,
#      'Delta Number': 0.15031307669858585},
#     {'Asset': '^IXIC',
#      'Number': 21.41475523478298,
#      'Price': 6870.120117,
#      'Net Value': 147121.9407391136,
#      'Delta Number': 0.9901626320283832}]},
#   {'Date': Timestamp('2018-07-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.98729456622286,
#      'Price': 72840.0,
#      'Net Value': 144754.53620367314,
#      'Delta Number': 0.24962016635616502},
#     {'Asset': '^TWII',
#      'Number': 13.430630568411216,
#      'Price': 10777.94043,
#      'Net Value': 144754.53620367314,
#      'Delta Number': -0.08133662896965532},
#     {'Asset': '^IXIC',
#      'Number': 19.127968684264722,
#      'Price': 7567.689941,
#      'Net Value': 144754.53620367314,
#      'Delta Number': -2.286786550518258}]},
#   {'Date': Timestamp('2018-10-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9435071023597001,
#      'Price': 78624.0,
#      'Net Value': 152806.30241592907,
#      'Delta Number': -0.0437874638631599},
#     {'Asset': '^TWII',
#      'Number': 13.826372637223958,
#      'Price': 11051.799805,
#      'Net Value': 152806.3024159291,
#      'Delta Number': 0.39574206881274243},
#     {'Asset': '^IXIC',
#      'Number': 19.012144143343807,
#      'Price': 8037.299805,
#      'Net Value': 152806.30241592907,
#      'Delta Number': -0.1158245409209151}]},
#   {'Date': Timestamp('2019-01-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.5958165751419207,
#      'Price': 91012.0,
#      'Net Value': 145238.45813681648,
#      'Delta Number': -0.3476905272177795},
#     {'Asset': '^TWII',
#      'Number': 15.20162604774358,
#      'Price': 9554.139648,
#      'Net Value': 145238.45813681648,
#      'Delta Number': 1.3752534105196226},
#     {'Asset': '^IXIC',
#      'Number': 21.78814382102404,
#      'Price': 6665.939941,
#      'Net Value': 145238.45813681648,
#      'Delta Number': 2.7759996776802325}]},
#   {'Date': Timestamp('2019-04-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.6853272305001799,
#      'Price': 96054.0,
#      'Net Value': 161882.4217984643,
#      'Delta Number': 0.0895106553582592},
#     {'Asset': '^TWII',
#      'Number': 15.210753693224556,
#      'Price': 10642.629883,
#      'Net Value': 161882.42179846426,
#      'Delta Number': 0.009127645480974778},
#     {'Asset': '^IXIC',
#      'Number': 20.67751686668663,
#      'Price': 7828.910156,
#      'Net Value': 161882.42179846426,
#      'Delta Number': -1.110626954337409}]},
#   {'Date': Timestamp('2019-07-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.657207815199007,
#      'Price': 101340.0,
#      'Net Value': 167941.43999226738,
#      'Delta Number': -0.02811941530117279},
#     {'Asset': '^TWII',
#      'Number': 15.413891712090091,
#      'Price': 10895.459961,
#      'Net Value': 167941.43999226735,
#      'Delta Number': 0.20313801886553584},
#     {'Asset': '^IXIC',
#      'Number': 20.756163115586137,
#      'Price': 8091.160156,
#      'Net Value': 167941.43999226738,
#      'Delta Number': 0.07864624889950633}]},
#   {'Date': Timestamp('2019-10-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.6198330851261613,
#      'Price': 104053.0,
#      'Net Value': 168548.49200663247,
#      'Delta Number': -0.03737473007284575},
#     {'Asset': '^TWII',
#      'Number': 15.367784894469516,
#      'Price': 10967.650391,
#      'Net Value': 168548.49200663247,
#      'Delta Number': -0.04610681762057567},
#     {'Asset': '^IXIC',
#      'Number': 21.311835635750757,
#      'Price': 7908.680176000001,
#      'Net Value': 168548.49200663238,
#      'Delta Number': 0.5556725201646202}]}],
#  [{'Date': Timestamp('2015-01-05 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.1045099648546834,
#      'Price': 47517.0,
#      'Net Value': 100000.0,
#      'Delta Number': 2.1045099648546834},
#     {'Asset': '^TWII',
#      'Number': 10.782745164625332,
#      'Price': 9274.076172,
#      'Net Value': 100000.0,
#      'Delta Number': 10.782745164625332},
#     {'Asset': '^IXIC',
#      'Number': 21.49349795550752,
#      'Price': 4652.569824,
#      'Net Value': 100000.0,
#      'Delta Number': 21.49349795550752}]},
#   {'Date': Timestamp('2015-02-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.11270546986295,
#      'Price': 47651.0,
#      'Net Value': 100672.52834443943,
#      'Delta Number': 0.00819550500826649},
#     {'Asset': '^TWII',
#      'Number': 10.724725646373493,
#      'Price': 9386.956055,
#      'Net Value': 100672.52834443946,
#      'Delta Number': -0.058019518251839486},
#     {'Asset': '^IXIC',
#      'Number': 21.526449179761748,
#      'Price': 4676.689941,
#      'Net Value': 100672.52834443946,
#      'Delta Number': 0.032951224254226474}]},
#   {'Date': Timestamp('2015-03-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.081303294168353,
#      'Price': 51021.0,
#      'Net Value': 106190.17537176353,
#      'Delta Number': -0.03140217569459702},
#     {'Asset': '^TWII',
#      'Number': 11.059950997345188,
#      'Price': 9601.324219,
#      'Net Value': 106190.17537176356,
#      'Delta Number': 0.3352253509716956},
#     {'Asset': '^IXIC',
#      'Number': 21.203684689563396,
#      'Price': 5008.100098,
#      'Net Value': 106190.17537176354,
#      'Delta Number': -0.3227644901983524}]},
#   {'Date': Timestamp('2015-03-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.06191291627779,
#      'Price': 51150.0,
#      'Net Value': 105466.84566760896,
#      'Delta Number': -0.01939037789056286},
#     {'Asset': '^TWII',
#      'Number': 11.001710589299275,
#      'Price': 9586.404297,
#      'Net Value': 105466.84566760897,
#      'Delta Number': -0.05824040804591313},
#     {'Asset': '^IXIC',
#      'Number': 21.519981755408594,
#      'Price': 4900.879883,
#      'Net Value': 105466.845667609,
#      'Delta Number': 0.31629706584519823}]},
#   {'Date': Timestamp('2015-04-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9581562633176905,
#      'Price': 56229.0,
#      'Net Value': 110105.16853009042,
#      'Delta Number': -0.1037566529600995},
#     {'Asset': '^TWII',
#      'Number': 11.212324459229267,
#      'Price': 9820.012695,
#      'Net Value': 110105.1685300904,
#      'Delta Number': 0.21061386992999154},
#     {'Asset': '^IXIC',
#      'Number': 22.282091032151385,
#      'Price': 4941.419922,
#      'Net Value': 110105.16853009039,
#      'Delta Number': 0.762109276742791}]},
#   {'Date': Timestamp('2015-06-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.0430016204486687,
#      'Price': 53031.0,
#      'Net Value': 108342.41893401335,
#      'Delta Number': 0.08484535713097818},
#     {'Asset': '^TWII',
#      'Number': 11.255590071189253,
#      'Price': 9625.654297,
#      'Net Value': 108342.41893401336,
#      'Delta Number': 0.04326561195998657},
#     {'Asset': '^IXIC',
#      'Number': 21.31495322237009,
#      'Price': 5082.930176,
#      'Net Value': 108342.41893401336,
#      'Delta Number': -0.9671378097812955}]},
#   {'Date': Timestamp('2015-06-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.0074676666901534,
#      'Price': 53081.0,
#      'Net Value': 106558.39121558004,
#      'Delta Number': -0.03553395375851531},
#     {'Asset': '^TWII',
#      'Number': 11.42964267263605,
#      'Price': 9322.985352,
#      'Net Value': 106558.39121558002,
#      'Delta Number': 0.17405260144679602},
#     {'Asset': '^IXIC',
#      'Number': 21.367789558490326,
#      'Price': 4986.870117,
#      'Net Value': 106558.39121558004,
#      'Delta Number': 0.05283633612023664}]},
#   {'Date': Timestamp('2015-07-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.0363132200918512,
#      'Price': 50865.0,
#      'Net Value': 103577.07193997201,
#      'Delta Number': 0.02884555340169781},
#     {'Asset': '^TWII',
#      'Number': 11.953075011067092,
#      'Price': 8665.307617,
#      'Net Value': 103577.07193997204,
#      'Delta Number': 0.5234323384310429},
#     {'Asset': '^IXIC',
#      'Number': 20.197234995432687,
#      'Price': 5128.279785,
#      'Net Value': 103577.07193997201,
#      'Delta Number': -1.1705545630576388}]},
#   {'Date': Timestamp('2015-08-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.067033370069082,
#      'Price': 46626.0,
#      'Net Value': 96377.49791284102,
#      'Delta Number': 0.030720149977230715},
#     {'Asset': '^TWII',
#      'Number': 11.789456227054341,
#      'Price': 8174.88916,
#      'Net Value': 96377.49791284103,
#      'Delta Number': -0.1636187840127512},
#     {'Asset': '^IXIC',
#      'Number': 20.177389481933503,
#      'Price': 4776.509765999999,
#      'Net Value': 96377.49791284103,
#      'Delta Number': -0.01984551349918462}]},
#   {'Date': Timestamp('2015-09-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.092169810875824,
#      'Price': 45059.0,
#      'Net Value': 94271.07950825375,
#      'Delta Number': 0.025136440806742044},
#     {'Asset': '^TWII',
#      'Number': 11.52287810492708,
#      'Price': 8181.209473000001,
#      'Net Value': 94271.07950825374,
#      'Delta Number': -0.2665781221272603},
#     {'Asset': '^IXIC',
#      'Number': 20.404288233564376,
#      'Price': 4620.160156,
#      'Net Value': 94271.07950825375,
#      'Delta Number': 0.22689875163087336}]},
#   {'Date': Timestamp('2015-11-03 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.12206060616389,
#      'Price': 48054.0,
#      'Net Value': 101973.50036859958,
#      'Delta Number': 0.02989079528806604},
#     {'Asset': '^TWII',
#      'Number': 11.703391352803553,
#      'Price': 8713.158203,
#      'Net Value': 101973.50036859956,
#      'Delta Number': 0.1805132478764726},
#     {'Asset': '^IXIC',
#      'Number': 19.819421994676897,
#      'Price': 5145.129883,
#      'Net Value': 101973.50036859956,
#      'Delta Number': -0.5848662388874786}]},
#   {'Date': Timestamp('2015-11-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.1747727662839633,
#      'Price': 45120.0,
#      'Net Value': 98125.74721473243,
#      'Delta Number': 0.05271216012007329},
#     {'Asset': '^TWII',
#      'Number': 11.793140541509237,
#      'Price': 8320.578125,
#      'Net Value': 98125.74721473242,
#      'Delta Number': 0.08974918870568338},
#     {'Asset': '^IXIC',
#      'Number': 19.207689812207914,
#      'Price': 5108.669922,
#      'Net Value': 98125.7472147324,
#      'Delta Number': -0.6117321824689839}]},
#   {'Date': Timestamp('2016-01-04 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.2267812899478243,
#      'Price': 42141.0,
#      'Net Value': 93838.79033969126,
#      'Delta Number': 0.052008523663860995},
#     {'Asset': '^TWII',
#      'Number': 11.564720479719321,
#      'Price': 8114.229004000001,
#      'Net Value': 93838.79033969132,
#      'Delta Number': -0.22842006178991525},
#     {'Asset': '^IXIC',
#      'Number': 19.13870504627272,
#      'Price': 4903.089844,
#      'Net Value': 93838.79033969132,
#      'Delta Number': -0.06898476593519476}]},
#   {'Date': Timestamp('2016-02-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.2438667649852486,
#      'Price': 40570.0,
#      'Net Value': 91033.67465545154,
#      'Delta Number': 0.017085475037424303},
#     {'Asset': '^TWII',
#      'Number': 11.160287460458997,
#      'Price': 8156.929198999999,
#      'Net Value': 91033.67465545154,
#      'Delta Number': -0.40443301926032404},
#     {'Asset': '^IXIC',
#      'Number': 19.7026801641942,
#      'Price': 4620.370117,
#      'Net Value': 91033.67465545154,
#      'Delta Number': 0.5639751179214798}]},
#   {'Date': Timestamp('2016-03-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.161462208951529,
#      'Price': 44122.0,
#      'Net Value': 95368.03558335936,
#      'Delta Number': -0.08240455603371943},
#     {'Asset': '^TWII',
#      'Number': 11.238714855868002,
#      'Price': 8485.670898,
#      'Net Value': 95368.03558335938,
#      'Delta Number': 0.07842739540900467},
#     {'Asset': '^IXIC',
#      'Number': 20.33606993995747,
#      'Price': 4689.600098,
#      'Net Value': 95368.0355833594,
#      'Delta Number': 0.6333897757632698}]},
#   {'Date': Timestamp('2016-03-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.0344689858850304,
#      'Price': 50055.0,
#      'Net Value': 101835.3450884752,
#      'Delta Number': -0.12699322306649874},
#     {'Asset': '^TWII',
#      'Number': 11.645231710984396,
#      'Price': 8744.810547,
#      'Net Value': 101835.3450884752,
#      'Delta Number': 0.40651685511639357},
#     {'Asset': '^IXIC',
#      'Number': 20.911392145375892,
#      'Price': 4869.850098,
#      'Net Value': 101835.34508847521,
#      'Delta Number': 0.5753222054184235}]},
#   {'Date': Timestamp('2016-05-03 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9295422767647652,
#      'Price': 52260.0,
#      'Net Value': 100837.87938372663,
#      'Delta Number': -0.10492670912026525},
#     {'Asset': '^TWII',
#      'Number': 12.15778351590473,
#      'Price': 8294.100586,
#      'Net Value': 100837.87938372657,
#      'Delta Number': 0.512551804920335},
#     {'Asset': '^IXIC',
#      'Number': 21.170106531328326,
#      'Price': 4763.220215,
#      'Net Value': 100837.87938372661,
#      'Delta Number': 0.2587143859524339}]},
#   {'Date': Timestamp('2016-05-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.077165723054872,
#      'Price': 48472.0,
#      'Net Value': 100684.37692791576,
#      'Delta Number': 0.1476234462901067},
#     {'Asset': '^TWII',
#      'Number': 11.795858183555653,
#      'Price': 8535.570313,
#      'Net Value': 100684.37692791574,
#      'Delta Number': -0.3619253323490774},
#     {'Asset': '^IXIC',
#      'Number': 20.34829496384096,
#      'Price': 4948.049805,
#      'Net Value': 100684.37692791574,
#      'Delta Number': -0.8218115674873658}]},
#   {'Date': Timestamp('2016-06-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9911877526042796,
#      'Price': 51527.0,
#      'Net Value': 102599.93132844071,
#      'Delta Number': -0.0859779704505923},
#     {'Asset': '^TWII',
#      'Number': 11.838589235421711,
#      'Price': 8666.567383,
#      'Net Value': 102599.93132844071,
#      'Delta Number': 0.04273105186605797},
#     {'Asset': '^IXIC',
#      'Number': 21.186645586215676,
#      'Price': 4842.669922,
#      'Net Value': 102599.93132844071,
#      'Delta Number': 0.8383506223747155}]},
#   {'Date': Timestamp('2016-08-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9401784105254831,
#      'Price': 56756.0,
#      'Net Value': 110116.76586778431,
#      'Delta Number': -0.05100934207879648},
#     {'Asset': '^TWII',
#      'Number': 12.126467218287596,
#      'Price': 9080.696289,
#      'Net Value': 110116.76586778431,
#      'Delta Number': 0.2878779828658846},
#     {'Asset': '^IXIC',
#      'Number': 21.240839806685806,
#      'Price': 5184.200195,
#      'Net Value': 110116.76586778433,
#      'Delta Number': 0.054194220470130006}]},
#   {'Date': Timestamp('2016-08-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.91732093951886,
#      'Price': 57901.0,
#      'Net Value': 111014.79971908151,
#      'Delta Number': -0.022857471006623165},
#     {'Asset': '^TWII',
#      'Number': 12.241349223923375,
#      'Price': 9068.836914,
#      'Net Value': 111014.79971908155,
#      'Delta Number': 0.11488200563577955},
#     {'Asset': '^IXIC',
#      'Number': 21.29486097664906,
#      'Price': 5213.220215,
#      'Net Value': 111014.79971908152,
#      'Delta Number': 0.0540211699632529}]},
#   {'Date': Timestamp('2016-09-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9259800042711532,
#      'Price': 58367.0,
#      'Net Value': 112413.6749092944,
#      'Delta Number': 0.008659064752293277},
#     {'Asset': '^TWII',
#      'Number': 12.263082234790415,
#      'Price': 9166.836914,
#      'Net Value': 112413.6749092944,
#      'Delta Number': 0.021733010867039937},
#     {'Asset': '^IXIC',
#      'Number': 21.162212897081016,
#      'Price': 5312.0,
#      'Net Value': 112413.67490929435,
#      'Delta Number': -0.13264807956804248}]},
#   {'Date': Timestamp('2016-10-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.7906984540896398,
#      'Price': 64925.0,
#      'Net Value': 116261.09713176986,
#      'Delta Number': -0.13528155018151344},
#     {'Asset': '^TWII',
#      'Number': 12.514505145166646,
#      'Price': 9290.107422,
#      'Net Value': 116261.09713176984,
#      'Delta Number': 0.2514229103762311},
#     {'Asset': '^IXIC',
#      'Number': 22.404694046089862,
#      'Price': 5189.140136999999,
#      'Net Value': 116261.09713176981,
#      'Delta Number': 1.2424811490088459}]},
#   {'Date': Timestamp('2016-11-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8618186220191744,
#      'Price': 61906.0,
#      'Net Value': 115257.743614719,
#      'Delta Number': 0.07112016792953457},
#     {'Asset': '^TWII',
#      'Number': 12.472832646565413,
#      'Price': 9240.703125,
#      'Net Value': 115257.74361471903,
#      'Delta Number': -0.04167249860123334},
#     {'Asset': '^IXIC',
#      'Number': 21.650012736362214,
#      'Price': 5323.680176,
#      'Net Value': 115257.74361471903,
#      'Delta Number': -0.7546813097276477}]},
#   {'Date': Timestamp('2017-01-03 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8781349575878268,
#      'Price': 61814.0,
#      'Net Value': 116095.03426833393,
#      'Delta Number': 0.016316335568652418},
#     {'Asset': '^TWII',
#      'Number': 12.519855893626568,
#      'Price': 9272.873047,
#      'Net Value': 116095.0342683339,
#      'Delta Number': 0.047023247061154905},
#     {'Asset': '^IXIC',
#      'Number': 21.383923721954332,
#      'Price': 5429.080078,
#      'Net Value': 116095.03426833387,
#      'Delta Number': -0.266089014407882}]},
#   {'Date': Timestamp('2017-02-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8574929076172657,
#      'Price': 64578.0,
#      'Net Value': 119953.17698810778,
#      'Delta Number': -0.02064204997056107},
#     {'Asset': '^TWII',
#      'Number': 12.721778458010883,
#      'Price': 9428.962891,
#      'Net Value': 119953.1769881078,
#      'Delta Number': 0.201922564384315},
#     {'Asset': '^IXIC',
#      'Number': 21.28263241864988,
#      'Price': 5636.200195,
#      'Net Value': 119953.17698810778,
#      'Delta Number': -0.10129130330445335}]},
#   {'Date': Timestamp('2017-03-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8568482009532548,
#      'Price': 66989.0,
#      'Net Value': 124388.40413365759,
#      'Delta Number': -0.0006447066640109522},
#     {'Asset': '^TWII',
#      'Number': 12.856983673136181,
#      'Price': 9674.773438,
#      'Net Value': 124388.4041336576,
#      'Delta Number': 0.13520521512529804},
#     {'Asset': '^IXIC',
#      'Number': 21.06839034750188,
#      'Price': 5904.029785,
#      'Net Value': 124388.40413365759,
#      'Delta Number': -0.21424207114799998}]},
#   {'Date': Timestamp('2017-03-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9048931680725196,
#      'Price': 64984.0,
#      'Net Value': 123787.57763402461,
#      'Delta Number': 0.04804496711926487},
#     {'Asset': '^TWII',
#      'Number': 12.616563977653254,
#      'Price': 9811.512695,
#      'Net Value': 123787.5776340246,
#      'Delta Number': -0.2404196954829274},
#     {'Asset': '^IXIC',
#      'Number': 20.93927891521503,
#      'Price': 5911.740234000001,
#      'Net Value': 123787.5776340246,
#      'Delta Number': -0.12911143228684807}]},
#   {'Date': Timestamp('2017-05-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8992012316856492,
#      'Price': 66722.0,
#      'Net Value': 126718.50458052989,
#      'Delta Number': -0.005691936386870378},
#     {'Asset': '^TWII',
#      'Number': 12.746721263513484,
#      'Price': 9941.262695,
#      'Net Value': 126718.50458052986,
#      'Delta Number': 0.13015728586023023},
#     {'Asset': '^IXIC',
#      'Number': 20.78930436514621,
#      'Price': 6095.370117,
#      'Net Value': 126718.50458052989,
#      'Delta Number': -0.1499745500688192}]},
#   {'Date': Timestamp('2017-05-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9983202489441036,
#      'Price': 62711.0,
#      'Net Value': 125316.66113153368,
#      'Delta Number': 0.0991190172584544},
#     {'Asset': '^TWII',
#      'Number': 12.480844455258612,
#      'Price': 10040.719727,
#      'Net Value': 125316.66113153372,
#      'Delta Number': -0.2658768082548715},
#     {'Asset': '^IXIC',
#      'Number': 20.217190672481482,
#      'Price': 6198.52002,
#      'Net Value': 125316.66113153374,
#      'Delta Number': -0.572113692664729}]},
#   {'Date': Timestamp('2017-06-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.011529622198153,
#      'Price': 62900.0,
#      'Net Value': 126525.21323626382,
#      'Delta Number': 0.01320937325404925},
#     {'Asset': '^TWII',
#      'Number': 12.171655354560931,
#      'Price': 10395.070313,
#      'Net Value': 126525.21323626382,
#      'Delta Number': -0.30918910069768124},
#     {'Asset': '^IXIC',
#      'Number': 20.605303031955053,
#      'Price': 6140.419922,
#      'Net Value': 126525.21323626381,
#      'Delta Number': 0.3881123594735705}]},
#   {'Date': Timestamp('2017-07-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9737198592586986,
#      'Price': 65920.0,
#      'Net Value': 130107.61312233341,
#      'Delta Number': -0.03780976293945426},
#     {'Asset': '^TWII',
#      'Number': 12.477557740004759,
#      'Price': 10427.330078,
#      'Net Value': 130107.61312233334,
#      'Delta Number': 0.30590238544382764},
#     {'Asset': '^IXIC',
#      'Number': 20.495455461516972,
#      'Price': 6348.120117,
#      'Net Value': 130107.61312233342,
#      'Delta Number': -0.10984757043808102}]},
#   {'Date': Timestamp('2017-08-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8994915353261217,
#      'Price': 70835.0,
#      'Net Value': 134550.48290482583,
#      'Delta Number': -0.07422832393257695},
#     {'Asset': '^TWII',
#      'Number': 12.71049270198902,
#      'Price': 10585.780273,
#      'Net Value': 134550.48290482585,
#      'Delta Number': 0.23293496198426134},
#     {'Asset': '^IXIC',
#      'Number': 20.929786244688504,
#      'Price': 6428.660156,
#      'Net Value': 134550.48290482585,
#      'Delta Number': 0.4343307831715322}]},
#   {'Date': Timestamp('2017-10-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8408512348539772,
#      'Price': 74360.0,
#      'Net Value': 136885.69782374174,
#      'Delta Number': -0.058640300472144524},
#     {'Asset': '^TWII',
#      'Number': 13.080134062282928,
#      'Price': 10465.160156,
#      'Net Value': 136885.69782374174,
#      'Delta Number': 0.36964136029390815},
#     {'Asset': '^IXIC',
#      'Number': 21.00530532347578,
#      'Price': 6516.720215,
#      'Net Value': 136885.69782374174,
#      'Delta Number': 0.07551907878727704}]},
#   {'Date': Timestamp('2017-10-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8808700852198372,
#      'Price': 74308.0,
#      'Net Value': 139763.69429251566,
#      'Delta Number': 0.04001885036586006},
#     {'Asset': '^TWII',
#      'Number': 12.948516446244737,
#      'Price': 10793.799805,
#      'Net Value': 139763.69429251575,
#      'Delta Number': -0.13161761603819144},
#     {'Asset': '^IXIC',
#      'Number': 20.774457711648083,
#      'Price': 6727.669922,
#      'Net Value': 139763.69429251575,
#      'Delta Number': -0.23084761182769853}]},
#   {'Date': Timestamp('2017-11-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9216681766889707,
#      'Price': 71971.0,
#      'Net Value': 138304.3803444819,
#      'Delta Number': 0.04079809146913349},
#     {'Asset': '^TWII',
#      'Number': 13.096459495343407,
#      'Price': 10560.44043,
#      'Net Value': 138304.3803444819,
#      'Delta Number': 0.14794304909866973},
#     {'Asset': '^IXIC',
#      'Number': 20.12001449216083,
#      'Price': 6873.970215,
#      'Net Value': 138304.3803444819,
#      'Delta Number': -0.654443219487252}]},
#   {'Date': Timestamp('2018-01-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8441678382895752,
#      'Price': 77891.0,
#      'Net Value': 143644.0770922133,
#      'Delta Number': -0.07750033839939552},
#     {'Asset': '^TWII',
#      'Number': 13.411230681974628,
#      'Price': 10710.730469,
#      'Net Value': 143644.0770922133,
#      'Delta Number': 0.31477118663122106},
#     {'Asset': '^IXIC',
#      'Number': 20.50037521603706,
#      'Price': 7006.899901999999,
#      'Net Value': 143644.0770922133,
#      'Delta Number': 0.38036072387622966}]},
#   {'Date': Timestamp('2018-01-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.7957495075589942,
#      'Price': 84913.0,
#      'Net Value': 152482.47793535687,
#      'Delta Number': -0.048418330730580994},
#     {'Asset': '^TWII',
#      'Number': 13.73247129131499,
#      'Price': 11103.790039,
#      'Net Value': 152482.47793535684,
#      'Delta Number': 0.3212406093403626},
#     {'Asset': '^IXIC',
#      'Number': 20.57382308888823,
#      'Price': 7411.47998,
#      'Net Value': 152482.47793535687,
#      'Delta Number': 0.07344787285116894}]},
#   {'Date': Timestamp('2018-03-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.7536314033048848,
#      'Price': 85378.0,
#      'Net Value': 149721.54195136446,
#      'Delta Number': -0.042118104254109445},
#     {'Asset': '^TWII',
#      'Number': 13.881369970117257,
#      'Price': 10785.790039,
#      'Net Value': 149721.54195136443,
#      'Delta Number': 0.14889867880226682},
#     {'Asset': '^IXIC',
#      'Number': 20.850956014733953,
#      'Price': 7180.560059,
#      'Net Value': 149721.54195136443,
#      'Delta Number': 0.2771329258457236}]},
#   {'Date': Timestamp('2018-04-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.743579187481332,
#      'Price': 84666.0,
#      'Net Value': 147621.87548729446,
#      'Delta Number': -0.010052215823552757},
#     {'Asset': '^TWII',
#      'Number': 13.557882183849335,
#      'Price': 10888.269531,
#      'Net Value': 147621.87548729446,
#      'Delta Number': -0.32348778626792196},
#     {'Asset': '^IXIC',
#      'Number': 21.487524668165047,
#      'Price': 6870.120117,
#      'Net Value': 147621.87548729446,
#      'Delta Number': 0.6365686534310946}]},
#   {'Date': Timestamp('2018-04-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.7282442194737735,
#      'Price': 86115.0,
#      'Net Value': 148827.750959984,
#      'Delta Number': -0.015334968007558514},
#     {'Asset': '^TWII',
#      'Number': 13.964104736944329,
#      'Price': 10657.879883,
#      'Net Value': 148827.75095998397,
#      'Delta Number': 0.40622255309499344},
#     {'Asset': '^IXIC',
#      'Number': 21.061712974277764,
#      'Price': 7066.27002,
#      'Net Value': 148827.750959984,
#      'Delta Number': -0.4258116938872831}]},
#   {'Date': Timestamp('2018-06-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.922539341922692,
#      'Price': 77240.0,
#      'Net Value': 148496.9387701087,
#      'Delta Number': 0.19429512244891844},
#     {'Asset': '^TWII',
#      'Number': 13.562503672658657,
#      'Price': 10949.080078,
#      'Net Value': 148496.93877010874,
#      'Delta Number': -0.4016010642856713},
#     {'Asset': '^IXIC',
#      'Number': 19.657194911639753,
#      'Price': 7554.330078,
#      'Net Value': 148496.93877010874,
#      'Delta Number': -1.4045180626380116}]},
#   {'Date': Timestamp('2018-07-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9905417285937799,
#      'Price': 72840.0,
#      'Net Value': 144991.05951077092,
#      'Delta Number': 0.06800238667108793},
#     {'Asset': '^TWII',
#      'Number': 13.45257569871082,
#      'Price': 10777.94043,
#      'Net Value': 144991.05951077087,
#      'Delta Number': -0.10992797394783693},
#     {'Asset': '^IXIC',
#      'Number': 19.159223044438267,
#      'Price': 7567.689941,
#      'Net Value': 144991.05951077087,
#      'Delta Number': -0.49797186720148545}]},
#   {'Date': Timestamp('2018-07-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9078862215469543,
#      'Price': 79220.0,
#      'Net Value': 151142.74647094973,
#      'Delta Number': -0.08265550704682556},
#     {'Asset': '^TWII',
#      'Number': 13.668787065934909,
#      'Price': 11057.509766,
#      'Net Value': 151142.74647094973,
#      'Delta Number': 0.21621136722408885},
#     {'Asset': '^IXIC',
#      'Number': 19.701105700573997,
#      'Price': 7671.790039,
#      'Net Value': 151142.74647094973,
#      'Delta Number': 0.54188265613573}]},
#   {'Date': Timestamp('2018-08-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9879254850805168,
#      'Price': 76678.0,
#      'Net Value': 152430.15034500387,
#      'Delta Number': 0.0800392635335625},
#     {'Asset': '^TWII',
#      'Number': 13.777202734361062,
#      'Price': 11063.94043,
#      'Net Value': 152430.1503450039,
#      'Delta Number': 0.10841566842615258},
#     {'Asset': '^IXIC',
#      'Number': 18.796399008074975,
#      'Price': 8109.540039,
#      'Net Value': 152430.1503450039,
#      'Delta Number': -0.9047066924990226}]},
#   {'Date': Timestamp('2018-10-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9486578903571887,
#      'Price': 78624.0,
#      'Net Value': 153211.2779714436,
#      'Delta Number': -0.03926759472332808},
#     {'Asset': '^TWII',
#      'Number': 13.863016040349239,
#      'Price': 11051.799805,
#      'Net Value': 153211.2779714436,
#      'Delta Number': 0.08581330598817694},
#     {'Asset': '^IXIC',
#      'Number': 19.062531159548254,
#      'Price': 8037.299805,
#      'Net Value': 153211.2779714436,
#      'Delta Number': 0.26613215147327907}]},
#   {'Date': Timestamp('2018-10-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.6986773110916071,
#      'Price': 87424.0,
#      'Net Value': 148505.16524487265,
#      'Delta Number': -0.2499805792655816},
#     {'Asset': '^TWII',
#      'Number': 15.150295600798731,
#      'Price': 9802.129883,
#      'Net Value': 148505.16524487268,
#      'Delta Number': 1.2872795604494929},
#     {'Asset': '^IXIC',
#      'Number': 20.326745128853897,
#      'Price': 7305.899901999999,
#      'Net Value': 148505.16524487265,
#      'Delta Number': 1.2642139693056436}]},
#   {'Date': Timestamp('2018-11-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.6790721257416859,
#      'Price': 89504.0,
#      'Net Value': 150283.67154238385,
#      'Delta Number': -0.019605185349921284},
#     {'Asset': '^TWII',
#      'Number': 15.198544845958303,
#      'Price': 9888.030273,
#      'Net Value': 150283.67154238382,
#      'Delta Number': 0.048249245159571075},
#     {'Asset': '^IXIC',
#      'Number': 20.501036859882543,
#      'Price': 7330.540039,
#      'Net Value': 150283.67154238382,
#      'Delta Number': 0.1742917310286458}]},
#   {'Date': Timestamp('2019-01-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.5920369938355485,
#      'Price': 91012.0,
#      'Net Value': 144894.47088296094,
#      'Delta Number': -0.08703513190613732},
#     {'Asset': '^TWII',
#      'Number': 15.165622046700163,
#      'Price': 9554.139648,
#      'Net Value': 144894.47088296094,
#      'Delta Number': -0.03292279925813979},
#     {'Asset': '^IXIC',
#      'Number': 21.736540107684263,
#      'Price': 6665.939941,
#      'Net Value': 144894.47088296097,
#      'Delta Number': 1.23550324780172}]},
#   {'Date': Timestamp('2019-02-11 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.6271704192659224,
#      'Price': 94413.0,
#      'Net Value': 153626.04079415352,
#      'Delta Number': 0.0351334254303739},
#     {'Asset': '^TWII',
#      'Number': 15.356077746373145,
#      'Price': 10004.25,
#      'Net Value': 153626.04079415355,
#      'Delta Number': 0.1904556996729827},
#     {'Asset': '^IXIC',
#      'Number': 21.02191366251606,
#      'Price': 7307.899901999999,
#      'Net Value': 153626.04079415355,
#      'Delta Number': -0.7146264451682036}]},
#   {'Date': Timestamp('2019-03-07 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.6531252310371483,
#      'Price': 94340.0,
#      'Net Value': 155955.83429604457,
#      'Delta Number': 0.025954811771225827},
#     {'Asset': '^TWII',
#      'Number': 15.12419305242141,
#      'Price': 10311.679688,
#      'Net Value': 155955.83429604457,
#      'Delta Number': -0.23188469395173605},
#     {'Asset': '^IXIC',
#      'Number': 21.014171755368523,
#      'Price': 7421.459961,
#      'Net Value': 155955.83429604457,
#      'Delta Number': -0.007741907147536864}]},
#   {'Date': Timestamp('2019-04-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.6805426897145916,
#      'Price': 96054.0,
#      'Net Value': 161422.8475178454,
#      'Delta Number': 0.027417458677443385},
#     {'Asset': '^TWII',
#      'Number': 15.167571295107628,
#      'Price': 10642.629883,
#      'Net Value': 161422.84751784545,
#      'Delta Number': 0.04337824268621837},
#     {'Asset': '^IXIC',
#      'Number': 20.618814662744924,
#      'Price': 7828.910156,
#      'Net Value': 161422.84751784545,
#      'Delta Number': -0.3953570926235983}]},
#   {'Date': Timestamp('2019-04-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.7131330021676128,
#      'Price': 96353.0,
#      'Net Value': 165065.504157856,
#      'Delta Number': 0.03259031245302113},
#     {'Asset': '^TWII',
#      'Number': 15.05010581946824,
#      'Price': 10967.730469,
#      'Net Value': 165065.50415785602,
#      'Delta Number': -0.11746547563938847},
#     {'Asset': '^IXIC',
#      'Number': 20.390061672682545,
#      'Price': 8095.390137,
#      'Net Value': 165065.50415785602,
#      'Delta Number': -0.2287529900623788}]},
#   {'Date': Timestamp('2019-05-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.6359162813020207,
#      'Price': 97030.0,
#      'Net Value': 158732.95677473507,
#      'Delta Number': -0.07721672086559206},
#     {'Asset': '^TWII',
#      'Number': 15.11959846004035,
#      'Price': 10498.490234,
#      'Net Value': 158732.95677473507,
#      'Delta Number': 0.06949264057211124},
#     {'Asset': '^IXIC',
#      'Number': 21.297432476454045,
#      'Price': 7453.149901999999,
#      'Net Value': 158732.95677473507,
#      'Delta Number': 0.9073708037714994}]},
#   {'Date': Timestamp('2019-07-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.6539690568827679,
#      'Price': 101340.0,
#      'Net Value': 167613.2242244997,
#      'Delta Number': 0.018052775580747138},
#     {'Asset': '^TWII',
#      'Number': 15.383767626558825,
#      'Price': 10895.459961,
#      'Net Value': 167613.2242244997,
#      'Delta Number': 0.26416916651847444},
#     {'Asset': '^IXIC',
#      'Number': 20.71559838056179,
#      'Price': 8091.160156,
#      'Net Value': 167613.2242244997,
#      'Delta Number': -0.5818340958922548}]},
#   {'Date': Timestamp('2019-07-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.6509631627409596,
#      'Price': 101812.0,
#      'Net Value': 168087.86152498258,
#      'Delta Number': -0.0030058941418082963},
#     {'Asset': '^TWII',
#      'Number': 15.529454804052193,
#      'Price': 10823.80957,
#      'Net Value': 168087.86152498258,
#      'Delta Number': 0.14568717749336813},
#     {'Asset': '^IXIC',
#      'Number': 20.560150197625845,
#      'Price': 8175.419922,
#      'Net Value': 168087.86152498258,
#      'Delta Number': -0.1554481829359453}]},
#   {'Date': Timestamp('2019-09-03 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.6399876235649913,
#      'Price': 99681.0,
#      'Net Value': 163475.6063045819,
#      'Delta Number': -0.010975539175968274},
#     {'Asset': '^TWII',
#      'Number': 15.48326912501545,
#      'Price': 10558.209961,
#      'Net Value': 163475.6063045819,
#      'Delta Number': -0.046185679036742755},
#     {'Asset': '^IXIC',
#      'Number': 20.7610212474553,
#      'Price': 7874.160156,
#      'Net Value': 163475.60630458195,
#      'Delta Number': 0.20087104982945547}]},
#   {'Date': Timestamp('2019-10-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.616653667012665,
#      'Price': 104053.0,
#      'Net Value': 168217.66401366884,
#      'Delta Number': -0.023333956552326285},
#     {'Asset': '^TWII',
#      'Number': 15.337620913929518,
#      'Price': 10967.650391,
#      'Net Value': 168217.66401366884,
#      'Delta Number': -0.1456482110859323},
#     {'Asset': '^IXIC',
#      'Number': 21.270004636696388,
#      'Price': 7908.680176000001,
#      'Net Value': 168217.66401366884,
#      'Delta Number': 0.508983389241088}]},
#   {'Date': Timestamp('2019-10-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.6288370850164406,
#      'Price': 107220.0,
#      'Net Value': 174643.91225546275,
#      'Delta Number': 0.012183418003775648},
#     {'Asset': '^TWII',
#      'Number': 15.375329844242934,
#      'Price': 11358.709961,
#      'Net Value': 174643.9122554628,
#      'Delta Number': 0.037708930313415934},
#     {'Asset': '^IXIC',
#      'Number': 21.060820422901806,
#      'Price': 8292.360352,
#      'Net Value': 174643.9122554628,
#      'Delta Number': -0.20918421379458252}]},
#   {'Date': Timestamp('2019-12-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.6350217206393889,
#      'Price': 109061.0,
#      'Net Value': 178317.10387465238,
#      'Delta Number': 0.006184635622948242},
#     {'Asset': '^TWII',
#      'Number': 15.50202016942742,
#      'Price': 11502.830078,
#      'Net Value': 178317.10387465238,
#      'Delta Number': 0.12669032518448553},
#     {'Asset': '^IXIC',
#      'Number': 20.812010635474817,
#      'Price': 8567.990234,
#      'Net Value': 178317.10387465238,
#      'Delta Number': -0.248809787426989}]}]]

# %%
actual_price_result
# Out:
# [[{'Date': Timestamp('2015-01-05 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.1142354479150933,
#      'Price': 47298.4218,
#      'Net Value': 100000.0,
#      'Delta Number': 2.1142354479150933},
#     {'Asset': '^TWII',
#      'Number': 10.781397910903255,
#      'Price': 9275.235069366074,
#      'Net Value': 100000.0,
#      'Delta Number': 10.781397910903255},
#     {'Asset': '^IXIC',
#      'Number': 21.49349795550752,
#      'Price': 4652.569824,
#      'Net Value': 100000.0,
#      'Delta Number': 21.49349795550752}]},
#   {'Date': Timestamp('2016-01-04 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.936639063167109,
#      'Price': 28673.739472067584,
#      'Net Value': 84204.4234207503,
#      'Delta Number': 0.8224036152520156},
#     {'Asset': '^TWII',
#      'Number': 10.46841271825419,
#      'Price': 8049.305366552161,
#      'Net Value': 84263.45067232635,
#      'Delta Number': -0.3129851926490659},
#     {'Asset': '^IXIC',
#      'Number': 17.185785566511914,
#      'Price': 4903.089844,
#      'Net Value': 84263.45067232635,
#      'Delta Number': -4.307712388995608}]},
#   {'Date': Timestamp('2017-01-03 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.0671053955027854,
#      'Price': 57206.75074209068,
#      'Net Value': 118252.38311815861,
#      'Delta Number': -0.8695336676643235},
#     {'Asset': '^TWII',
#      'Number': 13.238665600648202,
#      'Price': 8927.672887933733,
#      'Net Value': 118190.47595532791,
#      'Delta Number': 2.770252882394013},
#     {'Asset': '^IXIC',
#      'Number': 21.769818430911634,
#      'Price': 5429.080078,
#      'Net Value': 118190.08754493957,
#      'Delta Number': 4.58403286439972}]},
#   {'Date': Timestamp('2018-01-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.0147666953461214,
#      'Price': 70999.74582519341,
#      'Net Value': 143047.92326663953,
#      'Delta Number': -0.052338700156663975},
#     {'Asset': '^TWII',
#      'Number': 14.581903266998847,
#      'Price': 9807.70097319061,
#      'Net Value': 143014.9468627159,
#      'Delta Number': 1.3432376663506442},
#     {'Asset': '^IXIC',
#      'Number': 20.415294248146594,
#      'Price': 7006.899901999999,
#      'Net Value': 143047.92326663953,
#      'Delta Number': -1.35452418276504}]},
#   {'Date': Timestamp('2019-01-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8244811301998944,
#      'Price': 77461.80273351054,
#      'Net Value': 141327.5973985566,
#      'Delta Number': -0.19028556514622696},
#     {'Asset': '^TWII',
#      'Number': 15.63003504690876,
#      'Price': 9040.534979345375,
#      'Net Value': 141303.8785699728,
#      'Delta Number': 1.0481317799099141},
#     {'Asset': '^IXIC',
#      'Number': 21.199487817952175,
#      'Price': 6665.939941,
#      'Net Value': 141314.51257443032,
#      'Delta Number': 0.7841935698055806}]}],
#  [{'Date': Timestamp('2015-01-05 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.1142354479150933,
#      'Price': 47298.4218,
#      'Net Value': 100000.0,
#      'Delta Number': 2.1142354479150933},
#     {'Asset': '^TWII',
#      'Number': 10.781397910903255,
#      'Price': 9275.235069366074,
#      'Net Value': 100000.0,
#      'Delta Number': 10.781397910903255},
#     {'Asset': '^IXIC',
#      'Number': 21.49349795550752,
#      'Price': 4652.569824,
#      'Net Value': 100000.0,
#      'Delta Number': 21.49349795550752}]},
#   {'Date': Timestamp('2015-06-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.1343956334446363,
#      'Price': 47052.51508384309,
#      'Net Value': 100428.68273754258,
#      'Delta Number': 0.020160185529543018},
#     {'Asset': '^TWII',
#      'Number': 11.440940619904246,
#      'Price': 8776.950293141388,
#      'Net Value': 100416.56712768179,
#      'Delta Number': 0.6595427090009913},
#     {'Asset': '^IXIC',
#      'Number': 20.139096230280398,
#      'Price': 4986.870117,
#      'Net Value': 100431.05717417267,
#      'Delta Number': -1.3544017252271239}]},
#   {'Date': Timestamp('2016-01-04 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.927948039289976,
#      'Price': 28673.739472067584,
#      'Net Value': 83955.21926635187,
#      'Delta Number': 0.7935524058453396},
#     {'Asset': '^TWII',
#      'Number': 10.437195748395112,
#      'Price': 8049.305366552161,
#      'Net Value': 84012.17574931217,
#      'Delta Number': -1.0037448715091344},
#     {'Asset': '^IXIC',
#      'Number': 17.134537286139963,
#      'Price': 4903.089844,
#      'Net Value': 84012.17574931218,
#      'Delta Number': -3.0045589441404346}]},
#   {'Date': Timestamp('2016-06-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.1376964984718807,
#      'Price': 48635.411216243185,
#      'Net Value': 103967.74825870308,
#      'Delta Number': -0.7902515408180952},
#     {'Asset': '^TWII',
#      'Number': 12.536087108327484,
#      'Price': 8290.00256469994,
#      'Net Value': 103924.1942793367,
#      'Delta Number': 2.098891359932372},
#     {'Asset': '^IXIC',
#      'Number': 21.458273709986585,
#      'Price': 4842.669922,
#      'Net Value': 103915.33667339539,
#      'Delta Number': 4.323736423846622}]},
#   {'Date': Timestamp('2017-01-03 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.043508487523269,
#      'Price': 57206.75074209068,
#      'Net Value': 116902.48068509037,
#      'Delta Number': -0.09418801094861173},
#     {'Asset': '^TWII',
#      'Number': 13.093001582825273,
#      'Price': 8927.672887933733,
#      'Net Value': 116890.03525266265,
#      'Delta Number': 0.5569144744977894},
#     {'Asset': '^IXIC',
#      'Number': 21.532464207544447,
#      'Price': 5429.080078,
#      'Net Value': 116901.4724594276,
#      'Delta Number': 0.07419049755786133}]},
#   {'Date': Timestamp('2017-06-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.218345987944024,
#      'Price': 56188.62082630116,
#      'Net Value': 124645.8015781332,
#      'Delta Number': 0.1748375004207552},
#     {'Asset': '^TWII',
#      'Number': 12.855779500737164,
#      'Price': 9697.614369013503,
#      'Net Value': 124670.39201121796,
#      'Delta Number': -0.2372220820881097},
#     {'Asset': '^IXIC',
#      'Number': 20.303235543313054,
#      'Price': 6140.419922,
#      'Net Value': 124670.39201121798,
#      'Delta Number': -1.2292286642313925}]},
#   {'Date': Timestamp('2018-01-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9993047233533534,
#      'Price': 70999.74582519341,
#      'Net Value': 141950.12718519673,
#      'Delta Number': -0.21904126459067075},
#     {'Asset': '^TWII',
#      'Number': 14.469294676965953,
#      'Price': 9807.70097319061,
#      'Net Value': 141910.5154846607,
#      'Delta Number': 1.6135151762287894},
#     {'Asset': '^IXIC',
#      'Number': 20.258620669702946,
#      'Price': 7006.899901999999,
#      'Net Value': 141950.12718519673,
#      'Delta Number': -0.044614873610107963}]},
#   {'Date': Timestamp('2018-07-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.4314890392660646,
#      'Price': 56656.55389335704,
#      'Net Value': 137759.78979428473,
#      'Delta Number': 0.4321843159127112},
#     {'Asset': '^TWII',
#      'Number': 13.57702389340098,
#      'Price': 10151.052445373343,
#      'Net Value': 137821.08159400034,
#      'Delta Number': -0.8922707835649728},
#     {'Asset': '^IXIC',
#      'Number': 18.211776997801863,
#      'Price': 7567.689941,
#      'Net Value': 137821.08159400034,
#      'Delta Number': -2.046843671901083}]},
#   {'Date': Timestamp('2019-01-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8610880036195987,
#      'Price': 77461.80273351054,
#      'Net Value': 144163.2318060843,
#      'Delta Number': -0.5704010356464659},
#     {'Asset': '^TWII',
#      'Number': 15.940400629750497,
#      'Price': 9040.534979345375,
#      'Net Value': 144109.74947803843,
#      'Delta Number': 2.363376736349517},
#     {'Asset': '^IXIC',
#      'Number': 21.618315283649405,
#      'Price': 6665.939941,
#      'Net Value': 144106.39130640932,
#      'Delta Number': 3.4065382858475424}]},
#   {'Date': Timestamp('2019-07-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8694102943901167,
#      'Price': 90118.93341839172,
#      'Net Value': 168469.261851799,
#      'Delta Number': 0.008322290770518048},
#     {'Asset': '^TWII',
#      'Number': 16.496633173945416,
#      'Price': 10211.594062102544,
#      'Net Value': 168456.92136374486,
#      'Delta Number': 0.5562325441949181},
#     {'Asset': '^IXIC',
#      'Number': 20.821629524099773,
#      'Price': 8091.160156,
#      'Net Value': 168471.13918838932,
#      'Delta Number': -0.7966857595496322}]}],
#  [{'Date': Timestamp('2015-01-05 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.1142354479150933,
#      'Price': 47298.4218,
#      'Net Value': 100000.0,
#      'Delta Number': 2.1142354479150933},
#     {'Asset': '^TWII',
#      'Number': 10.781397910903255,
#      'Price': 9275.235069366074,
#      'Net Value': 100000.0,
#      'Delta Number': 10.781397910903255},
#     {'Asset': '^IXIC',
#      'Number': 21.49349795550752,
#      'Price': 4652.569824,
#      'Net Value': 100000.0,
#      'Delta Number': 21.49349795550752}]},
#   {'Date': Timestamp('2015-03-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.2846644868340227,
#      'Price': 43240.451252545034,
#      'Net Value': 98789.92337136737,
#      'Delta Number': 0.17042903891892935},
#     {'Asset': '^TWII',
#      'Number': 10.68845587457883,
#      'Price': 9244.400796567012,
#      'Net Value': 98808.37000102788,
#      'Delta Number': -0.0929420363244251},
#     {'Asset': '^IXIC',
#      'Number': 20.161353136560418,
#      'Price': 4900.879883,
#      'Net Value': 98808.3700010279,
#      'Delta Number': -1.3321448189471035}]},
#   {'Date': Timestamp('2015-06-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.138414245494391,
#      'Price': 47052.51508384309,
#      'Net Value': 100617.76854162978,
#      'Delta Number': -0.1462502413396316},
#     {'Asset': '^TWII',
#      'Number': 11.461928359674564,
#      'Price': 8776.950293141388,
#      'Net Value': 100600.77547641126,
#      'Delta Number': 0.7734724850957342},
#     {'Asset': '^IXIC',
#      'Number': 20.176498910065728,
#      'Price': 4986.870117,
#      'Net Value': 100617.57948028986,
#      'Delta Number': 0.01514577350530999}]},
#   {'Date': Timestamp('2015-09-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.6852748642863875,
#      'Price': 31645.96668351943,
#      'Net Value': 84978.11889129918,
#      'Delta Number': 0.5468606187919964},
#     {'Asset': '^TWII',
#      'Number': 10.348027066554621,
#      'Price': 8216.197863177838,
#      'Net Value': 85021.43787233252,
#      'Delta Number': -1.1139012931199428},
#     {'Asset': '^IXIC',
#      'Number': 18.40227070092341,
#      'Price': 4620.160156,
#      'Net Value': 85021.43787233254,
#      'Delta Number': -1.7742282091423185}]},
#   {'Date': Timestamp('2016-01-04 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.9117295956813924,
#      'Price': 28673.739472067584,
#      'Net Value': 83490.17583967693,
#      'Delta Number': 0.22645473139500494},
#     {'Asset': '^TWII',
#      'Number': 10.3742989334461,
#      'Price': 8049.305366552161,
#      'Net Value': 83505.90007920406,
#      'Delta Number': 0.02627186689147898},
#     {'Asset': '^IXIC',
#      'Number': 17.03138879226576,
#      'Price': 4903.089844,
#      'Net Value': 83506.42941657366,
#      'Delta Number': -1.3708819086576511}]},
#   {'Date': Timestamp('2016-03-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.4005809230589708,
#      'Price': 39711.224799071155,
#      'Net Value': 95330.00868395652,
#      'Delta Number': -0.5111486726224217},
#     {'Asset': '^TWII',
#      'Number': 11.310474535671805,
#      'Price': 8426.72528576602,
#      'Net Value': 95310.26176375829,
#      'Delta Number': 0.9361756022257044},
#     {'Asset': '^IXIC',
#      'Number': 19.569200527712983,
#      'Price': 4869.850098,
#      'Net Value': 95299.07310766472,
#      'Delta Number': 2.5378117354472245}]},
#   {'Date': Timestamp('2016-06-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.0923320026726953,
#      'Price': 48635.411216243185,
#      'Net Value': 101761.42735089216,
#      'Delta Number': -0.3082489203862755},
#     {'Asset': '^TWII',
#      'Number': 12.27278973762979,
#      'Price': 8290.00256469994,
#      'Net Value': 101741.45840097406,
#      'Delta Number': 0.9623152019579848},
#     {'Asset': '^IXIC',
#      'Number': 21.00989024608507,
#      'Price': 4842.669922,
#      'Net Value': 101743.96355923735,
#      'Delta Number': 1.440689718372088}]},
#   {'Date': Timestamp('2016-09-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.0484005004429195,
#      'Price': 53548.59012993121,
#      'Net Value': 109688.95882016387,
#      'Delta Number': -0.04393150222977571},
#     {'Asset': '^TWII',
#      'Number': 12.768422613946107,
#      'Price': 8589.808258769133,
#      'Net Value': 109678.30202072884,
#      'Delta Number': 0.4956328763163178},
#     {'Asset': '^IXIC',
#      'Number': 20.649276886326028,
#      'Price': 5312.0,
#      'Net Value': 109688.95882016385,
#      'Delta Number': -0.36061335975904285}]},
#   {'Date': Timestamp('2017-01-03 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.0002372130130617,
#      'Price': 57206.75074209068,
#      'Net Value': 114427.07166989235,
#      'Delta Number': -0.04816328742985787},
#     {'Asset': '^TWII',
#      'Number': 12.817000301760105,
#      'Price': 8927.672887933733,
#      'Net Value': 114425.98609866216,
#      'Delta Number': 0.04857768781399763},
#     {'Asset': '^IXIC',
#      'Number': 21.07562902623106,
#      'Price': 5429.080078,
#      'Net Value': 114421.27767762958,
#      'Delta Number': 0.4263521399050312}]},
#   {'Date': Timestamp('2017-03-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9562320304738439,
#      'Price': 62078.5653450955,
#      'Net Value': 121440.07793393936,
#      'Delta Number': -0.04400518253921781},
#     {'Asset': '^TWII',
#      'Number': 13.468155970232974,
#      'Price': 9015.739289714926,
#      'Net Value': 121425.38294083807,
#      'Delta Number': 0.6511556684728692},
#     {'Asset': '^IXIC',
#      'Number': 20.54218776994039,
#      'Price': 5911.740234000001,
#      'Net Value': 121440.07793393936,
#      'Delta Number': -0.5334412562906685}]},
#   {'Date': Timestamp('2017-06-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.174654196283073,
#      'Price': 56188.62082630116,
#      'Net Value': 122190.8200632743,
#      'Delta Number': 0.21842216580922935},
#     {'Asset': '^TWII',
#      'Number': 12.603258483351174,
#      'Price': 9697.614369013503,
#      'Net Value': 122221.54056453767,
#      'Delta Number': -0.8648974868817998},
#     {'Asset': '^IXIC',
#      'Number': 19.904427077802985,
#      'Price': 6140.419922,
#      'Net Value': 122221.5405645377,
#      'Delta Number': -0.6377606921374053}]},
#   {'Date': Timestamp('2017-10-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.928743452867418,
#      'Price': 69773.72855508298,
#      'Net Value': 134575.62213276472,
#      'Delta Number': -0.2459107434156551},
#     {'Asset': '^TWII',
#      'Number': 13.867214120924878,
#      'Price': 9702.375989613154,
#      'Net Value': 134544.92532968603,
#      'Delta Number': 1.2639556375737033},
#     {'Asset': '^IXIC',
#      'Number': 20.64895726298196,
#      'Price': 6516.720215,
#      'Net Value': 134563.47721434562,
#      'Delta Number': 0.7445301851789736}]},
#   {'Date': Timestamp('2018-01-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9606359251847896,
#      'Price': 70999.74582519341,
#      'Net Value': 139204.65234386298,
#      'Delta Number': 0.03189247231737147},
#     {'Asset': '^TWII',
#      'Number': 14.193165006587918,
#      'Price': 9807.70097319061,
#      'Net Value': 139202.31824776722,
#      'Delta Number': 0.3259508856630404},
#     {'Asset': '^IXIC',
#      'Number': 19.86760511344991,
#      'Price': 7006.899901999999,
#      'Net Value': 139210.32032240686,
#      'Delta Number': -0.7813521495320508}]},
#   {'Date': Timestamp('2018-04-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8781423248327536,
#      'Price': 75141.62727647192,
#      'Net Value': 141126.6705447492,
#      'Delta Number': -0.08249360035203601},
#     {'Asset': '^TWII',
#      'Number': 14.351911522905532,
#      'Price': 9833.029073349602,
#      'Net Value': 141122.76326287125,
#      'Delta Number': 0.15874651631761338},
#     {'Asset': '^IXIC',
#      'Number': 20.540412396251828,
#      'Price': 6870.120117,
#      'Net Value': 141115.10041496585,
#      'Delta Number': 0.6728072828019194}]},
#   {'Date': Timestamp('2018-07-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.396422052319524,
#      'Price': 56656.55389335704,
#      'Net Value': 135773.0151584704,
#      'Delta Number': 0.5182797274867705},
#     {'Asset': '^TWII',
#      'Number': 13.382505668743384,
#      'Price': 10151.052445373343,
#      'Net Value': 135846.51689392017,
#      'Delta Number': -0.9694058541621473},
#     {'Asset': '^IXIC',
#      'Number': 17.95085659600495,
#      'Price': 7567.689941,
#      'Net Value': 135846.51689392017,
#      'Delta Number': -2.5895558002468775}]},
#   {'Date': Timestamp('2018-10-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.3211900603192315,
#      'Price': 62148.69739626856,
#      'Net Value': 144258.9386580063,
#      'Delta Number': -0.07523199200029262},
#     {'Asset': '^TWII',
#      'Number': 13.831382708007169,
#      'Price': 10428.98050983001,
#      'Net Value': 144247.2206858066,
#      'Delta Number': 0.44887703926378464},
#     {'Asset': '^IXIC',
#      'Number': 17.948682039739627,
#      'Price': 8037.299805,
#      'Net Value': 144258.9386580063,
#      'Delta Number': -0.0021745562653237016}]},
#   {'Date': Timestamp('2019-01-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8266702093213611,
#      'Price': 77461.80273351054,
#      'Net Value': 141497.1674136317,
#      'Delta Number': -0.4945198509978703},
#     {'Asset': '^TWII',
#      'Number': 15.646870889942766,
#      'Price': 9040.534979345375,
#      'Net Value': 141456.0835978285,
#      'Delta Number': 1.8154881819355975},
#     {'Asset': '^IXIC',
#      'Number': 21.218703744936747,
#      'Price': 6665.939941,
#      'Net Value': 141442.60478962012,
#      'Delta Number': 3.27002170519712}]},
#   {'Date': Timestamp('2019-04-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8757028364893,
#      'Price': 84697.01268536378,
#      'Net Value': 158866.42693610708,
#      'Delta Number': 0.04903262716793888},
#     {'Asset': '^TWII',
#      'Number': 15.955344130789188,
#      'Price': 9957.111081671206,
#      'Net Value': 158869.13385655865,
#      'Delta Number': 0.30847324084642125},
#     {'Asset': '^IXIC',
#      'Number': 20.293606524666387,
#      'Price': 7828.910156,
#      'Net Value': 158876.82222282854,
#      'Delta Number': -0.9250972202703593}]},
#   {'Date': Timestamp('2019-07-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.835221664425147,
#      'Price': 90118.93341839172,
#      'Net Value': 165388.21898431986,
#      'Delta Number': -0.04048117206415314},
#     {'Asset': '^TWII',
#      'Number': 16.195520390690287,
#      'Price': 10211.594062102544,
#      'Net Value': 165382.0798542336,
#      'Delta Number': 0.2401762599010997},
#     {'Asset': '^IXIC',
#      'Number': 20.440239225493798,
#      'Price': 8091.160156,
#      'Net Value': 165385.2492004237,
#      'Delta Number': 0.14663270082741064}]},
#   {'Date': Timestamp('2019-10-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8662899484074118,
#      'Price': 87081.34157845649,
#      'Net Value': 162519.03248170577,
#      'Delta Number': 0.03106828398226491},
#     {'Asset': '^TWII',
#      'Number': 15.846205561940574,
#      'Price': 10256.449342475595,
#      'Net Value': 162525.8046164985,
#      'Delta Number': -0.34931482874971387},
#     {'Asset': '^IXIC',
#      'Number': 20.550032052368373,
#      'Price': 7908.680176000001,
#      'Net Value': 162523.63110873036,
#      'Delta Number': 0.1097928268745747}]}],
#  [{'Date': Timestamp('2015-01-05 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.1142354479150933,
#      'Price': 47298.4218,
#      'Net Value': 100000.0,
#      'Delta Number': 2.1142354479150933},
#     {'Asset': '^TWII',
#      'Number': 10.781397910903255,
#      'Price': 9275.235069366074,
#      'Net Value': 100000.0,
#      'Delta Number': 10.781397910903255},
#     {'Asset': '^IXIC',
#      'Number': 21.49349795550752,
#      'Price': 4652.569824,
#      'Net Value': 100000.0,
#      'Delta Number': 21.49349795550752}]},
#   {'Date': Timestamp('2015-02-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.1012241453128966,
#      'Price': 47618.322865483475,
#      'Net Value': 100056.76976425908,
#      'Delta Number': -0.01301130260219674},
#     {'Asset': '^TWII',
#      'Number': 10.898882389107104,
#      'Price': 9180.213758253549,
#      'Net Value': 100054.07005806835,
#      'Delta Number': 0.11748447820384911},
#     {'Asset': '^IXIC',
#      'Number': 21.3947837095363,
#      'Price': 4676.689941,
#      'Net Value': 100056.76976425906,
#      'Delta Number': -0.09871424597122314}]},
#   {'Date': Timestamp('2015-03-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.1608221861455643,
#      'Price': 47580.76093187208,
#      'Net Value': 102813.56385527729,
#      'Delta Number': 0.05959804083266773},
#     {'Asset': '^TWII',
#      'Number': 11.058061380489669,
#      'Price': 9297.918846379222,
#      'Net Value': 102816.95731407312,
#      'Delta Number': 0.1591789913825643},
#     {'Asset': '^IXIC',
#      'Number': 20.530871990635227,
#      'Price': 5008.100098,
#      'Net Value': 102820.66202832574,
#      'Delta Number': -0.8639117189010719}]},
#   {'Date': Timestamp('2015-03-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.283660477215033,
#      'Price': 43240.451252545034,
#      'Net Value': 98746.50954238037,
#      'Delta Number': 0.12283829106946875},
#     {'Asset': '^TWII',
#      'Number': 10.683202437130337,
#      'Price': 9244.400796567012,
#      'Net Value': 98759.80511969433,
#      'Delta Number': -0.3748589433593317},
#     {'Asset': '^IXIC',
#      'Number': 20.15144371570274,
#      'Price': 4900.879883,
#      'Net Value': 98759.80511969433,
#      'Delta Number': -0.37942827493248643}]},
#   {'Date': Timestamp('2015-04-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.0728756402186246,
#      'Price': 50503.41644344958,
#      'Net Value': 104687.30169344337,
#      'Delta Number': -0.2107848369964085},
#     {'Asset': '^TWII',
#      'Number': 11.278061144943761,
#      'Price': 9281.159290368278,
#      'Net Value': 104673.48197273628,
#      'Delta Number': 0.5948587078134242},
#     {'Asset': '^IXIC',
#      'Number': 21.183089659576694,
#      'Price': 4941.419922,
#      'Net Value': 104674.54125334448,
#      'Delta Number': 1.0316459438739543}]},
#   {'Date': Timestamp('2015-06-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.235551585866532,
#      'Price': 45305.437310329675,
#      'Net Value': 101282.64222748425,
#      'Delta Number': 0.16267594564790722},
#     {'Asset': '^TWII',
#      'Number': 11.165909654395788,
#      'Price': 9072.354486600287,
#      'Net Value': 101301.09055003109,
#      'Delta Number': -0.1121514905479728},
#     {'Asset': '^IXIC',
#      'Number': 19.92966400135556,
#      'Price': 5082.930176,
#      'Net Value': 101301.09055003109,
#      'Delta Number': -1.2534256582211327}]},
#   {'Date': Timestamp('2015-06-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.1435453842731533,
#      'Price': 47052.51508384309,
#      'Net Value': 100859.20152641479,
#      'Delta Number': -0.09200620159337847},
#     {'Asset': '^TWII',
#      'Number': 11.490559437493097,
#      'Price': 8776.950293141388,
#      'Net Value': 100852.06902326358,
#      'Delta Number': 0.32464978309730874},
#     {'Asset': '^IXIC',
#      'Number': 20.224213257410526,
#      'Price': 4986.870117,
#      'Net Value': 100855.52473321579,
#      'Delta Number': 0.29454925605496385}]},
#   {'Date': Timestamp('2015-07-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.359465509522444,
#      'Price': 40421.25923491148,
#      'Net Value': 95372.5670162392,
#      'Delta Number': 0.2159201252492906},
#     {'Asset': '^TWII',
#      'Number': 11.439164149526638,
#      'Price': 8339.28182916883,
#      'Net Value': 95394.41373302702,
#      'Delta Number': -0.05139528796645898},
#     {'Asset': '^IXIC',
#      'Number': 18.601639873871864,
#      'Price': 5128.279785,
#      'Net Value': 95394.41373302703,
#      'Delta Number': -1.6225733835386613}]},
#   {'Date': Timestamp('2015-08-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.507442426548445,
#      'Price': 35033.72239952045,
#      'Net Value': 87845.04190447817,
#      'Delta Number': 0.14797691702600124},
#     {'Asset': '^TWII',
#      'Number': 10.916765036466966,
#      'Price': 8047.990250538455,
#      'Net Value': 87858.01858090523,
#      'Delta Number': -0.5223991130596719},
#     {'Asset': '^IXIC',
#      'Number': 18.393769276113158,
#      'Price': 4776.509765999999,
#      'Net Value': 87858.01858090523,
#      'Delta Number': -0.2078705977587063}]},
#   {'Date': Timestamp('2015-09-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.675296291099949,
#      'Price': 31645.96668351943,
#      'Net Value': 84662.33729669209,
#      'Delta Number': 0.16785386455150375},
#     {'Asset': '^TWII',
#      'Number': 10.305938960056997,
#      'Price': 8216.197863177838,
#      'Net Value': 84675.63366166153,
#      'Delta Number': -0.6108260764099693},
#     {'Asset': '^IXIC',
#      'Number': 18.327423899298598,
#      'Price': 4620.160156,
#      'Net Value': 84675.63366166153,
#      'Delta Number': -0.0663453768145601}]},
#   {'Date': Timestamp('2015-11-03 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.627392697502842,
#      'Price': 35109.55327723688,
#      'Net Value': 92246.58389319916,
#      'Delta Number': -0.04790359359710683},
#     {'Asset': '^TWII',
#      'Number': 10.739410833042154,
#      'Price': 8588.670860093129,
#      'Net Value': 92237.26487631763,
#      'Delta Number': 0.433471872985157},
#     {'Asset': '^IXIC',
#      'Number': 17.92891258158335,
#      'Price': 5145.129883,
#      'Net Value': 92246.58389319916,
#      'Delta Number': -0.39851131771524706}]},
#   {'Date': Timestamp('2015-11-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.741949952391084,
#      'Price': 32024.789231665156,
#      'Net Value': 87810.36930909878,
#      'Delta Number': 0.11455725488824209},
#     {'Asset': '^TWII',
#      'Number': 10.751071643436399,
#      'Price': 8168.42422377243,
#      'Net Value': 87819.31404375876,
#      'Delta Number': 0.011660810394245047},
#     {'Asset': '^IXIC',
#      'Number': 17.19029685001132,
#      'Price': 5108.669922,
#      'Net Value': 87819.55246790417,
#      'Delta Number': -0.7386157315720325}]},
#   {'Date': Timestamp('2016-01-04 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.899427412860481,
#      'Price': 28673.739472067584,
#      'Net Value': 83137.42625453237,
#      'Delta Number': 0.15747746046939692},
#     {'Asset': '^TWII',
#      'Number': 10.329926032838653,
#      'Price': 8049.305366552161,
#      'Net Value': 83148.72905221504,
#      'Delta Number': -0.4211456105977458},
#     {'Asset': '^IXIC',
#      'Number': 16.958434721314692,
#      'Price': 4903.089844,
#      'Net Value': 83148.72905221504,
#      'Delta Number': -0.23186212869662626}]},
#   {'Date': Timestamp('2016-02-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.8915355275669783,
#      'Price': 28155.928605647412,
#      'Net Value': 81413.86787486887,
#      'Delta Number': -0.00789188529350282},
#     {'Asset': '^TWII',
#      'Number': 9.98203421471152,
#      'Price': 8156.039753388255,
#      'Net Value': 81413.86787486887,
#      'Delta Number': -0.3478918181271329},
#     {'Asset': '^IXIC',
#      'Number': 17.618984260067673,
#      'Price': 4620.370117,
#      'Net Value': 81406.22836711004,
#      'Delta Number': 0.6605495387529814}]},
#   {'Date': Timestamp('2016-03-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.700655977328141,
#      'Price': 31969.490673840588,
#      'Net Value': 86338.59608044384,
#      'Delta Number': -0.1908795502388374},
#     {'Asset': '^TWII',
#      'Number': 10.26547656828636,
#      'Price': 8409.997205109012,
#      'Net Value': 86332.62924840034,
#      'Delta Number': 0.2834423535748396},
#     {'Asset': '^IXIC',
#      'Number': 18.408675441270674,
#      'Price': 4689.600098,
#      'Net Value': 86329.32615343314,
#      'Delta Number': 0.7896911812030005}]},
#   {'Date': Timestamp('2016-03-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.3788252895304063,
#      'Price': 39711.224799071155,
#      'Net Value': 94466.06583025749,
#      'Delta Number': -0.3218306877977346},
#     {'Asset': '^TWII',
#      'Number': 11.207934659022731,
#      'Price': 8426.72528576602,
#      'Net Value': 94446.18639240021,
#      'Delta Number': 0.9424580907363715},
#     {'Asset': '^IXIC',
#      'Number': 19.39567595078095,
#      'Price': 4869.850098,
#      'Net Value': 94454.03442968686,
#      'Delta Number': 0.9870005095102776}]},
#   {'Date': Timestamp('2016-05-03 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.1605943149014557,
#      'Price': 44281.435757210136,
#      'Net Value': 95674.21835270226,
#      'Delta Number': -0.21823097462895058},
#     {'Asset': '^TWII',
#      'Number': 12.006094326376324,
#      'Price': 7967.478644952813,
#      'Net Value': 95658.3001546925,
#      'Delta Number': 0.7981596673535929},
#     {'Asset': '^IXIC',
#      'Number': 20.084313435315917,
#      'Price': 4763.220215,
#      'Net Value': 95666.00775949287,
#      'Delta Number': 0.688637484534965}]},
#   {'Date': Timestamp('2016-05-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.371456229520367,
#      'Price': 40038.423657617794,
#      'Net Value': 94949.36920303335,
#      'Delta Number': 0.21086191461891124},
#     {'Asset': '^TWII',
#      'Number': 11.514336384182535,
#      'Price': 8248.022195725633,
#      'Net Value': 94970.50206578877,
#      'Delta Number': -0.49175794219378943},
#     {'Asset': '^IXIC',
#      'Number': 19.193521853765734,
#      'Price': 4948.049805,
#      'Net Value': 94970.50206578878,
#      'Delta Number': -0.8907915815501823}]},
#   {'Date': Timestamp('2016-06-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.0817377739286287,
#      'Price': 48635.411216243185,
#      'Net Value': 101246.17267940554,
#      'Delta Number': -0.28971845559173826},
#     {'Asset': '^TWII',
#      'Number': 12.21130020544003,
#      'Price': 8290.00256469994,
#      'Net Value': 101231.71002141877,
#      'Delta Number': 0.696963821257496},
#     {'Asset': '^IXIC',
#      'Number': 20.9028190038406,
#      'Price': 4842.669922,
#      'Net Value': 101225.45287490888,
#      'Delta Number': 1.7092971500748675}]},
#   {'Date': Timestamp('2016-08-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.0207776355950937,
#      'Price': 53274.46810408802,
#      'Net Value': 107655.85369296522,
#      'Delta Number': -0.060960138333534974},
#     {'Asset': '^TWII',
#      'Number': 12.676000509430727,
#      'Price': 8492.10881235253,
#      'Net Value': 107645.97563152183,
#      'Delta Number': 0.4647003039906963},
#     {'Asset': '^IXIC',
#      'Number': 20.766145141693396,
#      'Price': 5184.200195,
#      'Net Value': 107655.85369296522,
#      'Delta Number': -0.13667386214720523}]},
#   {'Date': Timestamp('2016-08-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9814469012558102,
#      'Price': 55045.498805776864,
#      'Net Value': 109069.73303678697,
#      'Delta Number': -0.03933073433928347},
#     {'Asset': '^TWII',
#      'Number': 12.834909985017042,
#      'Price': 8497.632866378612,
#      'Net Value': 109066.35292569183,
#      'Delta Number': 0.15890947558631474},
#     {'Asset': '^IXIC',
#      'Number': 20.92136970186913,
#      'Price': 5213.220215,
#      'Net Value': 109067.70745527267,
#      'Delta Number': 0.15522456017573205}]},
#   {'Date': Timestamp('2016-09-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.03842595159701,
#      'Price': 53548.59012993121,
#      'Net Value': 109154.83579228327,
#      'Delta Number': 0.056979050341199544},
#     {'Asset': '^TWII',
#      'Number': 12.70837135359151,
#      'Price': 8589.808258769133,
#      'Net Value': 109162.47320858542,
#      'Delta Number': -0.12653863142553234},
#     {'Asset': '^IXIC',
#      'Number': 20.550164384146353,
#      'Price': 5312.0,
#      'Net Value': 109162.47320858542,
#      'Delta Number': -0.3712053177227759}]},
#   {'Date': Timestamp('2016-10-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8715904892504804,
#      'Price': 60754.3832457377,
#      'Net Value': 113707.32586300142,
#      'Delta Number': -0.16683546234652935},
#     {'Asset': '^TWII',
#      'Number': 13.05969615353562,
#      'Price': 8706.149686807197,
#      'Net Value': 113699.6695769013,
#      'Delta Number': 0.3513247999441109},
#     {'Asset': '^IXIC',
#      'Number': 21.909154661256437,
#      'Price': 5189.140136999999,
#      'Net Value': 113689.6738204664,
#      'Delta Number': 1.3589902771100846}]},
#   {'Date': Timestamp('2016-11-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.0343097092193867,
#      'Price': 54648.46186636071,
#      'Net Value': 111171.896568643,
#      'Delta Number': 0.16271921996890626},
#     {'Asset': '^TWII',
#      'Number': 12.66432114886928,
#      'Price': 8780.111778014903,
#      'Net Value': 111194.1552797504,
#      'Delta Number': -0.3953750046663398},
#     {'Asset': '^IXIC',
#      'Number': 20.88670836783761,
#      'Price': 5323.680176,
#      'Net Value': 111194.1552797504,
#      'Delta Number': -1.0224462934188274}]},
#   {'Date': Timestamp('2017-01-03 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.997635901823454,
#      'Price': 57206.75074209068,
#      'Net Value': 114278.25910906585,
#      'Delta Number': -0.036673807395932734},
#     {'Asset': '^TWII',
#      'Number': 12.800113308403002,
#      'Price': 8927.672887933733,
#      'Net Value': 114275.22454590925,
#      'Delta Number': 0.1357921595337217},
#     {'Asset': '^IXIC',
#      'Number': 21.0488800321685,
#      'Price': 5429.080078,
#      'Net Value': 114276.05524685801,
#      'Delta Number': 0.16217166433089147}]},
#   {'Date': Timestamp('2017-02-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.909295525788185,
#      'Price': 62072.13532047412,
#      'Net Value': 118514.0502435,
#      'Delta Number': -0.08834037603526901},
#     {'Asset': '^TWII',
#      'Number': 13.433961551728629,
#      'Price': 8820.931522185449,
#      'Net Value': 118500.0549194704,
#      'Delta Number': 0.6338482433256267},
#     {'Asset': '^IXIC',
#      'Number': 21.027296075933652,
#      'Price': 5636.200195,
#      'Net Value': 118514.0502435,
#      'Delta Number': -0.02158395623484921}]},
#   {'Date': Timestamp('2017-03-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9022357998615647,
#      'Price': 64687.80425872521,
#      'Net Value': 123051.45707538449,
#      'Delta Number': -0.007059725926620297},
#     {'Asset': '^TWII',
#      'Number': 13.605023424075625,
#      'Price': 9044.275821672823,
#      'Net Value': 123047.58440765958,
#      'Delta Number': 0.17106187234699632},
#     {'Asset': '^IXIC',
#      'Number': 20.84194381742681,
#      'Price': 5904.029785,
#      'Net Value': 123051.45707538447,
#      'Delta Number': -0.18535225850684256}]},
#   {'Date': Timestamp('2017-03-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9541654529473642,
#      'Price': 62078.5653450955,
#      'Net Value': 121311.7877659211,
#      'Delta Number': 0.051929653085799554},
#     {'Asset': '^TWII',
#      'Number': 13.456451351355735,
#      'Price': 9015.739289714926,
#      'Net Value': 121319.85714855541,
#      'Delta Number': -0.14857207271989026},
#     {'Asset': '^IXIC',
#      'Number': 20.521851831515267,
#      'Price': 5911.740234000001,
#      'Net Value': 121319.85714855541,
#      'Delta Number': -0.3200919859115423}]},
#   {'Date': Timestamp('2017-05-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9719016616082063,
#      'Price': 62569.04919645355,
#      'Net Value': 123380.01207573236,
#      'Delta Number': 0.017736208660842134},
#     {'Asset': '^TWII',
#      'Number': 13.521273034529743,
#      'Price': 9124.977284719762,
#      'Net Value': 123381.30930057775,
#      'Delta Number': 0.06482168317400827},
#     {'Asset': '^IXIC',
#      'Number': 20.24205052752561,
#      'Price': 6095.370117,
#      'Net Value': 123382.78989228369,
#      'Delta Number': -0.2798013039896574}]},
#   {'Date': Timestamp('2017-05-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.1122965522872987,
#      'Price': 57428.083942043944,
#      'Net Value': 121305.14371524501,
#      'Delta Number': 0.1403948906790924},
#     {'Asset': '^TWII',
#      'Number': 13.096261092670396,
#      'Price': 9264.119324427153,
#      'Net Value': 121325.32546635128,
#      'Delta Number': -0.42501194185934743},
#     {'Asset': '^IXIC',
#      'Number': 19.57327314824923,
#      'Price': 6198.52002,
#      'Net Value': 121325.32546635126,
#      'Delta Number': -0.6687773792763814}]},
#   {'Date': Timestamp('2017-06-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.170386815415719,
#      'Price': 56188.62082630116,
#      'Net Value': 121951.04181779712,
#      'Delta Number': 0.05809026312842036},
#     {'Asset': '^TWII',
#      'Number': 12.576207654710842,
#      'Price': 9697.614369013503,
#      'Net Value': 121959.21206002147,
#      'Delta Number': -0.5200534379595538},
#     {'Asset': '^IXIC',
#      'Number': 19.860985306825626,
#      'Price': 6140.419922,
#      'Net Value': 121954.78984858135,
#      'Delta Number': 0.2877121585763973}]},
#   {'Date': Timestamp('2017-07-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.044321963663089,
#      'Price': 62429.83020291489,
#      'Net Value': 127626.67307157618,
#      'Delta Number': -0.12606485175263016},
#     {'Asset': '^TWII',
#      'Number': 13.230159911631997,
#      'Price': 9645.452891241075,
#      'Net Value': 127610.88417123261,
#      'Delta Number': 0.6539522569211549},
#     {'Asset': '^IXIC',
#      'Number': 20.104032164675125,
#      'Price': 6348.120117,
#      'Net Value': 127622.81101738922,
#      'Delta Number': 0.24304685784949953}]},
#   {'Date': Timestamp('2017-08-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.973472384055119,
#      'Price': 66619.2237342405,
#      'Net Value': 131471.19828671296,
#      'Delta Number': -0.07084957960797},
#     {'Asset': '^TWII',
#      'Number': 13.48500905127179,
#      'Price': 9748.972263944916,
#      'Net Value': 131464.97921989483,
#      'Delta Number': 0.25484913963979317},
#     {'Asset': '^IXIC',
#      'Number': 20.449927206410777,
#      'Price': 6428.660156,
#      'Net Value': 131465.63222495336,
#      'Delta Number': 0.3458950417356519}]},
#   {'Date': Timestamp('2017-10-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9195362725426761,
#      'Price': 69773.72855508298,
#      'Net Value': 133933.20283202847,
#      'Delta Number': -0.05393611151244282},
#     {'Asset': '^TWII',
#      'Number': 13.803368494803141,
#      'Price': 9702.375989613154,
#      'Net Value': 133925.47105976066,
#      'Delta Number': 0.31835944353135126},
#     {'Asset': '^IXIC',
#      'Number': 20.551985296639046,
#      'Price': 6516.720215,
#      'Net Value': 133931.53804099045,
#      'Delta Number': 0.10205809022826884}]},
#   {'Date': Timestamp('2017-10-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.00501944475008,
#      'Price': 67489.64139070532,
#      'Net Value': 135318.043307574,
#      'Delta Number': 0.08548317220740409},
#     {'Asset': '^TWII',
#      'Number': 13.518755529583235,
#      'Price': 10010.720597352421,
#      'Net Value': 135332.48443057082,
#      'Delta Number': -0.28461296521990676},
#     {'Asset': '^IXIC',
#      'Number': 20.115803242371204,
#      'Price': 6727.669922,
#      'Net Value': 135332.48443057082,
#      'Delta Number': -0.4361820542678423}]},
#   {'Date': Timestamp('2017-11-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.0493997793919654,
#      'Price': 65317.29830738649,
#      'Net Value': 133861.25674163707,
#      'Delta Number': 0.04438033464188518},
#     {'Asset': '^TWII',
#      'Number': 13.671656153848906,
#      'Price': 9791.408140232312,
#      'Net Value': 133864.76535525336,
#      'Delta Number': 0.15290062426567097},
#     {'Asset': '^IXIC',
#      'Number': 19.47470073822946,
#      'Price': 6873.970215,
#      'Net Value': 133868.5128206278,
#      'Delta Number': -0.6411025041417453}]},
#   {'Date': Timestamp('2018-01-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9533011592970926,
#      'Price': 70999.74582519341,
#      'Net Value': 138683.8858301492,
#      'Delta Number': -0.0960986200948728},
#     {'Asset': '^TWII',
#      'Number': 14.139135117268976,
#      'Price': 9807.70097319061,
#      'Net Value': 138672.40924971245,
#      'Delta Number': 0.46747896342007067},
#     {'Asset': '^IXIC',
#      'Number': 19.791680800547244,
#      'Price': 7006.899901999999,
#      'Net Value': 138678.32626176975,
#      'Delta Number': 0.31698006231778564}]},
#   {'Date': Timestamp('2018-01-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.861407812676956,
#      'Price': 79408.19125265698,
#      'Net Value': 147811.02758824162,
#      'Delta Number': -0.0918933466201366},
#     {'Asset': '^TWII',
#      'Number': 14.753686599271763,
#      'Price': 10017.53809795804,
#      'Net Value': 147795.6175935379,
#      'Delta Number': 0.6145514820027866},
#     {'Asset': '^IXIC',
#      'Number': 19.943144695205312,
#      'Price': 7411.47998,
#      'Net Value': 147808.21764675737,
#      'Delta Number': 0.1514638946580682}]},
#   {'Date': Timestamp('2018-03-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.863682821570192,
#      'Price': 77179.86251761405,
#      'Net Value': 143838.78394522646,
#      'Delta Number': 0.0022750088932359525},
#     {'Asset': '^TWII',
#      'Number': 14.670836357786502,
#      'Price': 9804.432409230556,
#      'Net Value': 143839.22345679995,
#      'Delta Number': -0.08285024148526077},
#     {'Asset': '^IXIC',
#      'Number': 20.031534249807557,
#      'Price': 7180.560059,
#      'Net Value': 143837.63475465868,
#      'Delta Number': 0.0883895546022444}]},
#   {'Date': Timestamp('2018-04-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8716366856627304,
#      'Price': 75141.62727647192,
#      'Net Value': 140637.82623104012,
#      'Delta Number': 0.00795386409253851},
#     {'Asset': '^TWII',
#      'Number': 14.302746510532177,
#      'Price': 9833.029073349602,
#      'Net Value': 140639.32226681247,
#      'Delta Number': -0.3680898472543248},
#     {'Asset': '^IXIC',
#      'Number': 20.47006145580964,
#      'Price': 6870.120117,
#      'Net Value': 140631.7810037841,
#      'Delta Number': 0.4385272060020817}]},
#   {'Date': Timestamp('2018-04-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9270809908819058,
#      'Price': 72768.34129028837,
#      'Net Value': 140230.4872385216,
#      'Delta Number': 0.055444305219175316},
#     {'Asset': '^TWII',
#      'Number': 14.339638942389394,
#      'Price': 9779.861526850416,
#      'Net Value': 140239.68320160004,
#      'Delta Number': 0.03689243185721658},
#     {'Asset': '^IXIC',
#      'Number': 19.846479959126658,
#      'Price': 7066.27002,
#      'Net Value': 140240.58633770753,
#      'Delta Number': -0.6235814966829807}]},
#   {'Date': Timestamp('2018-06-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.2177619546449465,
#      'Price': 62188.69539570192,
#      'Net Value': 137919.72265759108,
#      'Delta Number': 0.29068096376304076},
#     {'Asset': '^TWII',
#      'Number': 13.726711947874183,
#      'Price': 10050.83900775558,
#      'Net Value': 137964.9718939184,
#      'Delta Number': -0.6129269945152114},
#     {'Asset': '^IXIC',
#      'Number': 18.263031992168983,
#      'Price': 7554.330078,
#      'Net Value': 137964.9718939184,
#      'Delta Number': -1.5834479669576744}]},
#   {'Date': Timestamp('2018-07-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.3718041439640523,
#      'Price': 56656.55389335704,
#      'Net Value': 134378.2493069869,
#      'Delta Number': 0.15404218931910574},
#     {'Asset': '^TWII',
#      'Number': 13.240015859125734,
#      'Price': 10151.052445373343,
#      'Net Value': 134400.09536356013,
#      'Delta Number': -0.48669608874844883},
#     {'Asset': '^IXIC',
#      'Number': 17.759725413089587,
#      'Price': 7567.689941,
#      'Net Value': 134400.09536356013,
#      'Delta Number': -0.5033065790793962}]},
#   {'Date': Timestamp('2018-07-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.205038240841835,
#      'Price': 64628.15999202263,
#      'Net Value': 142507.56421765423,
#      'Delta Number': -0.16676590312221728},
#     {'Asset': '^TWII',
#      'Number': 13.672540964681225,
#      'Price': 10422.077429196332,
#      'Net Value': 142496.28058776644,
#      'Delta Number': 0.4325251055554915},
#     {'Asset': '^IXIC',
#      'Number': 18.573492799985306,
#      'Price': 7671.790039,
#      'Net Value': 142491.9370523655,
#      'Delta Number': 0.8137673868957194}]},
#   {'Date': Timestamp('2018-08-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.4230813213716025,
#      'Price': 57968.213384551695,
#      'Net Value': 140461.69508539053,
#      'Delta Number': 0.2180430805297675},
#     {'Asset': '^TWII',
#      'Number': 13.429549568470518,
#      'Price': 10461.507501552318,
#      'Net Value': 140493.33355302303,
#      'Delta Number': -0.24299139621070687},
#     {'Asset': '^IXIC',
#      'Number': 17.32445155673064,
#      'Price': 8109.540039,
#      'Net Value': 140493.33355302303,
#      'Delta Number': -1.2490412432546663}]},
#   {'Date': Timestamp('2018-10-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 2.305704906902325,
#      'Price': 62148.69739626856,
#      'Net Value': 143296.55654416417,
#      'Delta Number': -0.11737641446927727},
#     {'Asset': '^TWII',
#      'Number': 13.739450985358621,
#      'Price': 10428.98050983001,
#      'Net Value': 143288.46654206977,
#      'Delta Number': 0.3099014168881027},
#     {'Asset': '^IXIC',
#      'Number': 17.827682904987856,
#      'Price': 8037.299805,
#      'Net Value': 143286.43233586074,
#      'Delta Number': 0.5032313482572164}]},
#   {'Date': Timestamp('2018-10-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9095117008237714,
#      'Price': 75445.50569528066,
#      'Net Value': 144064.0758997049,
#      'Delta Number': -0.3961932060785538},
#     {'Asset': '^TWII',
#      'Number': 15.460673495574031,
#      'Price': 9315.502370635677,
#      'Net Value': 144023.94059964406,
#      'Delta Number': 1.7212225102154104},
#     {'Asset': '^IXIC',
#      'Number': 19.714145954986655,
#      'Price': 7305.899901999999,
#      'Net Value': 144029.5770005507,
#      'Delta Number': 1.8864630499987989}]},
#   {'Date': Timestamp('2018-11-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9327239485433114,
#      'Price': 74359.37464582347,
#      'Net Value': 143716.14417668732,
#      'Delta Number': 0.023212247719540002},
#     {'Asset': '^TWII',
#      'Number': 15.360688563328395,
#      'Price': 9356.381656028992,
#      'Net Value': 143720.46469790014,
#      'Delta Number': -0.09998493224563632},
#     {'Asset': '^IXIC',
#      'Number': 19.605713076155006,
#      'Price': 7330.540039,
#      'Net Value': 143720.46469790014,
#      'Delta Number': -0.10843287883164976}]},
#   {'Date': Timestamp('2019-01-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8042080723429987,
#      'Price': 77461.80273351054,
#      'Net Value': 139757.20979004068,
#      'Delta Number': -0.12851587620031268},
#     {'Asset': '^TWII',
#      'Number': 15.45870813654292,
#      'Price': 9040.534979345375,
#      'Net Value': 139754.99164390724,
#      'Delta Number': 0.09801957321452548},
#     {'Asset': '^IXIC',
#      'Number': 20.962470794080627,
#      'Price': 6665.939941,
#      'Net Value': 139734.57132830803,
#      'Delta Number': 1.3567577179256212}]},
#   {'Date': Timestamp('2019-02-11 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8114518155334696,
#      'Price': 82061.76371324345,
#      'Net Value': 148650.93086423344,
#      'Delta Number': 0.0072437431904708305},
#     {'Asset': '^TWII',
#      'Number': 15.878903310258274,
#      'Price': 9361.010012480074,
#      'Net Value': 148642.57287453068,
#      'Delta Number': 0.42019517371535287},
#     {'Asset': '^IXIC',
#      'Number': 20.34133209314187,
#      'Price': 7307.899901999999,
#      'Net Value': 148652.4188100209,
#      'Delta Number': -0.6211387009387579}]},
#   {'Date': Timestamp('2019-03-07 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8295059138524647,
#      'Price': 82794.41443229829,
#      'Net Value': 151472.8708378416,
#      'Delta Number': 0.018054098318995182},
#     {'Asset': '^TWII',
#      'Number': 15.670678608354711,
#      'Price': 9666.244599028283,
#      'Net Value': 151476.61246111678,
#      'Delta Number': -0.20822470190356235},
#     {'Asset': '^IXIC',
#      'Number': 20.410448791092737,
#      'Price': 7421.459961,
#      'Net Value': 151475.3284891356,
#      'Delta Number': 0.06911669795086794}]},
#   {'Date': Timestamp('2019-04-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8527421034227867,
#      'Price': 84697.01268536378,
#      'Net Value': 156921.72143630733,
#      'Delta Number': 0.02323618957032192},
#     {'Asset': '^TWII',
#      'Number': 15.760035142757761,
#      'Price': 9957.111081671206,
#      'Net Value': 156924.42056748096,
#      'Delta Number': 0.08935653440305025},
#     {'Asset': '^IXIC',
#      'Number': 20.04450741633004,
#      'Price': 7828.910156,
#      'Net Value': 156926.64768372357,
#      'Delta Number': -0.3659413747626985}]},
#   {'Date': Timestamp('2019-04-30 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.9107839257052945,
#      'Price': 83542.29615667395,
#      'Net Value': 159631.2766126838,
#      'Delta Number': 0.05804182228250787},
#     {'Asset': '^TWII',
#      'Number': 15.54230814958217,
#      'Price': 10271.538346552898,
#      'Net Value': 159643.41415237487,
#      'Delta Number': -0.21772699317559052},
#     {'Asset': '^IXIC',
#      'Number': 19.720286663236188,
#      'Price': 8095.390137,
#      'Net Value': 159643.41415237487,
#      'Delta Number': -0.3242207530938508}]},
#   {'Date': Timestamp('2019-05-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8271712132233584,
#      'Price': 84515.16197833086,
#      'Net Value': 154423.67104771544,
#      'Delta Number': -0.08361271248193614},
#     {'Asset': '^TWII',
#      'Number': 15.504268625260545,
#      'Price': 9960.074530450183,
#      'Net Value': 154423.67104771544,
#      'Delta Number': -0.038039524321625606},
#     {'Asset': '^IXIC',
#      'Number': 20.716755032402695,
#      'Price': 7453.149901999999,
#      'Net Value': 154405.08073951013,
#      'Delta Number': 0.9964683691665073}]},
#   {'Date': Timestamp('2019-07-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.814670837782373,
#      'Price': 90118.93341839172,
#      'Net Value': 163536.2004064068,
#      'Delta Number': -0.012500375440985367},
#     {'Asset': '^TWII',
#      'Number': 16.01348265750425,
#      'Price': 10211.594062102544,
#      'Net Value': 163523.18441895247,
#      'Delta Number': 0.5092140322437064},
#     {'Asset': '^IXIC',
#      'Number': 20.2117121961968,
#      'Price': 8091.160156,
#      'Net Value': 163536.2004064068,
#      'Delta Number': -0.5050428362058952}]},
#   {'Date': Timestamp('2019-07-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8196483924045574,
#      'Price': 90365.69892887387,
#      'Net Value': 164433.79878443957,
#      'Delta Number': 0.00497755462218441},
#     {'Asset': '^TWII',
#      'Number': 16.047884911546475,
#      'Price': 10246.46196319651,
#      'Net Value': 164434.04233591617,
#      'Delta Number': 0.034402254042223746},
#     {'Asset': '^IXIC',
#      'Number': 20.11333072321302,
#      'Price': 8175.419922,
#      'Net Value': 164434.92469233042,
#      'Delta Number': -0.0983814729837782}]},
#   {'Date': Timestamp('2019-09-03 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8952899194916388,
#      'Price': 82246.51830504279,
#      'Net Value': 155880.99705683216,
#      'Delta Number': 0.07564152708708138},
#     {'Asset': '^TWII',
#      'Number': 15.670163628925868,
#      'Price': 9948.624235512796,
#      'Net Value': 155896.56965318305,
#      'Delta Number': -0.3777212826206071},
#     {'Asset': '^IXIC',
#      'Number': 19.79850124516353,
#      'Price': 7874.160156,
#      'Net Value': 155896.56965318305,
#      'Delta Number': -0.3148294780494929}]},
#   {'Date': Timestamp('2019-10-01 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8463375119050927,
#      'Price': 87081.34157845649,
#      'Net Value': 160781.54754332485,
#      'Delta Number': -0.048952407586546176},
#     {'Asset': '^TWII',
#      'Number': 15.676126220268385,
#      'Price': 10256.449342475595,
#      'Net Value': 160781.3944644361,
#      'Delta Number': 0.005962591342516532},
#     {'Asset': '^IXIC',
#      'Number': 20.328430692080428,
#      'Price': 7908.680176000001,
#      'Net Value': 160771.05682364645,
#      'Delta Number': 0.5299294469168991}]},
#   {'Date': Timestamp('2019-10-31 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.80805880062221,
#      'Price': 92824.77568683919,
#      'Net Value': 167832.65259637215,
#      'Delta Number': -0.03827871128288263},
#     {'Asset': '^TWII',
#      'Number': 16.086431717139593,
#      'Price': 10432.514858389668,
#      'Net Value': 167821.93790752962,
#      'Delta Number': 0.4103054968712083},
#     {'Asset': '^IXIC',
#      'Number': 20.239430689465067,
#      'Price': 8292.360352,
#      'Net Value': 167832.65259637215,
#      'Delta Number': -0.08900000261536078}]},
#   {'Date': Timestamp('2019-12-02 00:00:00'),
#    'Record': [{'Asset': '^BVSP',
#      'Number': 1.8981255950110814,
#      'Price': 88352.10378922202,
#      'Net Value': 167703.38957539786,
#      'Delta Number': 0.09006679438887133},
#     {'Asset': '^TWII',
#      'Number': 15.86979478361005,
#      'Price': 10568.713126909963,
#      'Net Value': 167723.3084509068,
#      'Delta Number': -0.21663693352954283},
#     {'Asset': '^IXIC',
#      'Number': 19.575571851767215,
#      'Price': 8567.990234,
#      'Net Value': 167723.3084509068,
#      'Delta Number': -0.6638588376978518}]}]]

# %%
nominal_plot_data_list = []
actual_plot_data_list = []

# for balance_freq in range(4):
for balance_freq in [3]:
    nominal = nominal_price_result[balance_freq]
    date_df = pd.DataFrame([tmp['Date']for tmp in nominal], columns = ['Date']) # Action dates in the five years
    nominal_df_list = []
    
    for i in range(3):
        asset_df = pd.DataFrame([tmp['Record'][i] for tmp in nominal])
        result_df = pd.concat([date_df, asset_df], axis=1)
        result_df.rename(columns={'0':'Date'}, inplace=True)
        nominal_df_list.append(result_df)
        
    
    actual = actual_price_result[balance_freq]
    date_df = pd.DataFrame([tmp['Date']for tmp in actual], columns = ['Date'])
    actual_df_list = []
    
    for i in range(3):
        asset_df = pd.DataFrame([tmp['Record'][i] for tmp in actual])
        result_df = pd.concat([date_df, asset_df], axis=1)
        result_df.rename(columns={'0':'Date'}, inplace=True)
        actual_df_list.append(result_df)

        
    for market_num in range(len(actual_df_list)):
        tmp_trans_df = actual_df_list[market_num]
        trans_date = tmp_trans_df['Date']
        start_date = list(trans_date)[0]
        end_date = list(df_list[0]['Date'])[-1]

        history_df = df_list[market_num]
        all_price_date = history_df['Date'][(history_df['Date']>=start_date) & (history_df['Date']<= end_date)]
        plot_data = []
        number = 0
        net_value = 0
        price = 0
        for date in all_price_date:
            if (trans_date == date).any(): # If rebalanced at that day:
                number = tmp_trans_df['Number'][tmp_trans_df['Date']==date].values[0]
                net_value = tmp_trans_df['Net Value'][tmp_trans_df['Date']==date].values[0]
                price = tmp_trans_df['Price'][tmp_trans_df['Date']==date].values[0]
            else:
                price = history_df['Actual Price'][history_df['Date']==date].values[0]
                net_value = number*price
            plot_data.append({
                "Date": date,
                "Number": number,
                "Price": price,
                "Net Value": net_value
            })
        actual_plot_data_list.append(plot_data)
        
        
    for market_num in range(len(nominal_df_list)):
        tmp_trans_df = nominal_df_list[market_num]
        trans_date = tmp_trans_df['Date']
        start_date = list(trans_date)[0]
        end_date = list(df_list[0]['Date'])[-1]

        history_df = df_list[market_num]
        all_price_date = history_df['Date'][(history_df['Date']>=start_date) & (history_df['Date']<= end_date)]
        plot_data = []
        number = 0
        net_value = 0
        price = 0
        for date in all_price_date:
            if (trans_date == date).any(): # If rebalanced at that day:
                number = tmp_trans_df['Number'][tmp_trans_df['Date']==date].values[0]
                net_value = tmp_trans_df['Net Value'][tmp_trans_df['Date']==date].values[0]
                price = tmp_trans_df['Price'][tmp_trans_df['Date']==date].values[0]
            else:
                price = history_df['Actual Price'][history_df['Date']==date].values[0]
                net_value = number*price
            plot_data.append({
                "Date": date,
                "Number": number,
                "Price": price,
                "Net Value": net_value
            })
        nominal_plot_data_list.append(plot_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.gridspec import GridSpec
from CSVUtils import *

DIR = "./from github/Stock-Trading-Environment/data"
file_names = ["^BVSP", "^TWII", "^IXIC"]
source_list = ["yahoo", "yahoo", "yahoo"]

nominal_labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
actual_labels = ["high-^BVSP_act", "mid-^TWII_act", "low-^IXIC"]


plt.rcParams['figure.facecolor'] = 'white'
fig=plt.figure(figsize=(40,25))
axs = []
gs=GridSpec(5,1) # 5 rows, 1 columns
axs.append(fig.add_subplot(gs[0,0])) # First row, first column
axs.append(fig.add_subplot(gs[1,0])) # First row, second column
axs.append(fig.add_subplot(gs[2,0])) # First row, third column
axs.append(fig.add_subplot(gs[3:,:])) # Second row, span all columns



for i, plot_data in enumerate(nominal_plot_data_list):
    plot_data = pd.DataFrame(plot_data)
    
    axs[i].plot(plot_data['Date'], np.log(plot_data['Net Value']/plot_data['Net Value'][0]), color="b", label = nominal_labels[i])
#     axs[i].bar(actual_df_list[1]['Date'], np.log(actual_df_list[1]['Net Value']/actual_df_list[1]['Net Value'][0]),width=2, label = nominal_labels[i])
    axs[i].axhline(y=0, color = "grey", linestyle='--')
#     axs[i].set_ylim((0, 300000))
    axs[i].legend()
    axs[i].set_title('Portfolio Weights')
    axs[i].set_xlabel('Date')
    axs[i].set_ylabel('Market Value (US$)')
    
    
for i, plot_data in enumerate(actual_plot_data_list):
    plot_data = pd.DataFrame(plot_data)
    
    axs[i].plot(plot_data['Date'], np.log(plot_data['Net Value']/plot_data['Net Value'][0]), color="orange", label = actual_labels[i])
    axs[i].bar(actual_df_list[1]['Date'], np.log(actual_df_list[1]['Net Value']/actual_df_list[1]['Net Value'][0]),width=2, color="orange")
    axs[i].axhline(y=0, color = "grey", linestyle='--')
#     axs[i].set_ylim((0, 300000))
    axs[i].legend()
    axs[i].set_title('Portfolio Weights')
    axs[i].set_xlabel('Date')
    axs[i].set_ylabel('Market Value (US$)')
    
    
    
for i in range(2,-1,-1): # Inverse: Low-Mid-High
    df = csv2df(DIR, file_names[i]+".csv",source = source_list[i])
    df['Date'] = pd.to_datetime(df['Date'])
    df = df[(df['Date']>=pd.to_datetime("2015-01-01"))&(df['Date']<=pd.to_datetime("2019-12-31"))].reset_index(drop=True)

    j = 0
    init_price = df['Price'][j]
    while np.isnan(init_price):
        j+=1
        init_price = df['Price'][j]
    y = np.log(df['Price'][j:] / init_price)
    x = df['Date'][j:]
    axs[3].plot(x,y,label = nominal_labels[i])

axs[3].axhline(y=0, color = "grey", linestyle='--')
axs[3].set_ylim((-1,1))
axs[3].legend()
axs[3].set_title('Log Market Price')
axs[3].set_xlabel('Date')
axs[3].set_ylabel('log(Market Price)')
plt.show()

# %%
# Out:
# [{'Date': Timestamp('2015-01-05 00:00:00'),
#   'Number': 2.1045099648546834,
#   'Price': 47517.0,
#   'Net Value': 100000.0},
#  {'Date': Timestamp('2015-01-05 00:00:00'),
#   'Number': 10.782745164625332,
#   'Price': 9274.076172,
#   'Net Value': 100000.0},
#  {'Date': Timestamp('2015-01-05 00:00:00'),
#   'Number': 21.49349795550752,
#   'Price': 4652.569824,
#   'Net Value': 100000.0}]

# %%
nominal = nominal_price_result[3]
date_df = pd.DataFrame([tmp['Date']for tmp in nominal], columns = ['Date'])
nominal_df_list = []
for i in range(3):
    asset_df = pd.DataFrame([tmp['Record'][i] for tmp in nominal])
    result_df = pd.concat([date_df, asset_df], axis=1)
    result_df.rename(columns={'0':'Date'}, inplace=True)
    nominal_df_list.append(result_df)

# %%
actual = actual_price_result[3]
date_df = pd.DataFrame([tmp['Date']for tmp in actual], columns = ['Date'])
actual_df_list = []
for i in range(3):
    asset_df = pd.DataFrame([tmp['Record'][i] for tmp in actual])
    result_df = pd.concat([date_df, asset_df], axis=1)
    result_df.rename(columns={'0':'Date'}, inplace=True)
    actual_df_list.append(result_df)

# %%
tmp_trans_df = actual_df_list[1]
trans_date = tmp_trans_df['Date']
start_date = list(trans_date)[0]
end_date = list(trans_date)[-1]

history_df = df_list[1]
all_price_date = history_df['Date'][(history_df['Date']>=start_date) & (history_df['Date']<= end_date)]
plot_data = []
number = 0
net_value = 0
price = 0
for date in all_price_date:
    if (trans_date == date).any(): # If rebalanced at that day:
        number = tmp_trans_df['Number'][tmp_trans_df['Date']==date].values[0]
        net_value = tmp_trans_df['Net Value'][tmp_trans_df['Date']==date].values[0]
        price = tmp_trans_df['Price'][tmp_trans_df['Date']==date].values[0]
    else:
        price = history_df['Actual Price'][history_df['Date']==date].values[0]
        net_value = number*price
    plot_data.append({
        "Date": date,
        "Number": number,
        "Price": price,
        "Net Value": net_value
    })

# %%
plot_data = pd.DataFrame(plot_data)

# %%
plt.figure(figsize=(30,10))
plt.plot(plot_data['Date'], np.log(plot_data['Net Value']/plot_data['Net Value'][0]))
plt.bar(actual_df_list[1]['Date'], np.log(actual_df_list[1]['Net Value']/actual_df_list[1]['Net Value'][0]),width=2)
plt.axhline(y=0, color = "grey", linestyle='--')

# %%
tmp_trans_df['Number'][tmp_trans_df['Date']==all_price_date[0]].values[0]
# Out:
# 10.781397910903255

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.gridspec import GridSpec


nominal_labels = ["high-^BVSP", "mid-^TWII", "low-^IXIC"]
actual_labels = ["high-^BVSP_act", "mid-^TWII_act", "low-^IXIC"]

from matplotlib.gridspec import GridSpec
import matplotlib.pyplot as plt

plt.rcParams['figure.facecolor'] = 'white'
fig=plt.figure(figsize=(40,25))
axs = []
gs=GridSpec(5,1) # 5 rows, 1 columns
axs.append(fig.add_subplot(gs[0,0])) # First row, first column
axs.append(fig.add_subplot(gs[1,0])) # First row, second column
axs.append(fig.add_subplot(gs[2,0])) # First row, third column
axs.append(fig.add_subplot(gs[3:,:])) # Second row, span all columns


for i in range(3):
    axs[i].plot(nominal_df_list[i]['Date'], nominal_df_list[i]['Price']/nominal_df_list[i]['Price'][0], color = "blue", label = nominal_labels[i])
    axs[i].plot(actual_df_list[i]['Date'], actual_df_list[i]['Price']/actual_df_list[i]['Price'][0], color = "orange", label = actual_labels[i])
    axs[i].axhline(y=1, color = "grey", linestyle='--')
#     axs[i].set_ylim((0, 300000))
    axs[i].legend()
    axs[i].set_title('Portfolio Weights')
    axs[i].set_xlabel('Date')
    axs[i].set_ylabel('Market Value (US$)')
