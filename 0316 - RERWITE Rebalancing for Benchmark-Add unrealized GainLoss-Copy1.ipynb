# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from os import path
import numpy as np
import pandas as pd
import pickle

output_dir = "./from github/Stock-Trading-Environment/output/306"
record = pickle.load(open(path.join(output_dir,"BRZ_TW_NASDAQ-Selected_Trans-withleakage+RSI-_detailed-ModelNo-200000-1.out"), "rb"))
df = pd.DataFrame(record)

# %%
df[(df['date'] >= pd.to_datetime("2017-12-01")) & (df['date'] <= pd.to_datetime("2017-12-15"))]
# Out:
#           date                                       actual_price  \
# 660 2017-12-01  [72115.10965375148, 10661.934185666658, 6777.3...
# 661 2017-12-04  [73687.93255273186, 10596.979518997025, 6881.6...
# 662 2017-12-05  [72792.4283662736, 10583.62191975625, 6823.654...
# 663 2017-12-06  [73006.23997955752, 10414.726740007227, 6741.9...
# 664 2017-12-07  [73191.85957637585, 10412.22659336163, 6820.15...
# 665 2017-12-08  [72888.30363695617, 10361.69678717632, 6863.66...
# 666 2017-12-11  [73297.34572458362, 10483.617143708512, 6858.4...
# 667 2017-12-12  [72130.18317972333, 10435.584651235436, 6858.9...
# 668 2017-12-13  [74209.08778657997, 10465.73486266777, 6883.79...
# 669 2017-12-14  [72337.94848563761, 10564.895235425023, 6873.3...
# 670 2017-12-15  [72926.95510567578, 10454.29122246849, 6877.79...
#
#                           action  \
# 660         [0.0, 0.0, 1.0, 1.0]
# 661         [0.0, 0.0, 1.0, 1.0]
# 662  [0.0, 0.22800267, 1.0, 1.0]
# 663         [0.0, 0.0, 1.0, 1.0]
# 664         [0.0, 0.0, 1.0, 1.0]
# 665         [0.0, 0.0, 1.0, 1.0]
# 666  [0.17517734, 0.0, 1.0, 1.0]
# 667         [1.0, 0.0, 1.0, 1.0]
# 668         [1.0, 0.0, 1.0, 1.0]
# 669         [1.0, 0.0, 1.0, 1.0]
# 670  [0.69207084, 0.0, 1.0, 1.0]
#
#                                              inventory  \
# 660  [47903.03349271317, 383284.8454595289, 47910.6...
# 661  [47903.03349271317, 383284.8454595289, 47910.6...
# 662  [47903.03349271317, 383284.8454595289, 47910.6...
# 663  [47903.03349271317, 383284.8454595289, 47910.6...
# 664  [47903.03349271317, 383284.8454595289, 47910.6...
# 665  [47903.03349271317, 383284.8454595289, 47910.6...
# 666  [47903.03349271317, 383284.8454595289, 47910.6...
# 667  [373604.8652932868, 46802.91908195817, 46802.9...
# 668  [373604.8652932868, 46802.91908195817, 46802.9...
# 669  [373604.8652932868, 46802.91908195817, 46802.9...
# 670  [373604.8652932868, 46802.91908195817, 46802.9...
#
#                                            shares_held      net_worth  \
# 660  [0.6491548451827321, 35.65731157400905, 7.1586...  479098.484635
# 661  [0.6491548451827321, 35.65731157400905, 7.1586...  479098.484635
# 662  [0.6491548451827321, 35.65731157400905, 7.1586...  479098.484635
# 663  [0.6491548451827321, 35.65731157400905, 7.1586...  479098.484635
# 664  [0.6491548451827321, 35.65731157400905, 7.1586...  479098.484635
# 665  [0.6491548451827321, 35.65731157400905, 7.1586...  479098.484635
# 666  [0.6491548451827321, 35.65731157400905, 7.1586...  479098.484635
# 667  [5.179591244935472, 4.484935022439526, 6.82366...  467210.703457
# 668  [5.179591244935472, 4.484935022439526, 6.82366...  467210.703457
# 669  [5.179591244935472, 4.484935022439526, 6.82366...  467210.703457
# 670  [5.179591244935472, 4.484935022439526, 6.82366...  467210.703457
#
#      net_worth_delta  buyNhold_balance  buyNhold_delta  actual_profit  \
# 660      8166.439809     412983.854119    -1704.316163   66114.630515
# 661      8166.439809     412983.854119    -1704.316163   66114.630515
# 662      8166.439809     412983.854119    -1704.316163   66114.630515
# 663      8166.439809     412983.854119    -1704.316163   66114.630515
# 664      8166.439809     412983.854119    -1704.316163   66114.630515
# 665      8166.439809     412983.854119    -1704.316163   66114.630515
# 666      8166.439809     412983.854119    -1704.316163   66114.630515
# 667    -11887.781177     413980.748982      996.894863   53229.954475
# 668    -11887.781177     413980.748982      996.894863   53229.954475
# 669    -11887.781177     413980.748982      996.894863   53229.954475
# 670    -11887.781177     413980.748982      996.894863   53229.954475
#
#       progress  testNo   rewards
# 660  -4.795023     660  0.052951
# 661  -4.795023     661  0.047417
# 662  -4.795023     662  0.049569
# 663  -4.795023     663  0.046347
# 664  -4.795023     664  0.051899
# 665  -4.795023     665  0.050820
# 666  -4.795023     666  0.056687
# 667 -11.911857     667  0.046721
# 668 -11.911857     668  0.046665
# 669 -11.911857     669  0.046754
# 670 -11.911857     670  0.035979

# %%
asset_list = ["^BVSP", "^TWII", "^IXIC"]
nominal_price_result = []
prev_num = [0,0,0]
prev_cost = [0,0,0]

for _, record in df.iterrows():
    status_list = []
    # The actual_price here is a random variable between high and low, not currency 
    for i, asset in enumerate(asset_list):
        curr_price = record['actual_price'][i]
        curr_num = record['shares_held'][i]
        if record['shares_held'][i] - prev_num[i] > 0:
            avg_cost = (prev_cost[i]*prev_num[i]+(record['shares_held'][i] - prev_num[i])*curr_price)/curr_num   
        else:
            avg_cost = prev_cost[i]
        
        status = {
            'Asset': asset_list[i],
            'Number': curr_num,
            'Price': curr_price,
            'Net Value': record['shares_held'][i]*record['actual_price'][i],
            'Delta Number': record['shares_held'][i] - prev_num[i],
            'Avg Cost': avg_cost
        }
        status_list.append(status)
        prev_num[i] = curr_num
        prev_cost[i] = avg_cost
    
    nominal_price_result.append({
        'Date': record['date'],
        'Record': status_list
    })

# %%
price_df_list = pickle.load(open("0306-adjusted market prices.out", "rb"))
asset_list = ["^BVSP", "^TWII", "^IXIC"]
actual_price_result = []
prev_num = [0,0,0]
prev_cost = [0,0,0]

for _, record in df.iterrows():
    status_list = []
    
    for i, asset in enumerate(asset_list):
        curr_price = price_df_list[i][price_df_list[i]['Date'] == record['date']]['Actual Price'].values[0]
        curr_num = record['shares_held'][i]
        if record['shares_held'][i] - prev_num[i] > 0:
            avg_cost = (prev_cost[i]*prev_num[i]+(record['shares_held'][i] - prev_num[i])*curr_price)/curr_num   
        else:
            avg_cost = prev_cost[i]
        status = {
            'Asset': asset_list[i],
            'Number': curr_num,
            'Price': curr_price,
            'Net Value': record['shares_held'][i]*curr_price,
            'Delta Number': record['shares_held'][i] - prev_num[i],
            'Avg Cost': avg_cost
        }
        
        status_list.append(status)
        prev_num[i] = curr_num
        prev_cost[i] = avg_cost
    
    actual_price_result.append({
        'Date': record['date'],
        'Record': status_list
    })

# %%
actual_price_result
# Out:
# [{'Date': Timestamp('2015-01-13 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 48971.28719194559,
#     'Net Value': 101934.32245107529,
#     'Delta Number': 2.0815120103242997,
#     'Avg Cost': 48971.28719194559},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9177.257543052952,
#     'Net Value': 99409.5595126523,
#     'Delta Number': 10.832164080205406,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4661.5,
#     'Net Value': 100000.00000000001,
#     'Delta Number': 21.452322213879654,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-01-14 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 49067.87383597223,
#     'Net Value': 102135.36871065365,
#     'Delta Number': 0.0,
#     'Avg Cost': 48971.28719194559},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9079.819259910653,
#     'Net Value': 98354.09204196141,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4639.319824,
#     'Net Value': 99524.18371768745,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-01-15 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 48969.56775235744,
#     'Net Value': 101930.74341692154,
#     'Delta Number': 0.0,
#     'Avg Cost': 48971.28719194559},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9010.157347404436,
#     'Net Value': 97599.50277555315,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4570.819824,
#     'Net Value': 98054.6996460367,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-01-16 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 50374.880248348636,
#     'Net Value': 104855.91825558603,
#     'Delta Number': 0.0,
#     'Avg Cost': 48971.28719194559},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 8990.09107328238,
#     'Net Value': 97382.14160178465,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4634.379883,
#     'Net Value': 99418.21051163788,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-01-20 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 49921.667880904184,
#     'Net Value': 103912.55126952288,
#     'Delta Number': 0.0,
#     'Avg Cost': 48971.28719194559},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9057.093249889007,
#     'Net Value': 98107.92017251854,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4654.850098,
#     'Net Value': 99857.34415960529,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-01-21 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 51582.824752354485,
#     'Net Value': 107370.26924847942,
#     'Delta Number': 0.0,
#     'Avg Cost': 48971.28719194559},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9102.541909115982,
#     'Net Value': 98600.22750649048,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4667.419922,
#     'Net Value': 100126.99607422504,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-01-22 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 52335.62370456266,
#     'Net Value': 108937.2293088603,
#     'Delta Number': 0.0,
#     'Avg Cost': 48971.28719194559},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9099.35814591944,
#     'Net Value': 98565.74046115301,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4750.399902,
#     'Net Value': 101907.10934248634,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-01-23 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 51520.12295154107,
#     'Net Value': 107239.75469701734,
#     'Delta Number': 0.0,
#     'Avg Cost': 48971.28719194559},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9217.875654001333,
#     'Net Value': 99849.54155507314,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4757.879883,
#     'Net Value': 102067.57230505202,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-01-26 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 51244.274970796694,
#     'Net Value': 106665.57381207422,
#     'Delta Number': 0.0,
#     'Avg Cost': 48971.28719194559},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9146.087540057842,
#     'Net Value': 99071.92092582877,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4771.759765999999,
#     'Net Value': 102365.32802745896,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-01-27 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 51469.20576451647,
#     'Net Value': 107133.76996069371,
#     'Delta Number': 0.0,
#     'Avg Cost': 48971.28719194559},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9239.360317767329,
#     'Net Value': 100082.26695819446,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4681.5,
#     'Net Value': 100429.0464442776,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-01-28 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 50444.352519709515,
#     'Net Value': 105000.5256228082,
#     'Delta Number': 0.0,
#     'Avg Cost': 48971.28719194559},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9333.922000470599,
#     'Net Value': 101106.5746209366,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4637.990234000001,
#     'Net Value': 99495.66092459511,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-01-29 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 49994.90798713468,
#     'Net Value': 104065.00143027908,
#     'Delta Number': 0.0,
#     'Avg Cost': 48971.28719194559},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9298.041881165307,
#     'Net Value': 100717.91528140433,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4683.410156,
#     'Net Value': 100470.02372626838,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-01-30 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 47657.413974101044,
#     'Net Value': 99199.47956808844,
#     'Delta Number': 0.0,
#     'Avg Cost': 48971.28719194559},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9186.813001671839,
#     'Net Value': 99513.06580827369,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4635.240234000001,
#     'Net Value': 99436.66703850694,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-02-02 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 47618.322865483475,
#     'Net Value': 99118.11095600408,
#     'Delta Number': 0.0,
#     'Avg Cost': 48971.28719194559},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9180.213758253549,
#     'Net Value': 99441.58172076156,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4676.689941,
#     'Net Value': 100325.85950874182,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-02-03 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 49517.58753257978,
#     'Net Value': 103071.45317134963,
#     'Delta Number': 0.0,
#     'Avg Cost': 48971.28719194559},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9238.245368326961,
#     'Net Value': 100070.18964291527,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4727.740234000001,
#     'Net Value': 101421.00684329082,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-02-04 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 49000.83321863173,
#     'Net Value': 246056.20950910624,
#     'Delta Number': 2.9399578983863055,
#     'Avg Cost': 48988.585727255166},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9309.077009391121,
#     'Net Value': 29823.98614785706,
#     'Delta Number': -7.628410784602606,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4716.700195,
#     'Net Value': 30591.503634675562,
#     'Delta Number': -14.966537158661499,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-02-05 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 48880.41347966897,
#     'Net Value': 245451.52541348996,
#     'Delta Number': 0.0,
#     'Avg Cost': 48988.585727255166},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9357.78985567535,
#     'Net Value': 29980.050089678352,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4765.100098,
#     'Net Value': 30905.415002226968,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-02-06 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 47787.62637982407,
#     'Net Value': 239964.12787499168,
#     'Delta Number': 0.0,
#     'Avg Cost': 48988.585727255166},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9276.38042205108,
#     'Net Value': 29719.234348411435,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4744.399902,
#     'Net Value': 30771.15798037008,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-02-09 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 48584.109835744974,
#     'Net Value': 243963.64558168434,
#     'Delta Number': 0.0,
#     'Avg Cost': 48988.585727255166},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9244.11750989207,
#     'Net Value': 29615.871937256266,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4726.009765999999,
#     'Net Value': 30651.883511137847,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-02-10 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 46641.86995150948,
#     'Net Value': 234210.7464474982,
#     'Delta Number': 0.0,
#     'Avg Cost': 48988.585727255166},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9228.224866517641,
#     'Net Value': 29564.9558286696,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4787.640136999999,
#     'Net Value': 31051.6048503172,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-02-11 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 45816.40404085746,
#     'Net Value': 230065.6942164927,
#     'Delta Number': 0.0,
#     'Avg Cost': 48988.585727255166},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9204.09552409623,
#     'Net Value': 29487.651368366278,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4801.180176,
#     'Net Value': 31139.42263291047,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-02-12 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 47853.607652303326,
#     'Net Value': 240295.4508492847,
#     'Delta Number': 0.0,
#     'Avg Cost': 48988.585727255166},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9243.157184418425,
#     'Net Value': 29612.795291355225,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4857.609863000001,
#     'Net Value': 31505.413453525714,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-02-13 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 48684.39875945405,
#     'Net Value': 244467.24339426644,
#     'Delta Number': 0.0,
#     'Avg Cost': 48988.585727255166},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9307.45275250033,
#     'Net Value': 29818.782429490286,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4893.839844,
#     'Net Value': 31740.39332284635,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-02-24 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 50677.66645702683,
#     'Net Value': 254476.37715763302,
#     'Delta Number': 0.0,
#     'Avg Cost': 48988.585727255166},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9339.316171928434,
#     'Net Value': 29920.864964492248,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4968.120117,
#     'Net Value': 32222.159207367276,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-02-25 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 49872.06242676453,
#     'Net Value': 250431.0607613349,
#     'Delta Number': 0.0,
#     'Avg Cost': 48988.585727255166},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9417.249049833968,
#     'Net Value': 30170.54267891791,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4967.140136999999,
#     'Net Value': 32215.803267728857,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-02-26 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 49250.95835448329,
#     'Net Value': 247312.20535219705,
#     'Delta Number': 0.0,
#     'Avg Cost': 48988.585727255166},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9335.827705573558,
#     'Net Value': 29909.68877891121,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4987.890136999999,
#     'Net Value': 32350.383307624634,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-03-02 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 47580.76093187208,
#     'Net Value': 238925.3592529488,
#     'Delta Number': 0.0,
#     'Avg Cost': 48988.585727255166},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9297.918846379222,
#     'Net Value': 29788.238146334814,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 5008.100098,
#     'Net Value': 32481.46077064498,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-03-03 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 47289.68056067344,
#     'Net Value': 237463.70792795855,
#     'Delta Number': 0.0,
#     'Avg Cost': 48988.585727255166},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9317.017625145212,
#     'Net Value': 29849.425921748345,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4979.899902,
#     'Net Value': 32298.56036087396,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-03-04 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 45812.003770433475,
#     'Net Value': 230043.5983909685,
#     'Delta Number': 0.0,
#     'Avg Cost': 48988.585727255166},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9361.017688318687,
#     'Net Value': 29990.391269147098,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4967.140136999999,
#     'Net Value': 32215.803267728857,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-03-05 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 45297.895923254764,
#     'Net Value': 227462.0213065286,
#     'Delta Number': 0.0,
#     'Avg Cost': 48988.585727255166},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9364.723716098293,
#     'Net Value': 30002.264467859604,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4982.810059,
#     'Net Value': 32317.435013652896,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-03-06 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 44102.926456212575,
#     'Net Value': 221461.5180859483,
#     'Delta Number': 0.0,
#     'Avg Cost': 48988.585727255166},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9392.148624322437,
#     'Net Value': 30090.127107964312,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4927.370117,
#     'Net Value': 31957.863466367136,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-03-09 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 42559.44906545209,
#     'Net Value': 213710.99281346938,
#     'Delta Number': 0.0,
#     'Avg Cost': 48988.585727255166},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9357.89150236873,
#     'Net Value': 29980.375740607255,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4942.439941,
#     'Net Value': 32055.6031056511,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-03-10 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 42050.11039334151,
#     'Net Value': 211153.36399812344,
#     'Delta Number': 0.0,
#     'Avg Cost': 48988.585727255166},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9335.54270971059,
#     'Net Value': 29908.77572247599,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4859.790039,
#     'Net Value': 31519.55360644426,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-03-11 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 42268.746586977904,
#     'Net Value': 212251.23906542364,
#     'Delta Number': 0.0,
#     'Avg Cost': 48988.585727255166},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9292.188491969517,
#     'Net Value': 29769.87950450975,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4849.939941,
#     'Net Value': 31455.66798804342,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-03-12 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 41718.196724468085,
#     'Net Value': 209486.66949758583,
#     'Delta Number': 0.0,
#     'Avg Cost': 48988.585727255166},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9393.165784077362,
#     'Net Value': 30093.38583688131,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4893.290039,
#     'Net Value': 31736.827405794065,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-03-13 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 40414.02717530445,
#     'Net Value': 202937.82135060395,
#     'Delta Number': 0.0,
#     'Avg Cost': 48988.585727255166},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9356.163874529086,
#     'Net Value': 29974.84084722242,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4871.759765999999,
#     'Net Value': 31597.18668293589,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-03-16 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 40647.97279815103,
#     'Net Value': 205079.3665823564,
#     'Delta Number': 0.023784564390324725,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9253.971703847934,
#     'Net Value': 29611.010494194794,
#     'Delta Number': -0.003936887921100141,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4929.509765999999,
#     'Net Value': 30843.55670520091,
#     'Delta Number': -0.2288633389987753,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-03-17 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 41939.986770655516,
#     'Net Value': 211597.90585644357,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9220.579248345255,
#     'Net Value': 29504.16076718454,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4937.430176,
#     'Net Value': 30893.114090531275,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-03-18 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 43379.00280547355,
#     'Net Value': 218858.10794297323,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9382.022438525013,
#     'Net Value': 30020.749336030207,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4982.830078,
#     'Net Value': 31177.177723269306,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-03-19 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 41825.008077986786,
#     'Net Value': 211017.80909294536,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9425.703429388272,
#     'Net Value': 30160.520487298258,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4992.379883,
#     'Net Value': 31236.930105559466,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-03-20 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 43484.05398138794,
#     'Net Value': 219388.1178581598,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9414.769719225076,
#     'Net Value': 30125.534622121228,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 5026.419922,
#     'Net Value': 31449.915964799522,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-03-23 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 44781.160208631,
#     'Net Value': 225932.34885324494,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9410.82936743683,
#     'Net Value': 30112.92621981716,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 5010.970215,
#     'Net Value': 31353.248357562,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-03-24 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 44323.26792809363,
#     'Net Value': 223622.16577666535,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9386.241531445374,
#     'Net Value': 30034.24965878231,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4994.72998,
#     'Net Value': 31251.634478513988,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-03-25 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 43769.357365614684,
#     'Net Value': 220827.5460336206,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9331.841639237338,
#     'Net Value': 29860.179991118923,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4876.52002,
#     'Net Value': 30512.004012716563,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-03-26 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 42938.30169514823,
#     'Net Value': 216634.65869480383,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9260.174092652074,
#     'Net Value': 29630.856999657102,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4863.359863000001,
#     'Net Value': 30429.66194059441,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-03-27 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 41646.27605760555,
#     'Net Value': 210116.06056763057,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9172.55472146989,
#     'Net Value': 29350.4910981176,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4891.220215,
#     'Net Value': 30603.981982044726,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-03-30 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 42847.7450591715,
#     'Net Value': 216177.7774220733,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9188.014794074214,
#     'Net Value': 29399.96049210086,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4947.439941,
#     'Net Value': 30955.744406534024,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-03-31 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 43240.451252545034,
#     'Net Value': 218159.08010080553,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9244.400796567012,
#     'Net Value': 29580.385348040898,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4900.879883,
#     'Net Value': 30664.421768525393,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-04-01 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 44655.83946400476,
#     'Net Value': 225300.07380584706,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9108.841469393,
#     'Net Value': 29146.620388735206,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4880.22998,
#     'Net Value': 30535.21694200687,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-04-02 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 46001.43422231722,
#     'Net Value': 232088.94177920415,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9156.116740914258,
#     'Net Value': 29297.892578226532,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4886.939941,
#     'Net Value': 30577.20064270275,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-04-07 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 46484.321468619695,
#     'Net Value': 234525.2308186151,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9217.99224021484,
#     'Net Value': 29495.882816122034,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4910.22998,
#     'Net Value': 30722.92459349345,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-04-08 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 47632.55316235402,
#     'Net Value': 240318.35190758447,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9192.310806237301,
#     'Net Value': 29413.706942307912,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4950.819824,
#     'Net Value': 30976.892069875008,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-04-09 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 47615.32463093776,
#     'Net Value': 240231.4295823916,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9185.597108170465,
#     'Net Value': 29392.224341077424,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4974.560059,
#     'Net Value': 31125.432861794663,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-04-10 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 47715.172293165444,
#     'Net Value': 240735.18644687452,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9259.86856542368,
#     'Net Value': 29629.879368618695,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4995.97998,
#     'Net Value': 31259.455630659264,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-04-13 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 47045.85377349328,
#     'Net Value': 237358.30419156924,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9277.4675375552,
#     'Net Value': 29686.192848403465,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4988.25,
#     'Net Value': 31211.08975093132,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-04-14 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 47697.646495332,
#     'Net Value': 240646.76433696068,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9245.850218739768,
#     'Net Value': 29585.02323289094,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4977.290039,
#     'Net Value': 31142.51413294151,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-04-15 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 49073.90384791505,
#     'Net Value': 247590.33290121832,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9108.90438327983,
#     'Net Value': 29146.821701622557,
#     'Delta Number': 0.0,
#     'Avg Cost': 9177.257543052952},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 5011.02002,
#     'Net Value': 31353.55998354807,
#     'Delta Number': 0.0,
#     'Avg Cost': 4661.5}]},
#  {'Date': Timestamp('2015-04-16 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 48972.23144752201,
#     'Net Value': 242367.5788263705,
#     'Delta Number': -0.09617268404485291,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9205.599474585262,
#     'Net Value': 32204.13079315331,
#     'Delta Number': 0.298503379319917,
#     'Avg Cost': 9179.67589324789},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 5007.790039,
#     'Net Value': 33683.58224070819,
#     'Delta Number': 0.4693152023384961,
#     'Avg Cost': 4685.66197670241}]},
#  {'Date': Timestamp('2015-04-17 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 48023.74580678601,
#     'Net Value': 237673.4458146228,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9139.260752121478,
#     'Net Value': 31972.056727713843,
#     'Delta Number': 0.0,
#     'Avg Cost': 9179.67589324789},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 4931.810059,
#     'Net Value': 33172.5228941609,
#     'Delta Number': 0.0,
#     'Avg Cost': 4685.66197670241}]},
#  {'Date': Timestamp('2015-04-20 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 47980.27005345349,
#     'Net Value': 237458.2807555393,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9126.986820627508,
#     'Net Value': 31929.118590304184,
#     'Delta Number': 0.0,
#     'Avg Cost': 9179.67589324789},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 4994.600098,
#     'Net Value': 33594.863572600385,
#     'Delta Number': 0.0,
#     'Avg Cost': 4685.66197670241}]},
#  {'Date': Timestamp('2015-04-22 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 49114.68353307679,
#     'Net Value': 243072.58584880273,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9159.635348615684,
#     'Net Value': 32043.3335817817,
#     'Delta Number': 0.0,
#     'Avg Cost': 9179.67589324789},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 5035.169922,
#     'Net Value': 33867.74582056858,
#     'Delta Number': 0.0,
#     'Avg Cost': 4685.66197670241}]},
#  {'Date': Timestamp('2015-04-23 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 50756.11051895777,
#     'Net Value': 251196.1422526915,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9248.996493226832,
#     'Net Value': 32355.94744216399,
#     'Delta Number': 0.0,
#     'Avg Cost': 9179.67589324789},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 5056.060059,
#     'Net Value': 34008.25783129172,
#     'Delta Number': 0.0,
#     'Avg Cost': 4685.66197670241}]},
#  {'Date': Timestamp('2015-04-24 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 51919.95173352807,
#     'Net Value': 256956.08761307425,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9270.855261983928,
#     'Net Value': 32432.416405426433,
#     'Delta Number': 0.0,
#     'Avg Cost': 9179.67589324789},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 5092.080078,
#     'Net Value': 34250.53701289667,
#     'Delta Number': 0.0,
#     'Avg Cost': 4685.66197670241}]},
#  {'Date': Timestamp('2015-04-27 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 51564.88940890715,
#     'Net Value': 255198.85512831295,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9333.866954613544,
#     'Net Value': 32652.851456565084,
#     'Delta Number': 0.0,
#     'Avg Cost': 9179.67589324789},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 5060.25,
#     'Net Value': 34036.44036713249,
#     'Delta Number': 0.0,
#     'Avg Cost': 4685.66197670241}]},
#  {'Date': Timestamp('2015-04-28 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 51474.87912700825,
#     'Net Value': 254753.3868813393,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9306.685438364371,
#     'Net Value': 32557.761820429896,
#     'Delta Number': 0.0,
#     'Avg Cost': 9179.67589324789},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 5055.419922,
#     'Net Value': 34003.95211816938,
#     'Delta Number': 0.0,
#     'Avg Cost': 4685.66197670241}]},
#  {'Date': Timestamp('2015-04-29 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 50592.00498739101,
#     'Net Value': 250383.97055493106,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9272.803640328615,
#     'Net Value': 32439.232455942216,
#     'Delta Number': 0.0,
#     'Avg Cost': 9179.67589324789},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 5023.640136999999,
#     'Net Value': 33790.19375503854,
#     'Delta Number': 0.0,
#     'Avg Cost': 4685.66197670241}]},
#  {'Date': Timestamp('2015-04-30 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 50503.41644344958,
#     'Net Value': 249945.53860539157,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9281.159290368278,
#     'Net Value': 32468.46319180923,
#     'Delta Number': 0.0,
#     'Avg Cost': 9179.67589324789},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 4941.419922,
#     'Net Value': 33237.16110945378,
#     'Delta Number': 0.0,
#     'Avg Cost': 4685.66197670241}]},
#  {'Date': Timestamp('2015-05-04 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 50318.740406804725,
#     'Net Value': 249031.56179555744,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9282.970162597885,
#     'Net Value': 32474.798201961796,
#     'Delta Number': 0.0,
#     'Avg Cost': 9179.67589324789},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 5016.930176,
#     'Net Value': 33745.06096763826,
#     'Delta Number': 0.0,
#     'Avg Cost': 4685.66197670241}]},
#  {'Date': Timestamp('2015-05-05 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 51481.17718190993,
#     'Net Value': 254784.55647015967,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9243.469532459674,
#     'Net Value': 32336.612365950263,
#     'Delta Number': 0.0,
#     'Avg Cost': 9179.67589324789},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 4939.330078,
#     'Net Value': 33223.10432358695,
#     'Delta Number': 0.0,
#     'Avg Cost': 4685.66197670241}]},
#  {'Date': Timestamp('2015-05-06 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 50963.68653012062,
#     'Net Value': 252223.45290938244,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9301.461859041417,
#     'Net Value': 32539.488069525432,
#     'Delta Number': 0.0,
#     'Avg Cost': 9179.67589324789},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 4919.640136999999,
#     'Net Value': 33090.66511550852,
#     'Delta Number': 0.0,
#     'Avg Cost': 4685.66197670241}]},
#  {'Date': Timestamp('2015-05-07 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 50938.41727726466,
#     'Net Value': 252098.39331025,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9159.042509211939,
#     'Net Value': 32041.25963996506,
#     'Delta Number': 0.0,
#     'Avg Cost': 9179.67589324789},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 4945.540039,
#     'Net Value': 33264.87399252796,
#     'Delta Number': 0.0,
#     'Avg Cost': 4685.66197670241}]},
#  {'Date': Timestamp('2015-05-08 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 52037.44667408374,
#     'Net Value': 257537.57968368454,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9189.059567669548,
#     'Net Value': 32146.268909514903,
#     'Delta Number': 0.0,
#     'Avg Cost': 9179.67589324789},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 5003.549805,
#     'Net Value': 33655.06142223406,
#     'Delta Number': 0.0,
#     'Avg Cost': 4685.66197670241}]},
#  {'Date': Timestamp('2015-05-11 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 50581.216212006184,
#     'Net Value': 250330.57602314782,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9143.814335243802,
#     'Net Value': 31987.986617652427,
#     'Delta Number': 0.0,
#     'Avg Cost': 9179.67589324789},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 4993.569824,
#     'Net Value': 33587.933705585354,
#     'Delta Number': 0.0,
#     'Avg Cost': 4685.66197670241}]},
#  {'Date': Timestamp('2015-05-12 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 50916.13943846014,
#     'Net Value': 251988.13846392298,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9133.104830291002,
#     'Net Value': 31950.521344567056,
#     'Delta Number': 0.0,
#     'Avg Cost': 9179.67589324789},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 4976.189941,
#     'Net Value': 33471.032494910534,
#     'Delta Number': 0.0,
#     'Avg Cost': 4685.66197670241}]},
#  {'Date': Timestamp('2015-05-13 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 50206.03250427649,
#     'Net Value': 248473.76116767223,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9131.547947421095,
#     'Net Value': 31945.074870417215,
#     'Delta Number': 0.0,
#     'Avg Cost': 9179.67589324789},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 4981.689941,
#     'Net Value': 33508.02679796261,
#     'Delta Number': 0.0,
#     'Avg Cost': 4685.66197670241}]},
#  {'Date': Timestamp('2015-05-14 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 51257.12498927821,
#     'Net Value': 253675.70384380795,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 8997.376872914736,
#     'Net Value': 31475.70154562835,
#     'Delta Number': 0.0,
#     'Avg Cost': 9179.67589324789},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 5050.799805,
#     'Net Value': 33972.87611663592,
#     'Delta Number': 0.0,
#     'Avg Cost': 4685.66197670241}]},
#  {'Date': Timestamp('2015-05-15 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 51715.01349856896,
#     'Net Value': 255941.83152655684,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 8987.184964975513,
#     'Net Value': 31440.04699241727,
#     'Delta Number': 0.0,
#     'Avg Cost': 9179.67589324789},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 5048.290039,
#     'Net Value': 33955.99483590978,
#     'Delta Number': 0.0,
#     'Avg Cost': 4685.66197670241}]},
#  {'Date': Timestamp('2015-05-18 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 50603.48424657106,
#     'Net Value': 250440.78234749092,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9020.72897264137,
#     'Net Value': 31557.394658170066,
#     'Delta Number': 0.0,
#     'Avg Cost': 9179.67589324789},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 5078.439941,
#     'Net Value': 34158.79021983308,
#     'Delta Number': 0.0,
#     'Avg Cost': 4685.66197670241}]},
#  {'Date': Timestamp('2015-05-19 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 0.6159498606776559,
#     'Price': 49444.06311103023,
#     'Net Value': 30455.063784576294,
#     'Delta Number': -4.333131928378421,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 28.498869573909545,
#     'Price': 9108.212535831586,
#     'Net Value': 259573.7611101123,
#     'Delta Number': 25.00054978690793,
#     'Avg Cost': 9116.984872455208},
#    {'Asset': '^IXIC',
#     'Number': 6.826669672240306,
#     'Price': 5070.029785,
#     'Net Value': 34611.418570614536,
#     'Delta Number': 0.10043275368242988,
#     'Avg Cost': 4691.316727740267}]},
#  {'Date': Timestamp('2015-05-20 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 0.6159498606776559,
#     'Price': 49508.0227871988,
#     'Net Value': 30494.459738201316,
#     'Delta Number': 0.0,
#     'Avg Cost': 48949.26603657857},
#    {'Asset': '^TWII',
#     'Number': 28.498869573909545,
#     'Price': 9065.90983179469,
#     'Net Value': 258368.1818651411,
#     'Delta Number': 0.0,
#     'Avg Cost': 9116.984872455208},
#    {'Asset': '^IXIC',
#     'Number': 6.826669672240306,
#     'Price': 5071.740234000001,
#     'Net Value': 34623.09524092876,
#     'Delta Number': 0.0,
#     'Avg Cost': 4691.316727740267}]},
#  {'Date': Timestamp('2015-05-21 00:00:00'),
# ...
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.884329278240505,
#     'Price': 8161.850098000001,
#     'Net Value': 56188.863594271534,
#     'Delta Number': 0.0,
#     'Avg Cost': 5472.291137602342}]},
#  {'Date': Timestamp('2019-04-30 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.5553860658609144,
#     'Price': 83542.29615667395,
#     'Net Value': 213482.81950879045,
#     'Delta Number': 0.0,
#     'Avg Cost': 83269.6591177369},
#    {'Asset': '^TWII',
#     'Number': 22.7569675717081,
#     'Price': 10271.538346552898,
#     'Net Value': 233749.0650640605,
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.884329278240505,
#     'Price': 8095.390137,
#     'Net Value': 55731.33133892851,
#     'Delta Number': 0.0,
#     'Avg Cost': 5472.291137602342}]},
#  {'Date': Timestamp('2019-05-02 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.5553860658609144,
#     'Price': 81882.75718169694,
#     'Net Value': 209242.05673638108,
#     'Delta Number': 0.0,
#     'Avg Cost': 83269.6591177369},
#    {'Asset': '^TWII',
#     'Number': 22.7569675717081,
#     'Price': 10292.961834309923,
#     'Net Value': 234236.59868022002,
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.884329278240505,
#     'Price': 8036.77002,
#     'Net Value': 55327.771151171524,
#     'Delta Number': 0.0,
#     'Avg Cost': 5472.291137602342}]},
#  {'Date': Timestamp('2019-05-03 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.5553860658609144,
#     'Price': 82911.40031861457,
#     'Net Value': 211870.63707520385,
#     'Delta Number': 0.0,
#     'Avg Cost': 83269.6591177369},
#    {'Asset': '^TWII',
#     'Number': 22.7569675717081,
#     'Price': 10394.97226650218,
#     'Net Value': 236558.04677759515,
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.884329278240505,
#     'Price': 8164.0,
#     'Net Value': 56203.66422755548,
#     'Delta Number': 0.0,
#     'Avg Cost': 5472.291137602342}]},
#  {'Date': Timestamp('2019-05-06 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.5553860658609144,
#     'Price': 81400.49091671078,
#     'Net Value': 208009.68024280068,
#     'Delta Number': 0.0,
#     'Avg Cost': 83269.6591177369},
#    {'Asset': '^TWII',
#     'Number': 22.7569675717081,
#     'Price': 10214.984570558952,
#     'Net Value': 232462.07261770865,
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.884329278240505,
#     'Price': 8123.290039,
#     'Net Value': 55923.40345112715,
#     'Delta Number': 0.0,
#     'Avg Cost': 5472.291137602342}]},
#  {'Date': Timestamp('2019-05-07 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.5553860658609144,
#     'Price': 80836.94821293309,
#     'Net Value': 206569.61107004955,
#     'Delta Number': 0.0,
#     'Avg Cost': 83269.6591177369},
#    {'Asset': '^TWII',
#     'Number': 22.7569675717081,
#     'Price': 10304.695190606317,
#     'Net Value': 234503.61428896437,
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.884329278240505,
#     'Price': 7963.759765999999,
#     'Net Value': 54825.14452194754,
#     'Delta Number': 0.0,
#     'Avg Cost': 5472.291137602342}]},
#  {'Date': Timestamp('2019-05-08 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.5553860658609144,
#     'Price': 82714.78420807907,
#     'Net Value': 211368.20700601768,
#     'Delta Number': 0.0,
#     'Avg Cost': 83269.6591177369},
#    {'Asset': '^TWII',
#     'Number': 22.7569675717081,
#     'Price': 10261.75332541221,
#     'Net Value': 233526.3876552734,
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.884329278240505,
#     'Price': 7943.319823999999,
#     'Net Value': 54684.42923079141,
#     'Delta Number': 0.0,
#     'Avg Cost': 5472.291137602342}]},
#  {'Date': Timestamp('2019-05-09 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.5553860658609144,
#     'Price': 81679.36819331572,
#     'Net Value': 208722.31934952218,
#     'Delta Number': 0.0,
#     'Avg Cost': 83269.6591177369},
#    {'Asset': '^TWII',
#     'Number': 22.7569675717081,
#     'Price': 10065.993627958447,
#     'Net Value': 229071.49056847073,
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.884329278240505,
#     'Price': 7910.589844,
#     'Net Value': 54459.10527120119,
#     'Delta Number': 0.0,
#     'Avg Cost': 5472.291137602342}]},
#  {'Date': Timestamp('2019-05-10 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.5553860658609144,
#     'Price': 80978.15450469885,
#     'Net Value': 206930.44766043968,
#     'Delta Number': 0.0,
#     'Avg Cost': 83269.6591177369},
#    {'Asset': '^TWII',
#     'Number': 22.7569675717081,
#     'Price': 10099.18160621821,
#     'Net Value': 229826.7483134987,
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.884329278240505,
#     'Price': 7916.939941,
#     'Net Value': 54502.82142989795,
#     'Delta Number': 0.0,
#     'Avg Cost': 5472.291137602342}]},
#  {'Date': Timestamp('2019-05-13 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 78086.62862919236,
#     'Net Value': 356371.51423727977,
#     'Delta Number': 2.008410841412039,
#     'Avg Cost': 80988.73934061603},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 9968.379853525372,
#     'Net Value': 50066.485272147045,
#     'Delta Number': -17.734437731571564,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7647.02002,
#     'Net Value': 52932.30090141929,
#     'Delta Number': 0.03762211759477019,
#     'Avg Cost': 5484.11120120457}]},
#  {'Date': Timestamp('2019-05-14 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 78742.2992189426,
#     'Net Value': 359363.8616469717,
#     'Delta Number': 0.0,
#     'Avg Cost': 80988.73934061603},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 9906.024557977555,
#     'Net Value': 49753.303939567595,
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7734.490234000001,
#     'Net Value': 53537.76547131061,
#     'Delta Number': 0.0,
#     'Avg Cost': 5484.11120120457}]},
#  {'Date': Timestamp('2019-05-15 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 77839.90145698455,
#     'Net Value': 355245.50153181754,
#     'Delta Number': 0.0,
#     'Avg Cost': 80988.73934061603},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 9987.62257107978,
#     'Net Value': 50163.13239526938,
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7822.149901999999,
#     'Net Value': 54144.54143258165,
#     'Delta Number': 0.0,
#     'Avg Cost': 5484.11120120457}]},
#  {'Date': Timestamp('2019-05-16 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 75624.85123527306,
#     'Net Value': 345136.4621805164,
#     'Delta Number': 0.0,
#     'Avg Cost': 80988.73934061603},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 9957.923893146699,
#     'Net Value': 50013.969899137875,
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7898.049805,
#     'Net Value': 54669.91687209627,
#     'Delta Number': 0.0,
#     'Avg Cost': 5484.11120120457}]},
#  {'Date': Timestamp('2019-05-17 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 74653.824499586,
#     'Net Value': 340704.8933673084,
#     'Delta Number': 0.0,
#     'Avg Cost': 80988.73934061603},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 9880.067938853723,
#     'Net Value': 49622.93604546909,
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7816.279785,
#     'Net Value': 54103.90876801979,
#     'Delta Number': 0.0,
#     'Avg Cost': 5484.11120120457}]},
#  {'Date': Timestamp('2019-05-20 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 76304.44807549375,
#     'Net Value': 348238.00413810805,
#     'Delta Number': 0.0,
#     'Avg Cost': 80988.73934061603},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 9909.425884261562,
#     'Net Value': 49770.387202325066,
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7702.379883,
#     'Net Value': 53315.499182385385,
#     'Delta Number': 0.0,
#     'Avg Cost': 5484.11120120457}]},
#  {'Date': Timestamp('2019-05-21 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 79532.80648441186,
#     'Net Value': 362971.57626029715,
#     'Delta Number': 0.0,
#     'Avg Cost': 80988.73934061603},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 9970.822622654678,
#     'Net Value': 50078.75415299155,
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7785.720215,
#     'Net Value': 53892.376909802166,
#     'Delta Number': 0.0,
#     'Avg Cost': 5484.11120120457}]},
#  {'Date': Timestamp('2019-05-22 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 79396.65803687906,
#     'Net Value': 362350.22239651694,
#     'Delta Number': 0.0,
#     'Avg Cost': 80988.73934061603},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 9991.13291086435,
#     'Net Value': 50180.76318158639,
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7750.839844,
#     'Net Value': 53650.93667707146,
#     'Delta Number': 0.0,
#     'Avg Cost': 5484.11120120457}]},
#  {'Date': Timestamp('2019-05-23 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 79017.18036310884,
#     'Net Value': 360618.3633625853,
#     'Delta Number': 0.0,
#     'Avg Cost': 80988.73934061603},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 9835.175699969419,
#     'Net Value': 49397.46343608214,
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7628.279785,
#     'Net Value': 52802.581905602754,
#     'Delta Number': 0.0,
#     'Avg Cost': 5484.11120120457}]},
#  {'Date': Timestamp('2019-05-24 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 79126.53320748075,
#     'Net Value': 361117.42753553134,
#     'Delta Number': 0.0,
#     'Avg Cost': 80988.73934061603},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 9842.593852495684,
#     'Net Value': 49434.72132850399,
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7637.009765999999,
#     'Net Value': 52863.01040977132,
#     'Delta Number': 0.0,
#     'Avg Cost': 5484.11120120457}]},
#  {'Date': Timestamp('2019-05-28 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 81821.71774145291,
#     'Net Value': 373417.7023762034,
#     'Delta Number': 0.0,
#     'Avg Cost': 80988.73934061603},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 9833.605662138038,
#     'Net Value': 49389.57787422388,
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7607.350098000001,
#     'Net Value': 52657.70762945872,
#     'Delta Number': 0.0,
#     'Avg Cost': 5484.11120120457}]},
#  {'Date': Timestamp('2019-05-29 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 82994.03265644932,
#     'Net Value': 378767.9095596139,
#     'Delta Number': 0.0,
#     'Avg Cost': 80988.73934061603},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 9827.922732182526,
#     'Net Value': 49361.03518894292,
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7547.310059,
#     'Net Value': 52242.11339769666,
#     'Delta Number': 0.0,
#     'Avg Cost': 5484.11120120457}]},
#  {'Date': Timestamp('2019-05-30 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 83591.42089656282,
#     'Net Value': 381494.26816228515,
#     'Delta Number': 0.0,
#     'Avg Cost': 80988.73934061603},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 9894.103662409445,
#     'Net Value': 49693.43088585562,
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7567.720215,
#     'Net Value': 52383.39150551008,
#     'Delta Number': 0.0,
#     'Avg Cost': 5484.11120120457}]},
#  {'Date': Timestamp('2019-05-31 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 84515.16197833086,
#     'Net Value': 385710.0348543791,
#     'Delta Number': 0.0,
#     'Avg Cost': 80988.73934061603},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 9960.074530450183,
#     'Net Value': 50024.77153916993,
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7453.149901999999,
#     'Net Value': 51590.341367518435,
#     'Delta Number': 0.0,
#     'Avg Cost': 5484.11120120457}]},
#  {'Date': Timestamp('2019-06-03 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 85300.8124155411,
#     'Net Value': 389295.5838899169,
#     'Delta Number': 0.0,
#     'Avg Cost': 80988.73934061603},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 9950.46991019066,
#     'Net Value': 49976.5320473133,
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7333.02002,
#     'Net Value': 50758.80816312701,
#     'Delta Number': 0.0,
#     'Avg Cost': 5484.11120120457}]},
#  {'Date': Timestamp('2019-06-04 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 86319.38957485263,
#     'Net Value': 393944.16317940166,
#     'Delta Number': 0.0,
#     'Avg Cost': 80988.73934061603},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 9882.918324129809,
#     'Net Value': 49637.25219057412,
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7527.120117,
#     'Net Value': 52102.35960048793,
#     'Delta Number': 0.0,
#     'Avg Cost': 5484.11120120457}]},
#  {'Date': Timestamp('2019-06-05 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 84508.08905058207,
#     'Net Value': 385677.7554485938,
#     'Delta Number': 0.0,
#     'Avg Cost': 80988.73934061603},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 9896.963660076215,
#     'Net Value': 49707.79530947969,
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7575.47998,
#     'Net Value': 52437.10422168318,
#     'Delta Number': 0.0,
#     'Avg Cost': 5484.11120120457}]},
#  {'Date': Timestamp('2019-06-06 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 85569.73297807093,
#     'Net Value': 390522.88272149255,
#     'Delta Number': 0.0,
#     'Avg Cost': 80988.73934061603},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 9865.614173550077,
#     'Net Value': 49550.341577929205,
#     'Delta Number': 0.0,
#     'Avg Cost': 9594.490624834576},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7615.549805,
#     'Net Value': 52714.465602772805,
#     'Delta Number': 0.0,
#     'Avg Cost': 5484.11120120457}]},
#  ...]

# %%
nominal_price_result
# Out:
# [{'Date': Timestamp('2015-01-13 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 48448.06787884689,
#     'Net Value': 100845.23516682671,
#     'Delta Number': 2.0815120103242997,
#     'Avg Cost': 48448.06787884689},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9216.083635735256,
#     'Net Value': 99830.13011918028,
#     'Delta Number': 10.832164080205406,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4656.41492685446,
#     'Net Value': 99890.91337240073,
#     'Delta Number': 21.452322213879654,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-01-14 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 47549.305037822676,
#     'Net Value': 98974.44951880163,
#     'Delta Number': 0.0,
#     'Avg Cost': 48448.06787884689},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9217.617403707209,
#     'Net Value': 99846.74414551344,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4631.365424414574,
#     'Net Value': 99353.54337476293,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-01-15 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 48661.50879926725,
#     'Net Value': 101289.51500617637,
#     'Delta Number': 0.0,
#     'Avg Cost': 48448.06787884689},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9153.56403846688,
#     'Net Value': 99152.90758334087,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4594.260408569968,
#     'Net Value': 98557.55461911333,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-01-16 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 49087.14281794564,
#     'Net Value': 102175.47732805804,
#     'Delta Number': 0.0,
#     'Avg Cost': 48448.06787884689},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9254.86067455554,
#     'Net Value': 100250.1693662261,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4634.199022916845,
#     'Net Value': 99414.33064285842,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-01-20 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 48505.9524028235,
#     'Net Value': 100965.72249869595,
#     'Delta Number': 0.0,
#     'Avg Cost': 48448.06787884689},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9188.367405185496,
#     'Net Value': 99529.90336218047,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4641.200103173493,
#     'Net Value': 99564.52007236925,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-01-21 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 48735.732885034966,
#     'Net Value': 101444.0133321572,
#     'Delta Number': 0.0,
#     'Avg Cost': 48448.06787884689},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9290.121017743477,
#     'Net Value': 100632.11518916217,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4680.220551770073,
#     'Net Value': 100401.59930859323,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-01-22 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 49641.19639833069,
#     'Net Value': 103328.7465099927,
#     'Delta Number': 0.0,
#     'Avg Cost': 48448.06787884689},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9381.154210667053,
#     'Net Value': 101618.20167165535,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4655.40975567148,
#     'Net Value': 99869.35011630334,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-01-23 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 49035.148258339505,
#     'Net Value': 102067.25002776635,
#     'Delta Number': 0.0,
#     'Avg Cost': 48448.06787884689},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9466.451564487585,
#     'Net Value': 102542.15660384668,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4760.034193299358,
#     'Net Value': 102113.78726374253,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-01-26 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 48700.230752781936,
#     'Net Value': 101370.11521748042,
#     'Delta Number': 0.0,
#     'Avg Cost': 48448.06787884689},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9443.363590724133,
#     'Net Value': 102292.0638837615,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4764.963399723878,
#     'Net Value': 102219.53018822006,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-01-27 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 48286.21657261884,
#     'Net Value': 100508.33972902635,
#     'Delta Number': 0.0,
#     'Avg Cost': 48448.06787884689},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9480.746909677518,
#     'Net Value': 102697.00612852722,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4712.343142469128,
#     'Net Value': 101090.70347461393,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-01-28 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 48127.41640507894,
#     'Net Value': 100177.79527305055,
#     'Delta Number': 0.0,
#     'Avg Cost': 48448.06787884689},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9486.72312702197,
#     'Net Value': 102761.7414953813,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4706.180230642667,
#     'Net Value': 100958.49470433696,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-01-29 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 47863.40732050907,
#     'Net Value': 99628.25719268362,
#     'Delta Number': 0.0,
#     'Avg Cost': 48448.06787884689},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9455.997521698075,
#     'Net Value': 102428.91669704922,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4644.055726247115,
#     'Net Value': 99625.779818666,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-01-30 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 46897.45193594671,
#     'Net Value': 97617.60945827965,
#     'Delta Number': 0.0,
#     'Avg Cost': 48448.06787884689},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9392.877061455963,
#     'Net Value': 101745.1855148886,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4702.015459579045,
#     'Net Value': 100869.15069353308,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-02-02 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 47146.846252603355,
#     'Net Value': 98136.72672370708,
#     'Delta Number': 0.0,
#     'Avg Cost': 48448.06787884689},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9367.16219844281,
#     'Net Value': 101466.6378994301,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4619.628544170272,
#     'Net Value': 99101.76003797645,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-02-03 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.0815120103242997,
#     'Price': 48213.687083106655,
#     'Net Value': 100357.36872550406,
#     'Delta Number': 0.0,
#     'Avg Cost': 48448.06787884689},
#    {'Asset': '^TWII',
#     'Number': 10.832164080205406,
#     'Price': 9441.01676757139,
#     'Net Value': 102266.64271030374,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 21.452322213879654,
#     'Price': 4719.134345904474,
#     'Net Value': 101236.39055892898,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-02-04 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 48551.10081928838,
#     'Net Value': 243797.8917988314,
#     'Delta Number': 2.9399578983863055,
#     'Avg Cost': 48508.391352361985},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9526.147340095,
#     'Net Value': 30519.425935227202,
#     'Delta Number': -7.628410784602606,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4705.587014585493,
#     'Net Value': 30519.42593522721,
#     'Delta Number': -14.966537158661499,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-02-05 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 49698.80762907342,
#     'Net Value': 249561.06700818922,
#     'Delta Number': 0.0,
#     'Avg Cost': 48508.391352361985},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9482.12889668175,
#     'Net Value': 30378.401702074698,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4739.28235663975,
#     'Net Value': 30737.96668115317,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-02-06 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 48397.39304819877,
#     'Net Value': 243026.05285156996,
#     'Delta Number': 0.0,
#     'Avg Cost': 48508.391352361985},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9505.241522181304,
#     'Net Value': 30452.44885218893,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4783.574929732336,
#     'Net Value': 31025.238789774226,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-02-09 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 48504.50164741917,
#     'Net Value': 243563.89545951935,
#     'Delta Number': 0.0,
#     'Avg Cost': 48508.391352361985},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9413.951524990465,
#     'Net Value': 30159.978222833208,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4745.37816336684,
#     'Net Value': 30777.50277332323,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-02-10 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 48594.63041503663,
#     'Net Value': 244016.47435401956,
#     'Delta Number': 0.0,
#     'Avg Cost': 48508.391352361985},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9403.02077513861,
#     'Net Value': 30124.958796971914,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4744.866227294908,
#     'Net Value': 30774.182465998663,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-02-11 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 48351.067857655406,
#     'Net Value': 242793.43230124118,
#     'Delta Number': 0.0,
#     'Avg Cost': 48508.391352361985},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9458.141446604946,
#     'Net Value': 30301.55182983803,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4785.9018787663845,
#     'Net Value': 31040.33088104351,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-02-12 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 48428.75210415378,
#     'Net Value': 243183.5214074136,
#     'Delta Number': 0.0,
#     'Avg Cost': 48508.391352361985},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9453.783605026103,
#     'Net Value': 30287.590380518097,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4823.631391580241,
#     'Net Value': 31285.03639139228,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-02-13 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 50311.804892481436,
#     'Net Value': 252639.21432051453,
#     'Delta Number': 0.0,
#     'Avg Cost': 48508.391352361985},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9530.257836357303,
#     'Net Value': 30532.59495117412,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4873.054115918286,
#     'Net Value': 31605.58155829214,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-02-24 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 51247.13875015536,
#     'Net Value': 257335.96514142235,
#     'Delta Number': 0.0,
#     'Avg Cost': 48508.391352361985},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9624.682673939404,
#     'Net Value': 30835.10883576453,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4968.4671541208045,
#     'Net Value': 32224.410015538993,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-02-25 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 51821.97499081537,
#     'Net Value': 260222.4880263329,
#     'Delta Number': 0.0,
#     'Avg Cost': 48508.391352361985},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9656.528290527163,
#     'Net Value': 30937.13433485807,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4981.646783537253,
#     'Net Value': 32309.89025904151,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-02-26 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 51511.665826733566,
#     'Net Value': 258664.279896499,
#     'Delta Number': 0.0,
#     'Avg Cost': 48508.391352361985},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9617.732555418543,
#     'Net Value': 30812.842370648494,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4972.220306107441,
#     'Net Value': 32248.75215260388,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-03-02 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 50799.200067213176,
#     'Net Value': 255086.65452408072,
#     'Delta Number': 0.0,
#     'Avg Cost': 48508.391352361985},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9625.31588830442,
#     'Net Value': 30837.137498373275,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4984.299834160283,
#     'Net Value': 32327.097375123096,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-03-03 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 51075.99612827832,
#     'Net Value': 256476.57761556894,
#     'Delta Number': 0.0,
#     'Avg Cost': 48508.391352361985},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9620.188932129167,
#     'Net Value': 30820.7119956304,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4992.062520254855,
#     'Net Value': 32377.44448858362,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-03-04 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 50712.216109176625,
#     'Net Value': 254649.8671962596,
#     'Delta Number': 0.0,
#     'Avg Cost': 48508.391352361985},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9596.418691581115,
#     'Net Value': 30744.558009137305,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4952.171923552356,
#     'Net Value': 32118.722652646815,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-03-05 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 50705.715372092694,
#     'Net Value': 254617.22394060824,
#     'Delta Number': 0.0,
#     'Avg Cost': 48508.391352361985},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9565.689919470575,
#     'Net Value': 30646.110604218335,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4964.704440075363,
#     'Net Value': 32200.00586101601,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-03-06 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 50043.68480081415,
#     'Net Value': 251292.85734828655,
#     'Delta Number': 0.0,
#     'Avg Cost': 48508.391352361985},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9614.149784958438,
#     'Net Value': 30801.364057979543,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4920.705567392727,
#     'Net Value': 31914.638630124522,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-03-09 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 49127.72447838944,
#     'Net Value': 246693.390151658,
#     'Delta Number': 0.0,
#     'Avg Cost': 48508.391352361985},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9611.804563170366,
#     'Net Value': 30793.85054594709,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4948.078324336165,
#     'Net Value': 32092.17244802839,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-03-10 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 48673.11384307666,
#     'Net Value': 244410.57652625506,
#     'Delta Number': 0.0,
#     'Avg Cost': 48508.391352361985},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9556.372049178502,
#     'Net Value': 30616.258446562108,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4901.087603378094,
#     'Net Value': 31787.40073230461,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-03-11 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 48514.67784977327,
#     'Net Value': 243614.9949534254,
#     'Delta Number': 0.0,
#     'Avg Cost': 48508.391352361985},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9501.782676328376,
#     'Net Value': 30441.367563388627,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4866.843967495409,
#     'Net Value': 31565.303870460357,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-03-12 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 49282.178810826445,
#     'Net Value': 247468.9779342604,
#     'Delta Number': 0.0,
#     'Avg Cost': 48508.391352361985},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9583.11953312071,
#     'Net Value': 30701.950786391037,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4872.235996029685,
#     'Net Value': 31600.275408545276,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-03-13 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.021469908710605,
#     'Price': 48339.556409571574,
#     'Net Value': 242735.62791108253,
#     'Delta Number': 0.0,
#     'Avg Cost': 48508.391352361985},
#    {'Asset': '^TWII',
#     'Number': 3.2037532956028,
#     'Price': 9598.840399124443,
#     'Net Value': 30752.31656266023,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.485785055218155,
#     'Price': 4870.181994822191,
#     'Net Value': 31586.953598210308,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-03-16 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 48653.11538108059,
#     'Net Value': 245467.3480066925,
#     'Delta Number': 0.023784564390324725,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9589.231660044865,
#     'Net Value': 30683.78080287238,
#     'Delta Number': -0.003936887921100141,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4903.973901948136,
#     'Net Value': 30683.780802872378,
#     'Delta Number': -0.2288633389987753,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-03-17 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 50375.30199295993,
#     'Net Value': 254156.2177137913,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9566.786956733782,
#     'Net Value': 30611.96187295203,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4907.414115754562,
#     'Net Value': 30705.305951346243,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-03-18 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 50419.616195760536,
#     'Net Value': 254379.79414369294,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9634.700317648605,
#     'Net Value': 30829.27215950809,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4947.452147834349,
#     'Net Value': 30955.82078374095,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-03-19 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 51273.17656140837,
#     'Net Value': 258686.22339653934,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9692.257179945058,
#     'Net Value': 31013.443551858956,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4986.750938015751,
#     'Net Value': 31201.710237448115,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-03-20 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 51400.83448146294,
#     'Net Value': 259330.2900887214,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9739.293862585577,
#     'Net Value': 31163.952300735007,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 5039.7371020707615,
#     'Net Value': 31533.240517983075,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-03-23 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 51560.24246193379,
#     'Net Value': 260134.54391523995,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9773.082465078302,
#     'Net Value': 31272.06962538386,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 5014.022200061702,
#     'Net Value': 31372.344389172136,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-03-24 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 51541.890016292265,
#     'Net Value': 260041.9511567747,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9751.825606190027,
#     'Net Value': 31204.051579537383,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 5000.984302921915,
#     'Net Value': 31290.767287424365,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-03-25 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 51945.63593999755,
#     'Net Value': 262078.95208434504,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9725.386454671467,
#     'Net Value': 31119.451148703116,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4989.912531583577,
#     'Net Value': 31221.49208090051,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-03-26 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 50945.347498544106,
#     'Net Value': 257032.24235071093,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9603.846364955822,
#     'Net Value': 30730.545175439885,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4869.034873366546,
#     'Net Value': 30465.17003619662,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-03-27 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 49931.40914635682,
#     'Net Value': 251916.6653438894,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9581.624952878748,
#     'Net Value': 30659.44073647381,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4861.981101673278,
#     'Net Value': 30421.03513890776,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-03-30 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 50750.395827861044,
#     'Net Value': 256048.6615621587,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9511.090381904918,
#     'Net Value': 30433.743058962962,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4934.40685990937,
#     'Net Value': 30874.197438428815,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-03-31 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 51114.11885852972,
#     'Net Value': 257883.73680960966,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9567.067638676215,
#     'Net Value': 30612.860003636768,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4899.5066379211685,
#     'Net Value': 30655.829481569963,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-04-01 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 51588.666766130904,
#     'Net Value': 260277.95176313524,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9541.045185377172,
#     'Net Value': 30529.59293060236,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4857.007028032353,
#     'Net Value': 30389.91274952578,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-04-02 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 52886.53374718949,
#     'Net Value': 266826.0209548111,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9570.68872384049,
#     'Net Value': 30624.44681135903,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4880.038008781382,
#     'Net Value': 30534.01579312021,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-04-07 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 53891.918516294296,
#     'Net Value': 271898.4429583246,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9616.371493474033,
#     'Net Value': 30770.62328718078,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4917.612894321178,
#     'Net Value': 30769.118910438618,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-04-08 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 53610.956098817136,
#     'Net Value': 270480.91606477473,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9636.091659558462,
#     'Net Value': 30833.724198179945,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4921.506811058672,
#     'Net Value': 30793.482842634592,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-04-09 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 53604.205041171524,
#     'Net Value': 270446.85526099004,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9646.332268624637,
#     'Net Value': 30866.49226709455,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4975.841141484651,
#     'Net Value': 31133.448494613145,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-04-10 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 54255.65257988466,
#     'Net Value': 273733.5738696731,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9624.744759085832,
#     'Net Value': 30797.41619987129,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4980.295042876478,
#     'Net Value': 31161.316206953565,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-04-13 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 54501.561581843554,
#     'Net Value': 274974.247361782,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9632.80615089517,
#     'Net Value': 30823.211173651565,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 5015.672976126305,
#     'Net Value': 31382.673165779364,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-04-14 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 54528.592340374,
#     'Net Value': 275110.624417169,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9647.911024664583,
#     'Net Value': 30871.543996574892,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 4964.7880710512145,
#     'Net Value': 31064.29029818727,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-04-15 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 5.04525447310093,
#     'Price': 54298.4930316232,
#     'Net Value': 273949.7148504366,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.1998164076816997,
#     'Price': 9633.969612917346,
#     'Net Value': 30826.934038519837,
#     'Delta Number': 0.0,
#     'Avg Cost': 9216.083635735256},
#    {'Asset': '^IXIC',
#     'Number': 6.25692171621938,
#     'Price': 5014.432877695466,
#     'Net Value': 31374.9139669772,
#     'Delta Number': 0.0,
#     'Avg Cost': 4656.41492685446}]},
#  {'Date': Timestamp('2015-04-16 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 54489.073420092376,
#     'Net Value': 269670.8809659187,
#     'Delta Number': -0.09617268404485291,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9633.669722327333,
#     'Net Value': 33701.65741105608,
#     'Delta Number': 0.298503379319917,
#     'Avg Cost': 9251.71527194755},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 5010.672464479288,
#     'Net Value': 33702.97011738196,
#     'Delta Number': 0.4693152023384961,
#     'Avg Cost': 4681.132826322381}]},
#  {'Date': Timestamp('2015-04-17 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 54611.82080095102,
#     'Net Value': 270278.3677931806,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9611.792392432404,
#     'Net Value': 33625.12351499789,
#     'Delta Number': 0.0,
#     'Avg Cost': 9251.71527194755},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 4948.433083248124,
#     'Net Value': 33284.33329355671,
#     'Delta Number': 0.0,
#     'Avg Cost': 4681.132826322381}]},
#  {'Date': Timestamp('2015-04-20 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 53822.257077708826,
#     'Net Value': 266370.7523491833,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9532.949868567528,
#     'Net Value': 33349.30715370424,
#     'Delta Number': 0.0,
#     'Avg Cost': 9251.71527194755},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 4962.5873618867945,
#     'Net Value': 33379.53832509169,
#     'Delta Number': 0.0,
#     'Avg Cost': 4681.132826322381}]},
#  {'Date': Timestamp('2015-04-22 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 53762.14395034617,
#     'Net Value': 266073.2475652696,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9563.30429445477,
#     'Net Value': 33455.49664240866,
#     'Delta Number': 0.0,
#     'Avg Cost': 9251.71527194755},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 4993.397446121342,
#     'Net Value': 33586.77425113398,
#     'Delta Number': 0.0,
#     'Avg Cost': 4681.132826322381}]},
#  {'Date': Timestamp('2015-04-23 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 55268.33495985514,
#     'Net Value': 273527.51006127044,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9805.842177439046,
#     'Net Value': 34303.971717550034,
#     'Delta Number': 0.0,
#     'Avg Cost': 9251.71527194755},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 5043.490602600224,
#     'Net Value': 33923.71268960933,
#     'Delta Number': 0.0,
#     'Avg Cost': 4681.132826322381}]},
#  {'Date': Timestamp('2015-04-24 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 56098.24251996293,
#     'Net Value': 277634.7904535998,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9870.263866283452,
#     'Net Value': 34529.33938634648,
#     'Delta Number': 0.0,
#     'Avg Cost': 9251.71527194755},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 5099.549680821779,
#     'Net Value': 34300.77933116348,
#     'Delta Number': 0.0,
#     'Avg Cost': 4681.132826322381}]},
#  {'Date': Timestamp('2015-04-27 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 55541.78650068229,
#     'Net Value': 274880.84410216735,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9966.502311422737,
#     'Net Value': 34866.01224324751,
#     'Delta Number': 0.0,
#     'Avg Cost': 9251.71527194755},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 5118.300544928186,
#     'Net Value': 34426.90208557086,
#     'Delta Number': 0.0,
#     'Avg Cost': 4681.132826322381}]},
#  {'Date': Timestamp('2015-04-28 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 55921.8464890734,
#     'Net Value': 276761.7920694627,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 10004.740446902619,
#     'Net Value': 34999.78146921483,
#     'Delta Number': 0.0,
#     'Avg Cost': 9251.71527194755},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 5052.209197005509,
#     'Net Value': 33982.3560211761,
#     'Delta Number': 0.0,
#     'Avg Cost': 4681.132826322381}]},
#  {'Date': Timestamp('2015-04-29 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 55806.531867047954,
#     'Net Value': 276191.09057358466,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9970.907154480088,
#     'Net Value': 34881.421792873676,
#     'Delta Number': 0.0,
#     'Avg Cost': 9251.71527194755},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 5018.676317284462,
#     'Net Value': 33756.80592761083,
#     'Delta Number': 0.0,
#     'Avg Cost': 4681.132826322381}]},
#  {'Date': Timestamp('2015-04-30 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 55608.00621309531,
#     'Net Value': 275208.5708749472,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9893.398173483769,
#     'Net Value': 34610.27059098392,
#     'Delta Number': 0.0,
#     'Avg Cost': 9251.71527194755},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 4929.642566668075,
#     'Net Value': 33157.94382721721,
#     'Delta Number': 0.0,
#     'Avg Cost': 4681.132826322381}]},
#  {'Date': Timestamp('2015-05-04 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 56859.76102106272,
#     'Net Value': 281403.60779942205,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9825.84945120091,
#     'Net Value': 34373.96355923512,
#     'Delta Number': 0.0,
#     'Avg Cost': 9251.71527194755},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 5034.26883793971,
#     'Net Value': 33861.68491569553,
#     'Delta Number': 0.0,
#     'Avg Cost': 4681.132826322381}]},
#  {'Date': Timestamp('2015-05-05 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 58074.82361461136,
#     'Net Value': 287417.0519537169,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9828.944709057676,
#     'Net Value': 34384.79176104131,
#     'Delta Number': 0.0,
#     'Avg Cost': 9251.71527194755},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 4975.085792216887,
#     'Net Value': 33463.605728601986,
#     'Delta Number': 0.0,
#     'Avg Cost': 4681.132826322381}]},
#  {'Date': Timestamp('2015-05-06 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 56848.14218038528,
#     'Net Value': 281346.1052066154,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9823.439965519416,
#     'Net Value': 34365.53440779905,
#     'Delta Number': 0.0,
#     'Avg Cost': 9251.71527194755},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 4949.744731694031,
#     'Net Value': 33293.15575175774,
#     'Delta Number': 0.0,
#     'Avg Cost': 4681.132826322381}]},
#  {'Date': Timestamp('2015-05-07 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 56959.889144489985,
#     'Net Value': 281899.1500716483,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9773.76603661378,
#     'Net Value': 34191.75911941036,
#     'Delta Number': 0.0,
#     'Avg Cost': 9251.71527194755},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 4936.820554947846,
#     'Net Value': 33206.224676985585,
#     'Delta Number': 0.0,
#     'Avg Cost': 4681.132826322381}]},
#  {'Date': Timestamp('2015-05-08 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 57086.53569271702,
#     'Net Value': 282525.93419712555,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9708.461011092528,
#     'Net Value': 33963.30125643871,
#     'Delta Number': 0.0,
#     'Avg Cost': 9251.71527194755},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 5000.85483435287,
#     'Net Value': 33636.93441117291,
#     'Delta Number': 0.0,
#     'Avg Cost': 4681.132826322381}]},
#  {'Date': Timestamp('2015-05-11 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 57029.1810497372,
#     'Net Value': 282242.0813780363,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9725.65358231902,
#     'Net Value': 34023.44636854979,
#     'Delta Number': 0.0,
#     'Avg Cost': 9251.71527194755},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 5011.47869361037,
#     'Net Value': 33708.39300552827,
#     'Delta Number': 0.0,
#     'Avg Cost': 4681.132826322381}]},
#  {'Date': Timestamp('2015-05-12 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 57352.6340349593,
#     'Net Value': 283842.8766568148,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9669.207565184788,
#     'Net Value': 33825.980149911666,
#     'Delta Number': 0.0,
#     'Avg Cost': 9251.71527194755},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 4968.288725865414,
#     'Net Value': 33417.887049970814,
#     'Delta Number': 0.0,
#     'Avg Cost': 4681.132826322381}]},
#  {'Date': Timestamp('2015-05-13 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 56326.803509783254,
#     'Net Value': 278765.95748600824,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9696.830936894517,
#     'Net Value': 33922.615537747515,
#     'Delta Number': 0.0,
#     'Avg Cost': 9251.71527194755},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 4998.204681532706,
#     'Net Value': 33619.1088554341,
#     'Delta Number': 0.0,
#     'Avg Cost': 4681.132826322381}]},
#  {'Date': Timestamp('2015-05-14 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 56174.727931034126,
#     'Net Value': 278013.32300866075,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9672.770790556771,
#     'Net Value': 33838.44545173602,
#     'Delta Number': 0.0,
#     'Avg Cost': 9251.71527194755},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 5023.122036965351,
#     'Net Value': 33786.70889145799,
#     'Delta Number': 0.0,
#     'Avg Cost': 4681.132826322381}]},
#  {'Date': Timestamp('2015-05-15 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 56921.979003160974,
#     'Net Value': 281711.52968157636,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9626.263062761305,
#     'Net Value': 33675.74654734066,
#     'Delta Number': 0.0,
#     'Avg Cost': 9251.71527194755},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 5035.73336237864,
#     'Net Value': 33871.5356540448,
#     'Delta Number': 0.0,
#     'Avg Cost': 4681.132826322381}]},
#  {'Date': Timestamp('2015-05-18 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.949081789056077,
#     'Price': 56379.53819348048,
#     'Net Value': 279026.9457487458,
#     'Delta Number': 0.0,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 3.4983197870016167,
#     'Price': 9600.2155680254,
#     'Net Value': 33584.62408110422,
#     'Delta Number': 0.0,
#     'Avg Cost': 9251.71527194755},
#    {'Asset': '^IXIC',
#     'Number': 6.726236918557876,
#     'Price': 5053.61845756368,
#     'Net Value': 33991.83504157033,
#     'Delta Number': 0.0,
#     'Avg Cost': 4681.132826322381}]},
#  {'Date': Timestamp('2015-05-19 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 0.6159498606776559,
#     'Price': 56189.01835573653,
#     'Net Value': 34609.61802783017,
#     'Delta Number': -4.333131928378421,
#     'Avg Cost': 48509.07361685394},
#    {'Asset': '^TWII',
#     'Number': 28.498869573909545,
#     'Price': 9694.065693779088,
# ...
#     'Delta Number': 0.0,
#     'Avg Cost': 5471.229810870589}]},
#  {'Date': Timestamp('2019-04-30 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.5553860658609144,
#     'Price': 96391.68608616269,
#     'Net Value': 246317.97148941952,
#     'Delta Number': 0.0,
#     'Avg Cost': 94908.11786448715},
#    {'Asset': '^TWII',
#     'Number': 22.7569675717081,
#     'Price': 10916.667704487541,
#     'Net Value': 248430.25294213608,
#     'Delta Number': 0.0,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.884329278240505,
#     'Price': 8063.820954425076,
#     'Net Value': 55513.998691037836,
#     'Delta Number': 0.0,
#     'Avg Cost': 5471.229810870589}]},
#  {'Date': Timestamp('2019-05-02 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.5553860658609144,
#     'Price': 96108.28970633741,
#     'Net Value': 245593.78432929856,
#     'Delta Number': 0.0,
#     'Avg Cost': 94908.11786448715},
#    {'Asset': '^TWII',
#     'Number': 22.7569675717081,
#     'Price': 11026.598226421762,
#     'Net Value': 250931.93826493408,
#     'Delta Number': 0.0,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.884329278240505,
#     'Price': 8056.87784891877,
#     'Net Value': 55466.20006651886,
#     'Delta Number': 0.0,
#     'Avg Cost': 5471.229810870589}]},
#  {'Date': Timestamp('2019-05-03 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.5553860658609144,
#     'Price': 95764.59107701665,
#     'Net Value': 244715.50164107681,
#     'Delta Number': 0.0,
#     'Avg Cost': 94908.11786448715},
#    {'Asset': '^TWII',
#     'Number': 22.7569675717081,
#     'Price': 11082.886576619683,
#     'Net Value': 252212.8904250531,
#     'Delta Number': 0.0,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.884329278240505,
#     'Price': 8129.934623131058,
#     'Net Value': 55969.14695620233,
#     'Delta Number': 0.0,
#     'Avg Cost': 5471.229810870589}]},
#  {'Date': Timestamp('2019-05-06 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.5553860658609144,
#     'Price': 95628.23787991352,
#     'Net Value': 244367.06658116388,
#     'Delta Number': 0.0,
#     'Avg Cost': 94908.11786448715},
#    {'Asset': '^TWII',
#     'Number': 22.7569675717081,
#     'Price': 10983.984441327455,
#     'Net Value': 249962.1777394352,
#     'Delta Number': 0.0,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.884329278240505,
#     'Price': 8003.164080663744,
#     'Net Value': 55096.41679907616,
#     'Delta Number': 0.0,
#     'Avg Cost': 5471.229810870589}]},
#  {'Date': Timestamp('2019-05-07 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.5553860658609144,
#     'Price': 92764.55409585746,
#     'Net Value': 237049.24894235516,
#     'Delta Number': 0.0,
#     'Avg Cost': 94908.11786448715},
#    {'Asset': '^TWII',
#     'Number': 22.7569675717081,
#     'Price': 10965.638370356817,
#     'Net Value': 249544.67679728812,
#     'Delta Number': 0.0,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.884329278240505,
#     'Price': 7973.818005277121,
#     'Net Value': 54894.388753090585,
#     'Delta Number': 0.0,
#     'Avg Cost': 5471.229810870589}]},
#  {'Date': Timestamp('2019-05-08 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.5553860658609144,
#     'Price': 95088.32760172083,
#     'Net Value': 242987.38737945518,
#     'Delta Number': 0.0,
#     'Avg Cost': 94908.11786448715},
#    {'Asset': '^TWII',
#     'Number': 22.7569675717081,
#     'Price': 10936.468755402375,
#     'Net Value': 248880.86481569067,
#     'Delta Number': 0.0,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.884329278240505,
#     'Price': 7978.90817365496,
#     'Net Value': 54929.43114828531,
#     'Delta Number': 0.0,
#     'Avg Cost': 5471.229810870589}]},
#  {'Date': Timestamp('2019-05-09 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.5553860658609144,
#     'Price': 95051.61219521916,
#     'Net Value': 242893.56534127842,
#     'Delta Number': 0.0,
#     'Avg Cost': 94908.11786448715},
#    {'Asset': '^TWII',
#     'Number': 22.7569675717081,
#     'Price': 10790.959953126863,
#     'Net Value': 245569.52572090877,
#     'Delta Number': 0.0,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.884329278240505,
#     'Price': 7808.900067773197,
#     'Net Value': 53759.039367425285,
#     'Delta Number': 0.0,
#     'Avg Cost': 5471.229810870589}]},
#  {'Date': Timestamp('2019-05-10 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 2.5553860658609144,
#     'Price': 94666.01214670656,
#     'Net Value': 241908.20835031403,
#     'Delta Number': 0.0,
#     'Avg Cost': 94908.11786448715},
#    {'Asset': '^TWII',
#     'Number': 22.7569675717081,
#     'Price': 10714.176187976444,
#     'Net Value': 243822.16006734702,
#     'Delta Number': 0.0,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.884329278240505,
#     'Price': 7793.5233586379145,
#     'Net Value': 53653.18103852226,
#     'Delta Number': 0.0,
#     'Avg Cost': 5471.229810870589}]},
#  {'Date': Timestamp('2019-05-13 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 93831.9466115336,
#     'Net Value': 428229.9477491179,
#     'Delta Number': 2.008410841412039,
#     'Avg Cost': 94434.5222914231},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 10669.472830177152,
#     'Net Value': 53587.745668090756,
#     'Delta Number': -17.734437731571564,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7741.605379347646,
#     'Net Value': 53587.016161581305,
#     'Delta Number': 0.03762211759477019,
#     'Avg Cost': 5483.569732337378}]},
#  {'Date': Timestamp('2019-05-14 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 92224.31718398519,
#     'Net Value': 420893.0535396315,
#     'Delta Number': 0.0,
#     'Avg Cost': 94434.5222914231},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 10370.322492724454,
#     'Net Value': 52085.25417154766,
#     'Delta Number': 0.0,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7715.783759571059,
#     'Net Value': 53408.28016452603,
#     'Delta Number': 0.0,
#     'Avg Cost': 5483.569732337378}]},
#  {'Date': Timestamp('2019-05-15 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 91757.11499554606,
#     'Net Value': 418760.83763696183,
#     'Delta Number': 0.0,
#     'Avg Cost': 94434.5222914231},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 10601.910433763987,
#     'Net Value': 53248.4115160345,
#     'Delta Number': 0.0,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7837.518962566722,
#     'Net Value': 54250.92532282415,
#     'Delta Number': 0.0,
#     'Avg Cost': 5483.569732337378}]},
#  {'Date': Timestamp('2019-05-16 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 89901.28576369985,
#     'Net Value': 410291.2099282354,
#     'Delta Number': 0.0,
#     'Avg Cost': 94434.5222914231},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 10511.353023413021,
#     'Net Value': 52793.58422030129,
#     'Delta Number': 0.0,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7908.806286542503,
#     'Net Value': 54744.37271452367,
#     'Delta Number': 0.0,
#     'Avg Cost': 5483.569732337378}]},
#  {'Date': Timestamp('2019-05-17 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 89884.82298142783,
#     'Net Value': 410216.07713341725,
#     'Delta Number': 0.0,
#     'Avg Cost': 94434.5222914231},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 10559.781129465526,
#     'Net Value': 53036.81582805129,
#     'Delta Number': 0.0,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7853.046555509395,
#     'Net Value': 54358.40656646765,
#     'Delta Number': 0.0,
#     'Avg Cost': 5483.569732337378}]},
#  {'Date': Timestamp('2019-05-20 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 91843.47827399142,
#     'Net Value': 419154.98210003274,
#     'Delta Number': 0.0,
#     'Avg Cost': 94434.5222914231},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 10390.340948824796,
#     'Net Value': 52185.7974646651,
#     'Delta Number': 0.0,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7720.771624385836,
#     'Net Value': 53442.805922342915,
#     'Delta Number': 0.0,
#     'Avg Cost': 5483.569732337378}]},
#  {'Date': Timestamp('2019-05-21 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 92520.80430042981,
#     'Net Value': 422246.16052470775,
#     'Delta Number': 0.0,
#     'Avg Cost': 94434.5222914231},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 10375.219242282117,
#     'Net Value': 52109.8482423207,
#     'Delta Number': 0.0,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7771.915047850569,
#     'Net Value': 53796.81821378242,
#     'Delta Number': 0.0,
#     'Avg Cost': 5483.569732337378}]},
#  {'Date': Timestamp('2019-05-22 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 94797.77641657968,
#     'Net Value': 432637.7988263393,
#     'Delta Number': 0.0,
#     'Avg Cost': 94434.5222914231},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 10467.74147736442,
#     'Net Value': 52574.54392889769,
#     'Delta Number': 0.0,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7746.170947162719,
#     'Net Value': 53618.61880009164,
#     'Delta Number': 0.0,
#     'Avg Cost': 5483.569732337378}]},
#  {'Date': Timestamp('2019-05-23 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 94493.91617185497,
#     'Net Value': 431251.0423812215,
#     'Delta Number': 0.0,
#     'Avg Cost': 94434.5222914231},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 10310.168296404412,
#     'Net Value': 51783.12792552082,
#     'Delta Number': 0.0,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7625.648399596651,
#     'Net Value': 52784.36758373707,
#     'Delta Number': 0.0,
#     'Avg Cost': 5483.569732337378}]},
#  {'Date': Timestamp('2019-05-24 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 93891.11420789843,
#     'Net Value': 428499.97664241854,
#     'Delta Number': 0.0,
#     'Avg Cost': 94434.5222914231},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 10363.379386105531,
#     'Net Value': 52050.382211370874,
#     'Delta Number': 0.0,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7654.653698110757,
#     'Net Value': 52985.140850273405,
#     'Delta Number': 0.0,
#     'Avg Cost': 5483.569732337378}]},
#  {'Date': Timestamp('2019-05-28 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 95232.19692228305,
#     'Net Value': 434620.4057867243,
#     'Delta Number': 0.0,
#     'Avg Cost': 94434.5222914231},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 10360.629860535033,
#     'Net Value': 52036.57263714683,
#     'Delta Number': 0.0,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7643.343173920273,
#     'Net Value': 52906.849951565455,
#     'Delta Number': 0.0,
#     'Avg Cost': 5483.569732337378}]},
#  {'Date': Timestamp('2019-05-29 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 96266.62664866459,
#     'Net Value': 439341.33297277556,
#     'Delta Number': 0.0,
#     'Avg Cost': 94434.5222914231},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 10294.840182177613,
#     'Net Value': 51706.142014423705,
#     'Delta Number': 0.0,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7570.466458676744,
#     'Net Value': 52402.400870761616,
#     'Delta Number': 0.0,
#     'Avg Cost': 5483.569732337378}]},
#  {'Date': Timestamp('2019-05-30 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 97050.36216242128,
#     'Net Value': 442918.1426865783,
#     'Delta Number': 0.0,
#     'Avg Cost': 94434.5222914231},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 10340.172088657806,
#     'Net Value': 51933.822867430754,
#     'Delta Number': 0.0,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7570.4522317842775,
#     'Net Value': 52402.30239290345,
#     'Delta Number': 0.0,
#     'Avg Cost': 5483.569732337378}]},
#  {'Date': Timestamp('2019-05-31 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 97653.03236438734,
#     'Net Value': 445668.6070904166,
#     'Delta Number': 0.0,
#     'Avg Cost': 94434.5222914231},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 10486.58293372968,
#     'Net Value': 52669.17570572384,
#     'Delta Number': 0.0,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7475.238779361672,
#     'Net Value': 51743.2395030045,
#     'Delta Number': 0.0,
#     'Avg Cost': 5483.569732337378}]},
#  {'Date': Timestamp('2019-06-03 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 97406.29006486507,
#     'Net Value': 444542.52534696343,
#     'Delta Number': 0.0,
#     'Avg Cost': 94434.5222914231},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 10486.516121616356,
#     'Net Value': 52668.84013989099,
#     'Delta Number': 0.0,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7327.198405444741,
#     'Net Value': 50718.51123013023,
#     'Delta Number': 0.0,
#     'Avg Cost': 5483.569732337378}]},
#  {'Date': Timestamp('2019-06-04 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 96613.64201545109,
#     'Net Value': 440925.040630492,
#     'Delta Number': 0.0,
#     'Avg Cost': 94434.5222914231},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 10463.292599064114,
#     'Net Value': 52552.19930487928,
#     'Delta Number': 0.0,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7416.058445740906,
#     'Net Value': 51333.59611009224,
#     'Delta Number': 0.0,
#     'Avg Cost': 5483.569732337378}]},
#  {'Date': Timestamp('2019-06-05 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 96636.08010877573,
#     'Net Value': 441027.44353141205,
#     'Delta Number': 0.0,
#     'Avg Cost': 94434.5222914231},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 10538.018450443335,
#     'Net Value': 52927.51212326102,
#     'Delta Number': 0.0,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7577.830677511008,
#     'Net Value': 52453.375635600685,
#     'Delta Number': 0.0,
#     'Avg Cost': 5483.569732337378}]},
#  {'Date': Timestamp('2019-06-06 00:00:00'),
#   'Record': [{'Asset': '^BVSP',
#     'Number': 4.563796907272954,
#     'Price': 97392.81334379275,
#     'Net Value': 444481.0203290134,
#     'Delta Number': 0.0,
#     'Avg Cost': 94434.5222914231},
#    {'Asset': '^TWII',
#     'Number': 5.022529840136535,
#     'Price': 10414.56625304369,
#     'Net Value': 52307.469777990875,
#     'Delta Number': 0.0,
#     'Avg Cost': 10237.254460168391},
#    {'Asset': '^IXIC',
#     'Number': 6.921951395835275,
#     'Price': 7594.987605345651,
#     'Net Value': 52572.13505617394,
#     'Delta Number': 0.0,
#     'Avg Cost': 5483.569732337378}]},
#  ...]

# %% [raw]
# nominal_price_resul[0-3]: The Transaction Records for evenly rebalancing the portfolio for [1 year, 6 months, 3 months, 1 months], REGARDLESS of Commission Cost and FX Change;
#
# actual_price_result[0-3]: The Transaction Records for evenly rebalancing the portfolio for [1 year, 6 months, 3 months, 1 months], CONSIDERING of Commission Cost and FX Change;

# %%
price_df_list = pickle.load(open("0306-adjusted market prices.out", "rb"))

# %% [raw]
# price_df_list[0-2]: The History data for three indexes [^BVSP, ^TWII, ^IXIC] within a given range, with Nominal Price['Price'], and Actual Price ['Actual Price'], where the Cummulative FX Change ['Cum FX Change'] is considered

# %%
nominal_plot_data_list = []
actual_plot_data_list = []

# for balance_freq in range(4):
for balance_freq in [1]: # We only draw the 6-month rebalancing
    # 1. Get Nominal Price Transaction Records
    nominal = nominal_price_result
    trans_date_df = pd.DataFrame([tmp['Date']for tmp in nominal], columns = ['Date']) 
    # ^ Action dates in the five years
    nominal_trans_df_list = []
    
    for i in range(3): # nominal_df_list[0-2] for three assets
        asset_df = pd.DataFrame([tmp['Record'][i] for tmp in nominal]) 
        # ^ Get the asset weightage at each time
        result_df = pd.concat([trans_date_df, asset_df], axis=1)
        result_df.rename(columns={'0':'Date'}, inplace=True)
        nominal_trans_df_list.append(result_df)
        
    # 2. Get Actual Price Transaction Records
    actual = actual_price_result
    trans_date_df = pd.DataFrame([tmp['Date']for tmp in actual], columns = ['Date'])
    actual_trans_df_list = []
    
    for i in range(3):
        asset_df = pd.DataFrame([tmp['Record'][i] for tmp in actual])
        result_df = pd.concat([trans_date_df, asset_df], axis=1)
        result_df.rename(columns={'0':'Date'}, inplace=True)
        actual_trans_df_list.append(result_df)

        
    for market_num in range(3):
        tmp_trans_df = actual_trans_df_list[market_num]
        trans_date = tmp_trans_df['Date']
        start_date = list(trans_date)[0]
        end_date = list(price_df_list[0]['Date'])[-1]

        history_df = price_df_list[market_num]
        all_price_date = history_df['Date'][(history_df['Date']>=start_date) & (history_df['Date']<= end_date)]
        plot_data = []
        number = 0
        net_value = 0
        price = 0
        for date in all_price_date:
            if (trans_date == date).any(): # If rebalanced at that day:
                number = tmp_trans_df['Number'][tmp_trans_df['Date']==date].values[0]
                net_value = tmp_trans_df['Net Value'][tmp_trans_df['Date']==date].values[0]
                price = tmp_trans_df['Price'][tmp_trans_df['Date']==date].values[0]
                avg_cost = tmp_trans_df['Avg Cost'][tmp_trans_df['Date']==date].values[0]
            else:
                price = history_df['Actual Price'][history_df['Date']==date].values[0]
                net_value = number*price
            plot_data.append({
                "Date": date,
                "Number": number,
                "Price": price,
                "Net Value": net_value,
                "Avg Cost": avg_cost
            })
        actual_plot_data_list.append(plot_data)
        
        
    for market_num in range(3):
        tmp_trans_df = nominal_trans_df_list[market_num]
        trans_date = tmp_trans_df['Date']
        start_date = list(trans_date)[0]
        end_date = list(price_df_list[0]['Date'])[-1]

        history_df = price_df_list[market_num]
        all_price_date = history_df['Date'][(history_df['Date']>=start_date) & (history_df['Date']<= end_date)]
        plot_data = []
        number = 0
        net_value = 0
        price = 0
        for date in all_price_date:
            if (trans_date == date).any(): # If rebalanced at that day:
                number = tmp_trans_df['Number'][tmp_trans_df['Date']==date].values[0]
                net_value = tmp_trans_df['Net Value'][tmp_trans_df['Date']==date].values[0]
                price = tmp_trans_df['Price'][tmp_trans_df['Date']==date].values[0]
                avg_cost = tmp_trans_df['Avg Cost'][tmp_trans_df['Date']==date].values[0]
            else:
                price = history_df['Actual Price'][history_df['Date']==date].values[0]
                net_value = number*price
            plot_data.append({
                "Date": date,
                "Number": number,
                "Price": price,
                "Net Value": net_value,
                "Avg Cost": avg_cost
            })
        nominal_plot_data_list.append(plot_data)

# %%
plt.figure(figsize=(20,10))

for i, df in enumerate(nominal_plot_data_list):
    nominal_df = pd.DataFrame(nominal_plot_data_list[i])
    actual_df = pd.DataFrame(actual_plot_data_list[i])
    plt.plot(nominal_df['Date'], (actual_df['Avg Cost'] - nominal_df['Avg Cost'])/nominal_df['Avg Cost'][0])
    
# plt.plot(actual_df['Date'], actual_df['Net Value'])

# %%
i=0
nominal_df = pd.DataFrame(nominal_plot_data_list[i])
actual_df = pd.DataFrame(actual_plot_data_list[i])
plt.plot(actual_df['Date'], (actual_df['Avg Cost'] - nominal_df['Avg Cost']))

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.gridspec import GridSpec
from CSVUtils import *

DIR = "./from github/Stock-Trading-Environment/data"
file_names = ["^BVSP", "^TWII", "^IXIC"]
source_list = ["yahoo", "yahoo", "yahoo"]

nominal_labels = ["high risk-^BVSP", "mid risk-^TWII", "low risk-^IXIC"]
actual_labels = ["high risk-^BVSP_actual", "mid risk-^TWII_actual", "low rick-^IXIC"]


plt.rcParams['figure.facecolor'] = 'white'
fig=plt.figure(figsize=(20,20))
axs = []
gs=GridSpec(4,1) # 5 rows, 1 columns
axs.append(fig.add_subplot(gs[0,0])) # First row, first column
axs.append(fig.add_subplot(gs[1,0])) # First row, second column
axs.append(fig.add_subplot(gs[2,0])) # First row, second column
axs.append(fig.add_subplot(gs[3,0])) # First row, second column




init_price = [tmp['Price'][0] for tmp in actual_trans_df_list]
#     print(init_net_value)


for i, plot_data in enumerate(nominal_plot_data_list):
    nominal_plot_data = pd.DataFrame(plot_data)
    actual_plot_data = pd.DataFrame(actual_plot_data_list[i])
    
#     axs[i].plot(nominal_plot_data['Date'], (actual_plot_data['Net Value'] - nominal_plot_data['Net Value'])/init_price[i], 
#                 color="C0", label = nominal_labels[i]+"_Market Value")
        
    axs[0].plot(nominal_plot_data['Date'], (actual_plot_data['Avg Cost'] - nominal_plot_data['Avg Cost'])/init_price[i]*100, 
                label = nominal_labels[i]+"_Delta Avg Cost")
    
    axs[1].plot(price_df_list[0]['Date'], (price_df_list[i]['Cum FX Change']-1)*100, 
                label = nominal_labels[i]+"_Log FX Change")
    
    axs[2].bar(nominal_plot_data['Date'], np.insert(np.diff(nominal_plot_data['Net Value']), 0, 0)/nominal_plot_data['Net Value'][0]*100, 
               label = nominal_labels[i]+"_Delta Net Value", width = 5)

#     axs[1].plot(nominal_plot_data['Date'], np.insert(np.diff(nominal_plot_data['Net Value']), 0, 0)/nominal_plot_data['Net Value'][0]*100, 
#                label = nominal_labels[i]+"_Delta Number")
    
    
#     axs[2].plot(price_df_list[0]['Date'], (price_df_list[i]['Cum FX Change']-1)*100,
#                  linestyle='--', label = nominal_labels[i]+"_Log FX Change")

axs[0].legend()
axs[0].axhline(y=0, color = "grey", linestyle='--')
axs[0].set_title('Delta Avg Cost')
axs[0].set_xlabel('Date')
axs[0].set_ylabel('Percentage %')

axs[1].legend()
axs[1].axhline(y=0, color = "grey", linestyle='--')
axs[1].set_title('Cum FX Change')
axs[1].set_xlabel('Date')
axs[1].set_ylabel('Percentage%')

axs[2].legend()
axs[2].axhline(y=0, color = "grey", linestyle='--')
axs[2].set_title('Delta Number')
axs[2].set_xlabel('Date')
axs[2].set_ylabel('Percentage %')



# for i, plot_data in enumerate(actual_plot_data_list):
#     plot_data = pd.DataFrame(plot_data)

#     axs[i].plot(plot_data['Date'], plot_data['Net Value'], 
#                 color="orange", label = actual_labels[i]+"_Log Market Value")
# #         axs[i].bar(actual_trans_df_list[i]['Date'], np.log(actual_trans_df_list[i]['Net Value']/actual_trans_df_list[i]['Net Value'][0]), 
# #     axs[i].bar(actual_trans_df_list[i]['Date'], np.log(actual_trans_df_list[i]['Net Value']/init_net_value), 
# #                width=2, color="orange")

# #     axs[i].plot(actual_trans_df_list[i]['Date'], np.log(actual_trans_df_list[i]['Net Value']/init_net_value), 
# #                 linestyle='--', color="orange", label = actual_labels[i]+"_Log Book Value")



# #     axs[i].set_ylim((0, 300000))
#     axs[i].set_title('Log Portfolio Value')
#     axs[i].set_xlabel('Date')
#     axs[i].set_ylabel('Log Value')



for i in range(3): # Inverse: Low-Mid-High
    df = csv2df(DIR, file_names[i]+".csv",source = source_list[i])
    df['Date'] = pd.to_datetime(df['Date'])
    df = df[(df['Date']>=pd.to_datetime("2015-01-01"))&(df['Date']<=pd.to_datetime("2019-12-31"))].reset_index(drop=True)

    j = 0
    init_price = df['Price'][j]
    while np.isnan(init_price):
        j+=1
        init_price = df['Price'][j]
    y = ((df['Price'][j:] / init_price)-1)*100
    x = df['Date'][j:]
    axs[3].plot(x,y,label = nominal_labels[i])
#     axs[i].plot(x,y, color = "pink", linestyle='--', label = nominal_labels[i]+"_Log Nominal Price")


axs[3].axhline(y=0, color = "grey", linestyle='--')
# axs[3].set_ylim((-1,1))
axs[3].legend()
axs[3].set_title('Market Price Change')
axs[3].set_xlabel('Date')
axs[3].set_ylabel('Percentage %')
plt.show()

# %%
nom_df = pd.DataFrame(nominal_plot_data_list[0])
nom_df[(nom_df['Date'] >= pd.to_datetime("2017-12-01")) & (nom_df['Date'] <= pd.to_datetime("2017-12-15"))]
# Out:
#           Date    Number    Price      Net Value      Avg Cost
# 660 2017-12-01  0.649155  72264.0   46910.525732  64710.903538
# 661 2017-12-04  0.649155  73090.0   47446.727634  64710.903538
# 662 2017-12-05  0.649155  72546.0   47093.587399  64710.903538
# 663 2017-12-06  0.649155  73268.0   47562.277197  64710.903538
# 664 2017-12-07  0.649155  72487.0   47055.287263  64710.903538
# 665 2017-12-08  0.649155  72732.0   47214.330200  64710.903538
# 666 2017-12-11  0.649155  72800.0   47258.472729  64710.903538
# 667 2017-12-12  5.179591  73814.0  382326.348154  72673.114765
# 668 2017-12-13  5.179591  72914.0  377664.716033  72673.114765
# 669 2017-12-14  5.179591  72429.0  375152.614279  72673.114765
# 670 2017-12-15  5.179591  72608.0  376079.761112  72673.114765

# %%
act_df = pd.DataFrame(actual_plot_data_list[0])
act_df[(act_df['Date'] >= pd.to_datetime("2017-12-01")) & (act_df['Date'] <= pd.to_datetime("2017-12-15"))]
# Out:
#           Date    Number         Price      Net Value      Avg Cost
# 660 2017-12-01  0.649155  72115.109654   46813.872843  64955.207398
# 661 2017-12-04  0.649155  73687.932553   47834.878448  64955.207398
# 662 2017-12-05  0.649155  72792.428366   47253.557567  64955.207398
# 663 2017-12-06  0.649155  73006.239980   47392.354411  64955.207398
# 664 2017-12-07  0.649155  73191.859576   47512.850272  64955.207398
# 665 2017-12-08  0.649155  72888.303637   47315.795463  64955.207398
# 666 2017-12-11  0.649155  73297.345725   47581.327116  64955.207398
# 667 2017-12-12  5.179591  72130.183180  373604.865293  71230.948072
# 668 2017-12-13  5.179591  74209.087787  384372.741394  71230.948072
# 669 2017-12-14  5.179591  72337.948486  374681.004653  71230.948072
# 670 2017-12-15  5.179591  72926.955106  377731.818185  71230.948072

# %%
price_df = price_df_list[0]
price_df[(price_df['Date'] >= pd.to_datetime("2017-12-01")) & (price_df['Date'] <= pd.to_datetime("2017-12-15"))]
# Out:
#           Date     Open     High      Low    Price        Vol    Change  \
# 666 2017-12-01  71955.0  72472.0  71488.0  72264.0  3003100.0  0.004071
# 667 2017-12-04  72266.0  73749.0  72266.0  73090.0  3038600.0  0.011430
# 668 2017-12-05  73090.0  74166.0  72319.0  72546.0  2913300.0 -0.007443
# 669 2017-12-06  72535.0  73418.0  71906.0  73268.0  3099300.0  0.009952
# 670 2017-12-07  73268.0  73268.0  71356.0  72487.0  3260800.0 -0.010659
# 671 2017-12-08  72489.0  73425.0  72489.0  72732.0  3085600.0  0.003380
# 672 2017-12-11  72775.0  73361.0  72498.0  72800.0  2450200.0  0.000935
# 673 2017-12-12  72800.0  73814.0  71798.0  73814.0  2956100.0  0.013929
# 674 2017-12-13  73827.0  74622.0  72569.0  72914.0  4494700.0 -0.012193
# 675 2017-12-14  72913.0  72913.0  71969.0  72429.0  3491800.0 -0.006652
# 676 2017-12-15  72428.0  73069.0  72277.0  72608.0  4659500.0  0.002471
#
#      FX Change  Cum FX Change  Actual Price
# 666     0.0043       0.911453  65865.218333
# 667     0.0046       0.915645  66924.521428
# 668     0.0006       0.916195  66466.266183
# 669     0.0016       0.917661  67235.163225
# 670    -0.0165       0.902519  65420.915470
# 671    -0.0003       0.902249  65622.340085
# 672    -0.0039       0.898730  65427.526582
# 673    -0.0007       0.898101  66292.401373
# 674    -0.0010       0.897203  65418.626677
# 675    -0.0096       0.888589  64359.641999
# 676     0.0144       0.901385  65447.768776

# %%
df[(df['date'] >= pd.to_datetime("2017-12-01")) & (df['date'] <= pd.to_datetime("2017-12-15"))]
# Out:
#           date                                       actual_price  \
# 660 2017-12-01  [72115.10965375148, 10661.934185666658, 6777.3...
# 661 2017-12-04  [73687.93255273186, 10596.979518997025, 6881.6...
# 662 2017-12-05  [72792.4283662736, 10583.62191975625, 6823.654...
# 663 2017-12-06  [73006.23997955752, 10414.726740007227, 6741.9...
# 664 2017-12-07  [73191.85957637585, 10412.22659336163, 6820.15...
# 665 2017-12-08  [72888.30363695617, 10361.69678717632, 6863.66...
# 666 2017-12-11  [73297.34572458362, 10483.617143708512, 6858.4...
# 667 2017-12-12  [72130.18317972333, 10435.584651235436, 6858.9...
# 668 2017-12-13  [74209.08778657997, 10465.73486266777, 6883.79...
# 669 2017-12-14  [72337.94848563761, 10564.895235425023, 6873.3...
# 670 2017-12-15  [72926.95510567578, 10454.29122246849, 6877.79...
#
#                           action  \
# 660         [0.0, 0.0, 1.0, 1.0]
# 661         [0.0, 0.0, 1.0, 1.0]
# 662  [0.0, 0.22800267, 1.0, 1.0]
# 663         [0.0, 0.0, 1.0, 1.0]
# 664         [0.0, 0.0, 1.0, 1.0]
# 665         [0.0, 0.0, 1.0, 1.0]
# 666  [0.17517734, 0.0, 1.0, 1.0]
# 667         [1.0, 0.0, 1.0, 1.0]
# 668         [1.0, 0.0, 1.0, 1.0]
# 669         [1.0, 0.0, 1.0, 1.0]
# 670  [0.69207084, 0.0, 1.0, 1.0]
#
#                                              inventory  \
# 660  [47903.03349271317, 383284.8454595289, 47910.6...
# 661  [47903.03349271317, 383284.8454595289, 47910.6...
# 662  [47903.03349271317, 383284.8454595289, 47910.6...
# 663  [47903.03349271317, 383284.8454595289, 47910.6...
# 664  [47903.03349271317, 383284.8454595289, 47910.6...
# 665  [47903.03349271317, 383284.8454595289, 47910.6...
# 666  [47903.03349271317, 383284.8454595289, 47910.6...
# 667  [373604.8652932868, 46802.91908195817, 46802.9...
# 668  [373604.8652932868, 46802.91908195817, 46802.9...
# 669  [373604.8652932868, 46802.91908195817, 46802.9...
# 670  [373604.8652932868, 46802.91908195817, 46802.9...
#
#                                            shares_held      net_worth  \
# 660  [0.6491548451827321, 35.65731157400905, 7.1586...  479098.484635
# 661  [0.6491548451827321, 35.65731157400905, 7.1586...  479098.484635
# 662  [0.6491548451827321, 35.65731157400905, 7.1586...  479098.484635
# 663  [0.6491548451827321, 35.65731157400905, 7.1586...  479098.484635
# 664  [0.6491548451827321, 35.65731157400905, 7.1586...  479098.484635
# 665  [0.6491548451827321, 35.65731157400905, 7.1586...  479098.484635
# 666  [0.6491548451827321, 35.65731157400905, 7.1586...  479098.484635
# 667  [5.179591244935472, 4.484935022439526, 6.82366...  467210.703457
# 668  [5.179591244935472, 4.484935022439526, 6.82366...  467210.703457
# 669  [5.179591244935472, 4.484935022439526, 6.82366...  467210.703457
# 670  [5.179591244935472, 4.484935022439526, 6.82366...  467210.703457
#
#      net_worth_delta  buyNhold_balance  buyNhold_delta  actual_profit  \
# 660      8166.439809     412983.854119    -1704.316163   66114.630515
# 661      8166.439809     412983.854119    -1704.316163   66114.630515
# 662      8166.439809     412983.854119    -1704.316163   66114.630515
# 663      8166.439809     412983.854119    -1704.316163   66114.630515
# 664      8166.439809     412983.854119    -1704.316163   66114.630515
# 665      8166.439809     412983.854119    -1704.316163   66114.630515
# 666      8166.439809     412983.854119    -1704.316163   66114.630515
# 667    -11887.781177     413980.748982      996.894863   53229.954475
# 668    -11887.781177     413980.748982      996.894863   53229.954475
# 669    -11887.781177     413980.748982      996.894863   53229.954475
# 670    -11887.781177     413980.748982      996.894863   53229.954475
#
#       progress  testNo   rewards
# 660  -4.795023     660  0.052951
# 661  -4.795023     661  0.047417
# 662  -4.795023     662  0.049569
# 663  -4.795023     663  0.046347
# 664  -4.795023     664  0.051899
# 665  -4.795023     665  0.050820
# 666  -4.795023     666  0.056687
# 667 -11.911857     667  0.046721
# 668 -11.911857     668  0.046665
# 669 -11.911857     669  0.046754
# 670 -11.911857     670  0.035979
