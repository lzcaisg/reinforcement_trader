# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("^GSPC.csv")

# %%
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     1990-01-02   353.399994   359.690002   351.980011   359.690002
# 1     1990-01-03   359.690002   360.589996   357.890015   358.760010
# 2     1990-01-04   358.760010   358.760010   352.890015   355.670013
# 3     1990-01-05   355.670013   355.670013   351.350006   352.200012
# 4     1990-01-08   352.200012   354.239990   350.540009   353.790009
# ...          ...          ...          ...          ...          ...
# 7553  2019-12-23  3226.050049  3227.780029  3222.300049  3224.010010
# 7554  2019-12-24  3225.449951  3226.429932  3220.510010  3223.379883
# 7555  2019-12-26  3227.199951  3240.080078  3227.199951  3239.909912
# 7556  2019-12-27  3247.229980  3247.929932  3234.370117  3240.020020
# 7557  2019-12-30  3240.090088  3240.919922  3216.570068  3221.290039
#
#         Adj Close      Volume
# 0      359.690002   162070000
# 1      358.760010   192330000
# 2      355.670013   177000000
# ...

# %%
type(df['Date'][0])
# Out:
# str

# %%
df.drop("Close", axis=1, inplace=True)
df.columns = ["Date", "Open", "High", "Low", "Price", "Vol"]
df['Date'] = pd.to_datetime(df['Date'])
df['Change'] = df['Price'].pct_change()

# %%
df
# Out:
#            Date         Open         High          Low        Price  \
# 0    1990-01-02   353.399994   359.690002   351.980011   359.690002
# 1    1990-01-03   359.690002   360.589996   357.890015   358.760010
# 2    1990-01-04   358.760010   358.760010   352.890015   355.670013
# 3    1990-01-05   355.670013   355.670013   351.350006   352.200012
# 4    1990-01-08   352.200012   354.239990   350.540009   353.790009
# ...         ...          ...          ...          ...          ...
# 7553 2019-12-23  3226.050049  3227.780029  3222.300049  3224.010010
# 7554 2019-12-24  3225.449951  3226.429932  3220.510010  3223.379883
# 7555 2019-12-26  3227.199951  3240.080078  3227.199951  3239.909912
# 7556 2019-12-27  3247.229980  3247.929932  3234.370117  3240.020020
# 7557 2019-12-30  3240.090088  3240.919922  3216.570068  3221.290039
#
#              Vol    Change
# 0      162070000       NaN
# 1      192330000 -0.002586
# 2      177000000 -0.008613
# 3      158530000 -0.009756
# ...

# %%
df[(df['Date'] > '2013-01-01') & (df['Date'] < '2013-02-01')]
# Out:
#            Date         Open         High          Low        Price  \
# 5797 2013-01-02  1426.189941  1462.430054  1426.189941  1462.420044
# 5798 2013-01-03  1462.420044  1465.469971  1455.530029  1459.369995
# 5799 2013-01-04  1459.369995  1467.939941  1458.989990  1466.469971
# 5800 2013-01-07  1466.469971  1466.469971  1456.619995  1461.890015
# 5801 2013-01-08  1461.890015  1461.890015  1451.640015  1457.150024
# 5802 2013-01-09  1457.150024  1464.729980  1457.150024  1461.020020
# 5803 2013-01-10  1461.020020  1472.300049  1461.020020  1472.119995
# 5804 2013-01-11  1472.119995  1472.750000  1467.579956  1472.050049
# 5805 2013-01-14  1472.050049  1472.050049  1465.689941  1470.680054
# 5806 2013-01-15  1470.670044  1473.310059  1463.760010  1472.339966
# 5807 2013-01-16  1472.329956  1473.959961  1467.599976  1472.630005
# 5808 2013-01-17  1472.630005  1485.160034  1472.630005  1480.939941
# 5809 2013-01-18  1480.949951  1485.979980  1475.810059  1485.979980
# ...

# %%
df['Date'].min()+pd.Timedelta(days=10*365)
# Out:
# Timestamp('1999-12-31 00:00:00')

# %%
import pickle
result = pickle.load(open("./from github/Stock-Trading-Environment/output/5/sp500_split_04FEB2020.out", "rb"))

# %%
len(result)
# Out:
# 52

# %%
result
# Out:
# [{'trainStart': Timestamp('1990-01-02 00:00:00'),
#   'trainEnd': Timestamp('1999-12-31 00:00:00'),
#   'testStart': Timestamp('2014-12-31 00:00:00'),
#   'testEnd': Timestamp('2019-12-30 00:00:00'),
#   'train_step': 50000,
#   'mean': -341.148284985557,
#   'max': 204.10823480945146,
#   'min': -844.987127308319,
#   'std': 281.52406944928754,
#   'final': -515.2573594985279,
#   'total_shares_sold': 19},
#  {'trainStart': Timestamp('1990-01-02 00:00:00'),
#   'trainEnd': Timestamp('1999-12-31 00:00:00'),
#   'testStart': Timestamp('2014-12-31 00:00:00'),
#   'testEnd': Timestamp('2019-12-30 00:00:00'),
#   'train_step': 50000,
#   'mean': 0.0,
#   'max': 0.0,
#   'min': 0.0,
#   'std': 0.0,
#   'final': 0.0,
#   'total_shares_sold': 0},
#  {'trainStart': Timestamp('1990-01-02 00:00:00'),
#   'trainEnd': Timestamp('1999-12-31 00:00:00'),
#   'testStart': Timestamp('2014-12-31 00:00:00'),
#   'testEnd': Timestamp('2019-12-30 00:00:00'),
#   'train_step': 50000,
# ...
